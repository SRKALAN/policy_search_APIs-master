# %%
# %load_ext autoreload
# %autoreload 15

# %%
# !pip3 install azure-cosmos

# %%
# !pip3 install comtypes

# %%
# !pip3 install pdfminer.six

# %%
import json
import re
from bs4 import BeautifulSoup
import os
import requests
from pprint import pprint
import uuid
from statistics import mode
from nltk.corpus import stopwords
from pdf2txt import convert_pdf
# !pip install tika
import tika
from definitions_v3 import *
# Out:
# /opt/app/RB/.local/lib/python3.6/site-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.2) or chardet (4.0.0) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
pointsRE_heading=re.compile('(?:\s*\([a-z]{1,3}\)|[A-Z]{1}\s+[a-zA-Z0-9_\s]{5})')
stop_words = list(set(stopwords.words('english')))
y_cordinate_Re=re.compile('top:(\d{1,5})px')
height_re=re.compile('height:(\d{1,5})px')

# %%
def check_underline(positions,y_cord_text):
    positions=[i for i in positions if y_cord_text<=i< y_cord_text+16]
    if positions:
        return True
    else:
        return False

# %%
def get_pages_no(soup):
    total_items = int(soup.find('span', id='NewReleases_total').text)
    items_per_page = int(soup.find('span', id='NewReleases_end').text)
    return round(total_items/items_per_page)

# %%
from pdfminer.high_level import extract_pages

# print(len(list(extract_pages('test/Chubb16-250-1019 Chubb EBM Business Pack Product Disclosure Statement (PDS) and Policy Wording.pdf'))))

# %%
def get_underlines(soup):
    positions=[]
    for span in soup.find_all('span'):
        y_cord_list=y_cordinate_Re.findall(str(span))
        if y_cord_list:
            y_cord=int(y_cord_list[0])
        else:
            continue
        style="position:absolute; border: black 1px solid" in str(span)
        height_px_li=height_re.findall(str(span))
        if height_px_li:
            height_px=height_px_li[0]
        else:
            continue
        height=int(height_px)<15
        if all([style,height]):
            positions.append(y_cord)
    return list(set(positions))

# %%
def ext_extract(text_list,language):
    ext_flag=False
    if language=='english':
        ext_lis=['extension']
    else:
        ext_lis=['extensión','extensiones']
   
    ext_count=0
    position_list=[]
    position=0
    for text in text_list:
        # if any two of 'exclusion ,condition or extension is present in the text, that text is omitted from the logic'
        bool_list=['condition' in text.lower(),'exclusion' in text.lower(),'extension' in text.lower()]
        if sum(bool_list)>=2:
            continue
        for i in ext_lis:
            for match in re.finditer(i, text.lower()):
                position_list.append(position+match.start())               
                ext_count+=1
        position+=len(text)
    if ext_count>=1:
        ext_flag=True
    return(ext_flag,ext_count,position_list)

# %%
def excl_extract(text_list,language):
    exclusion_flag=False
    if language=='english':
        excl_lis=['exclud','not cover','except','does not mean','not includ','exclusion']
    else:
        excl_lis=['excepto','excepción','no in cluido','exclusión','excluidos','excluirlo','excluyendo','exclusiones','exclusion','excluyen','excluyentes']
   
    exclusion_count=0
    position_list=[]
    position=0
    for text in text_list:
        # if any two of 'exclusion ,condition or extension is present in the text, that text is omitted from the logic'
        bool_list=['condition' in text.lower(),'exclusion' in text.lower(),'extension' in text.lower()]
        if sum(bool_list)>=2:
            continue
        for i in excl_lis:
            for match in re.finditer(i, text.lower()):
                position_list.append(position+match.start())               
                exclusion_count+=1
        position+=len(text)
    if exclusion_count>=1:
        exclusion_flag=True
    return(exclusion_flag,exclusion_count,position_list)

# %%
def cond_extract(text_list,language):
    cond_flag=False
    if language=='english':
        cond_lis=['condition']
    else:
        cond_lis=['condición','condiciones','condicionado']
   
    cond_count=0
    position_list=[]
    position=0
    for text in text_list:
        # if any two of 'exclusion ,condition or extension is present in the text, that text is omitted from the logic'
        bool_list=['condition' in text.lower(),'exclusion' in text.lower(),'extension' in text.lower()]
        if sum(bool_list)>=2:
            continue
        for i in cond_lis:
            for match in re.finditer(i, text.lower()):
                position_list.append(position+match.start())               
                cond_count+=1
        position+=len(text)
    if cond_count>=1:
        cond_flag=True
    return(cond_flag,cond_count,position_list)

# %%
def font_extraction(soup):
    fontsizes=[]
    for divs in soup.findAll('div'):
        for j in divs.find_all('span'):
            ext_size=re.findall(r'font-size:(.*)px">',str(j))
            if ext_size:
                fontsizes.append(int(ext_size[0]))
    return(fontsizes)

# %%
def stopword_check(word,text,language):
    if language=='spanish':
        stop_words = list(set(stopwords.words('spanish')))
    else:
        stop_words = list(set(stopwords.words('english')))
        transition="although  instead  whereas  despite  conversely  otherwise  however moreover  likewise  comparatively  correspondingly  similarly  furthermore  additionallyver  rather  nevertheless  nonetheless  regardless  notwithstanding consequently  therefore  thereupon  forthwith  accordingly  henceforth"
        transition_words=transition.split()
        transition_words
        stop_words.extend(transition_words)

    if exclusion_check(text,language):
        return True
    if word.lower() in stop_words:
        return False
    else:
        return True

# %%
def exclusion_check(text,language):
    if language=='spanish':
        exclusion_bag=['excepto','excepción','no in cluido','exclusión','excluidos','excluirlo','excluyendo',' excluyen','exclusiones','exclusiones','exclusion','excluyentes']
    else:
        exclusion_bag=['exclusion','excluded','not covered','will not cover','will not pay']
    for word in exclusion_bag:
        if word in text.lower():
            return True
    return False

# %%
def criteria_check(text,language):
    if language=='spanish':
        exclusion_bag=['condición','condiciones','condicionado']
    else:
        exclusion_bag=['condition','conditions']
    for word in exclusion_bag:
        if word in text.lower():
            return True
    return False

# %%
def ext_check(text,language):
    if language=='english':
        ext_bag=['extension']
    else:
        ext_bag=['extensión','extensiones']
    for word in ext_bag:
        if word in text.lower():
            return True
    return False

# %%
start=re.compile('.*\d{1,3}.*(?:\-|\.|–)')
def clean(text):
    text=text.replace('\n','').replace('\t',' ')
    text=start.sub('',text).strip()
    

    return(text)
def clean_pharses(phrases):
    phrases=[clean(i) for i in phrases if len(i)> 3]
    phrases=list(set(phrases))
    return phrases

# %%
def create_local_index(path,subdir,language,country):
    pointsRE_heading=re.compile('(?:\s*\([a-z]{1,3}\)|(?<![A-z])[A-Z]{1}\s+[a-zA-Z0-9_\s]{5})')
    pageNumRE=re.compile('Page\s*(\d{1,3})',re.IGNORECASE)
    neglect_def=['policy','insured','schedule']
    local_indexed={}
    previous_span=''
    bold_phrases_indexed={}
    for file in os.listdir(path):
        if file.endswith('.pdf'):
            print(file)
            global file_count
            file_count+=1
            
            print("COUNT",file_count)
            try:
                pg_no=len(list(extract_pages(os.path.join(path,file))))
            except:
                pg_no=0
            try:
                html=convert_pdf(os.path.join(path,file),'html')
            except:
                continue
            soup = BeautifulSoup(html, 'html5lib')
            underline_positions=get_underlines(soup)
            try:
                fontsizes=font_extraction(soup)
                file_font_size_mode=mode(fontsizes)
            except:
                file_font_size_mode=8
                
            text_para,text_plain_para='',''
            text_lis,text_plain_lis,bold_lis,page_list,=[],[],[],[]
            bold=False
            sub_page_def_list=[]
            try:
                definitions=def_extraction(os.path.join(path,file))
            except:
                continue
            definitions={key:value for key,value in definitions.items() if key.lower().strip() not in neglect_def}
            def_terms=list(definitions.keys())
#             print(len(def_terms),'LEN DEFINITIONS')
#             print(definitions)
            definition_text=''
            header_match_object=(0,'',False)
            cond_header_match_object=(0,'',False)
            ext_header_match_object=(0,'',False)
            second_category=False
            head_found=False
            def_flag=False
            cond_head_found=False
            ext_head_found=False
            single_page_head_found=False
            condition_text=''
            ext_text=''
            excl_text=''
            previous_pg_num=[]
            def_in_page=[]
            cond_single_page_head_found=False
            ext_single_page_head_found=False
            
            font_size=file_font_size_mode

            for divs in soup.findAll('div'):
                div_text_list=[span.text for span in divs.find_all('span') ]
                page_str=str(divs.find_all('a'))
                page_num_results=pageNumRE.findall(page_str)
                if page_num_results:
                    pagenum=page_num_results[0]
#                     print(pagenum)
                    if pagenum!=previous_pg_num:
                        sub_definitions_in_page=[]
                    previous_pg_num=pagenum
#                     definition_text=''
                    
                    #only for pdfs
                    if(int(pagenum) in [1,2]) and 'Wording' in file and pg_no >20:
#                     print('Continued on wording 2')
                        continue

                    if text_lis:
                        text_lis=text_lis[:-1]
                        text_para=''.join(text_lis)
                        text_plain_lis=text_plain_lis[:-1]
                        text_plain_para=''.join(text_plain_lis)
                        if(len(re.findall('\.',text_para))>(len(text_para)/3) or (len(re.findall('\d',text_para))>80 and int(pagenum)<4 and  pg_no>20 and 'content' in text_para.lower())) :
                            print('PASS')
                            print(text_plain_para)
                            text_para,text_plain_para=' ',' '
                            text_lis,text_plain_lis=[],[]
                            single_page_head_found=False
                            head_found=False
                            cond_head_found=False
                            ext_head_found=False
                            continue
                        
                        else:
                            bold_lis=clean_pharses(bold_lis)
                            pagenum=int(pagenum)-1
                            excl_flag,excl_count,excl_pos_lis=excl_extract(text_plain_lis,language)
                            cond_flag,cond_count,cond_pos_lis=cond_extract(text_plain_lis,language)
                            ext_flag,ext_count,ext_pos_lis=ext_extract(text_plain_lis,language)
                            if int(pagenum)==1:
                                if head_found or single_page_head_found or excl_count>0:
#                                     print(pagenum,True,'!!!')
                                    excl_flag=True
                                else:
                                    excl_flag=False
                            else:
                                if head_found or single_page_head_found:
#                                     print(pagenum,True,'!!!',excl_count)
                                    excl_flag=True
#                                     print(excl_flag,'EXCL')
#                                 else:
#                                     print(pagenum,excl_flag,'\n')
# #                             print(excl_text)
#                             print(condition_text)
                            if cond_head_found or cond_single_page_head_found or cond_count>0:
                                cond_flag=True
#                                 print('COND','TRUE')
                            else:
#                                 print('COND','FALSE')
                                cond_flag=False
    
                            if ext_head_found or ext_single_page_head_found or ext_count>0:
                                ext_flag=True
#                                 print('EXT','TRUE',pagenum)
                            else:
#                                 print('EXT','FALSE',pagenum)
                                ext_flag=False
#                             def_in_page=[{'name':k,'text':v[0] for k,v in definitions.items() if v[1]=pagenum}]
                            for term,defs in definitions.items():
#                                 print(defs[1])
                                if defs[1]==pagenum:  ###defs[1] is the pagenumber
                                    definition_text=definition_text+'          '+term+' '+defs[0]
                                    def_in_page.append({'name':term,'text':defs[0]})
#                                     def_in_page{'name':}
#                             print(definition_text)
                            if definition_text:
                                def_flag=True
                            
                            if def_flag:
                                def_search_flag=True
#                                 print('DEF','TRUE')
                            else:
#                                 print('DEF', 'FALSE')
                                def_search_flag=False   
                            
                            if pg_no>2:
                                endorsements=False
                            else:
                                endorsements=True
#                             print(endorsements,'ENDORSEMENTS!!!')
                            if text_para in local_indexed.keys():
                                text_para=text_para+' '
                            
                            local_indexed[text_para]=(file,pagenum,bold_lis,text_plain_para,excl_flag,excl_count,excl_pos_lis,subdir,sub_page_def_list,country,language,definition_text,def_search_flag,endorsements,excl_text,condition_text,cond_flag,cond_count,cond_pos_lis,def_in_page,ext_text,ext_flag,ext_count,ext_pos_lis)
#                             print(sub_page_def_list,'DEF LIST!!!!!1')
                            sub_page_def_list=[]
                            page_list.append(pagenum)
                            text_para,text_plain_para='',''
                            text_lis,text_plain_lis,bold_lis=[],[],[]
                            definition_text=''
                            cond_single_page_head_found=False
                            ext_single_page_head_found=False
                            condition_text=''
                            ext_text=''
                            excl_text=''
                            single_page_head_found=False
                            def_in_page=[]
                            def_flag=False
                for span in divs.find_all('span'):

                    bold=False
                    upper=False
                    bullet=False
                    def_flag=False
                    span_position=div_text_list.index(span.text)
                    
                    if "Bold" in str(span) or 'CIDFont+F3' in str(span):
                        bold_lis.append(span.text)
                        bold=True
                    if span.text.isupper():
                        upper=True
                    font_family_match=re.findall(r"font-family: b'(.*)';",str(span))
                    if font_family_match:
                        font_family=font_family_match[0]
                    else:
                        font_family=''
#                     print(font_family)
                    font_size_match=re.findall(r'font-size:(.*)px">',str(span))
                    if font_size_match:
                        font_size=int(font_size_match[0])
                    if pointsRE_heading.findall(span.text):
                        bullet=True
#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
                    y_cord_list=y_cordinate_Re.findall(str(divs))
                    if y_cord_list:
                        y_cord=int(y_cord_list[0])
                    underlined_text=check_underline(underline_positions,y_cord)
                    if span.text.split('\n')[0]!='' and span.text.split('\n')[0]!=' ':
                        head_check_text=span.text.split('\n')[0]
                    elif len(span.text.split('\n'))>1:
                        head_check_text=span.text.split('\n')[1]
                    else:
                        head_check_text=''
##############################3  
                    if str(previous_span).endswith('<br/></span>'):
                        span_position=0
                    ##################INSERT FUNCTION####################z
                    #EXCLUSION 
                    if  span_position==0 and (bold or font_size>= file_font_size_mode +2 ) and (font_size> file_font_size_mode or upper) and 5<len(head_check_text.strip())<80:                    
                        if exclusion_check(head_check_text,language) and not head_found: 
                            head_found=True
                            header_match_object=(font_size,font_family,bold,upper,bullet)
                            First_category=True
                            second_category=False
                            single_page_head_found=True
#                             print('FOUND Heading for exclusion ...',span.text)
                        
                    
                        elif ((font_size,font_family,bold,upper,bullet)==header_match_object  or font_size>header_match_object[0] ) and head_found and not exclusion_check(head_check_text,language):
                            head_found=False
                            single_page_head_found=True
#                             print('FOUND Closure for exclusion ...',span.text)
#                     if 'CLAIMS CONDITIONS' in span.text:
#                         print ('^^^^^^^',(font_size,font_family,bold,upper,bullet),header_match_object, font_size>header_match_object[0] , head_found , not exclusion_check(head_check_text,language))
#                         print(pointsRE_heading.findall(span.text))
                    words_title=[word.istitle() for word in head_check_text.split() if stopword_check(word,head_check_text,language) and not word.isdigit() ]
                    if span_position==0 and all(words_title) and head_check_text.strip() not in definitions and  (len(words_title) >1 or underlined_text )and 5<len(head_check_text.strip())<80 :
#                         print('MMMMMMMMARARARA',span.text)

                        if exclusion_check(head_check_text,language) and  not head_found:
                            head_found=True
                            second_category=True
                            First_category=False
                            single_page_head_found=True
                            header_match_object=(font_size,font_family,bold,upper,bullet)
#                             print("FOUND heading type2 ....",span.text)
                        elif head_found and not exclusion_check(head_check_text,language) and second_category and ((font_size,font_family,bold,upper,bullet)==header_match_object or font_size > header_match_object[0] ) :
                            head_found=False
                            second_category=False
                            single_page_head_found=True
#                             print('FOUND closure type 2',span.text)
                    if head_found:
                        excl_text=excl_text+' '+span.text     
                     
                    #CONDITIONS
#                     if 'Condition' in span.text:
# #                         print('text:',str(span.text),'head check',head_check_text,'length of head check',len(head_check_text))
# #                         print(span_position==0,(bold or font_size>= file_font_size_mode +2 ), (font_size> file_font_size_mode or upper), 5<len(head_check_text.strip())<80)
# #                         print(font_size,file_font_size_mode,cond_head_found,criteria_check(head_check_text,language))
                    if  span_position==0 and (bold or font_size>= file_font_size_mode +2 ) and (font_size> file_font_size_mode or upper) and 5<len(head_check_text.strip())<80:                    
                        if criteria_check(head_check_text,language) and not cond_head_found: 
                            cond_head_found=True
                            cond_header_match_object=(font_size,font_family,bold,upper,bullet)
                            cond_First_category=True
                            cond_second_category=False
                            cond_single_page_head_found=True
#                             print('FOUND Heading for condition...',span.text)
                    
                        elif ((font_size,font_family,bold,upper,bullet)==cond_header_match_object or font_size>cond_header_match_object[0] ) and not criteria_check(head_check_text,language)  and cond_head_found:
                            cond_head_found=False
                            cond_single_page_head_found=True
#                             print('FOUND Closure for condition ...',span.text)
                
                    
                    cond_words_title=[word.istitle() for word in head_check_text.split() if stopword_check(word,head_check_text,language) and not word.isdigit() ]
                    if span_position==0 and all(cond_words_title) and head_check_text.strip() not in definitions and  (len(words_title) >1 or underlined_text )and 5<len(head_check_text.strip())<80 :
#                         print('MMMMMMMMARARARA',span.text)

                        if criteria_check(head_check_text,language) and  not cond_head_found:
                            cond_head_found=True
                            cond_second_category=True
                            cond_First_category=False
                            cond_single_page_head_found=True
                            cond_header_match_object=(font_size,font_family,bold,upper,bullet)
#                             print("FOUND heading type2 ....",span.text)
                        elif cond_head_found and not criteria_check(head_check_text,language) and cond_second_category and ((font_size,font_family,bold,upper,bullet)==cond_header_match_object or font_size > cond_header_match_object[0] ) :
                            cond_head_found=False
                            cond_second_category=False
                            cond_single_page_head_found=True
#                             print('FOUND closure type 2',span.text)

                    if cond_head_found==True:
                        condition_text=condition_text+' '+span.text
                            
                    
                    #####EXTENSIONS
                    #CONDITIONS
#                     if 'Extension' in span.text:
#                         print(span.text)
#                         print('text:',str(span.text),'head check',head_check_text,'length of head check',len(head_check_text))
#                         print(span_position==0,(bold or font_size>= file_font_size_mode +2 ), (font_size> file_font_size_mode or upper), 5<len(head_check_text.strip())<80)
#                         print(font_size,file_font_size_mode,cond_head_found,criteria_check(head_check_text,language))
                    if  span_position==0 and (bold or font_size>= file_font_size_mode +2 ) and (font_size> file_font_size_mode or upper) and 5<len(head_check_text.strip())<80:                    
                        if ext_check(head_check_text,language) and not ext_head_found: 
                            ext_head_found=True
                            ext_header_match_object=(font_size,font_family,bold,upper,bullet)
                            ext_First_category=True
                            ext_second_category=False
                            ext_single_page_head_found=True
#                             print('FOUND Heading for ext...',span.text)
                    
                        elif ((font_size,font_family,bold,upper,bullet)==ext_header_match_object or font_size>ext_header_match_object[0] ) and not ext_check(head_check_text,language)  and ext_head_found:
                            ext_head_found=False
                            ext_single_page_head_found=True
#                             print('FOUND Closure for ext ...',span.text)
                
                    
                    ext_words_title=[word.istitle() for word in head_check_text.split() if stopword_check(word,head_check_text,language) and not word.isdigit() ]
                    if span_position==0 and all(ext_words_title) and head_check_text.strip() not in definitions and  (len(words_title) >1 or underlined_text )and 5<len(head_check_text.strip())<80 :
#                         print('MMMMMMMMARARARA',span.text)

                        if ext_check(head_check_text,language) and  not ext_head_found:
                            ext_head_found=True
                            ext_second_category=True
                            ext_First_category=False
                            ext_single_page_head_found=True
                            ext_header_match_object=(font_size,font_family,bold,upper,bullet)
#                             print("FOUND heading type2 ext....",span.text)
                        elif ext_head_found and not ext_check(head_check_text,language) and ext_second_category and ((font_size,font_family,bold,upper,bullet)==ext_header_match_object or font_size > ext_header_match_object[0] ) :
                            ext_head_found=False
                            ext_second_category=False
                            ext_single_page_head_found=True
#                             print('FOUND closure type 2 ext',span.text)
# 
                    if ext_head_found==True:
                        ext_text=ext_text+' '+span.text
                            
    #                     else:
###############################             
                        
                    if font_size_match:
                        if font_size<=file_font_size_mode-1:
                            text_lis.append(' ')
                    text=span.text.replace('\n',' ')
                    text_plain=text.replace('\n',' ')
                    for term in def_terms:
                        if term.lower().strip() in text.lower() and definitions[term][0].strip() not in text and term not in sub_definitions_in_page:
#                             def_page.append(definitions[term])
#                             print(pagenum)
                            src_str  = re.compile(re.escape(term), re.IGNORECASE)
                            text=src_str.sub('###{}@@{}%%%'.format(term,definitions[term][0]),text)
#                             print(text,'\n',term,'TERM!!!!@#$%^&*&^%#$%^&')
                            sub_definitions_in_page.append(term)
                            sub_page_def_list.append({'name':term,'text':definitions[term][0]})
#                             print(definitions_in_page)
                            break
#                     print(definitions_in_page)

                    
                    text_lis.append(text)
                    text_plain_lis.append(text_plain)
                    previous_span=span
                    

            if text_lis:
                if(int(pagenum) in [1,2]) and 'Wording' in file and pg_no >20:
#                     print('Continued on wording 2')
                    continue

                text_lis=text_lis[:-1]
                text_para=''.join(text_lis)
                text_plain_lis=text_plain_lis[:-1]
                text_plain_para=''.join(text_plain_lis)
                if(len(re.findall('\.',text_para))>(len(text_para)/3) or (len(re.findall('\d',text_para))>80 and int(pagenum)<4 and pg_no>20 and 'content' in text_para.lower())) :
                    print('PASS')
                    print(text_plain_para)
                    text_para,text_plain_para=' ',' '
                    text_lis,text_plain_lis=[],[]
                    single_page_head_found=False
                    head_found=False
                    cond_head_found=False
                    ext_head_found=False
                    continue
                else:
                    bold_lis=clean_pharses(bold_lis)
                    if pagenum in page_list and pagenum!='1':
                        pagenum=int(pagenum)+1
                    excl_flag,excl_count,excl_pos_lis=excl_extract(text_plain_lis,language)
                    cond_flag,cond_count,cond_pos_lis=cond_extract(text_plain_lis,language)
                    ext_flag,ext_count,ext_pos_lis=ext_extract(text_plain_lis,language)
                    if int(pagenum)==1:
                        if head_found or single_page_head_found or excl_count>0:
#                             print(pagenum,True,'!!!',excl_count)
                            excl_flag=True
                        else:
                            excl_flag=False
                    else:
                        if head_found or single_page_head_found:
#                             print(pagenum,True,'!!!')
                            excl_flag=True
#                             print(excl_flag,'EXCL')
                        
                    #####################
                    if cond_head_found or cond_single_page_head_found or cond_count>0:
                        cond_flag=True
#                         print('COND','TRUE')
                    else:
                        cond_flag=False
                    
                    if ext_head_found or ext_single_page_head_found or ext_count>0:
                        ext_flag=True
#                         print('EXT','TRUE',pagenum)
                    else:
#                         print('EXT','FALSE',pagenum)
                        ext_flag=False
#                         print('COND','FALSE')
#                     page_def_list.append({'name':term,'text':definitions[term][0]}
#                     def_in_page=[{'name':k,'text':v[0]} for k,v in definitions.items() if v[1]==pagenum]  
#                     print(def_in_page,'!!!!!!!!!!!!!!!!!!!!!!!!!!!!!')
                    for term,defs in definitions.items():
                        if defs[1]==pagenum:  ###defs[1] is the pagenumber
                            definition_text=definition_text+'          '+term+' '+defs[0]
                            def_in_page.append({'name':term,'text':defs[0]})        
#                     print(definition_text)
                    if definition_text:
                        def_flag=True

                    if def_flag:
                        def_search_flag=True
#                         print('DEF','TRUE')
                    else:
                        def_search_flag=False
#                         print('DEF','FALSE')
                    
                    if pg_no>2:
                        endorsements=False
                    else:
                        endorsements=True
#                     print(endorsements,'ENDORSEMENTS!!!')        
                    if text_para in local_indexed.keys():
                        text_para=text_para+' '
                    local_indexed[text_para]=(file,pagenum,bold_lis,text_plain_para,excl_flag,excl_count,excl_pos_lis,subdir,sub_page_def_list,country,language,definition_text,def_search_flag,endorsements,excl_text,condition_text,cond_flag,cond_count,cond_pos_lis,def_in_page,ext_text,ext_flag,ext_count,ext_pos_lis)
#                     print(sub_page_def_list,'DEF LIST!!!!!1')
                    sub_page_def_list=[]
                    text_para,text_plain_para='','' 
                    text_plain_lis,text_lis,bold_lis=[],[],[]
                    definition_text=''
                    single_page_head_found=False
                    cond_single_page_head_found=False
                    ext_single_page_head_found=False
                    condition_text=''
                    ext_text=''
                    excl_text=''
                    def_in_page=[]
                    def_flag=False
    return(local_indexed)

# %%
def doc_pdf_path(path):
    file_list=os.listdir(path)
    for file in file_list:
        raw_filename=file[:file.rfind(".")]
        pdf_filename=raw_filename+'.pdf'
#         print(raw_filename,pdf_filename,'FILE!!')
        if pdf_filename in file_list:
            print('continued!!!!!!!!!!!!!')
            continue
        if file.endswith('doc') or file.endswith('docx'):
            print('processing!!!')
            wordToPdf(os.path.join(path,file))

# %%
# rootDir='V://COG//AU- Property//'
# for dirname,subdirlist,filelist in os.walk(rootDir):
#     print(dirname)
#     for subdir in subdirlist:
#         path=os.path.join(dirname,subdir)
# #         doc_pdf_path(path)

# %%
# import os
file_count=0
rootDir='Documents/NZ-Casualty/'
country='new zealand'
local_indexed={}
language='english'
if 'spanish' in rootDir:
    language='spanish'
for dirname,subdirlist,filelist in os.walk(rootDir):
    for subdir in subdirlist:
        print(subdir, 'SUBDIR!!!!!!!!!!!!!')
        path=os.path.join(dirname,subdir)    
        local_indexed_subdir=create_local_index(path,subdir,language,country)
        local_indexed.update(local_indexed_subdir)
# Out:
# Bespoke wording SUBDIR!!!!!!!!!!!!!
# Other Carrier Wording SUBDIR!!!!!!!!!!!!!
# Chubb Standard Wording SUBDIR!!!!!!!!!!!!!
# Professional Negligence – Absolute Exclusion.pdf
# COUNT 1
# Section 1 - Self-Insured Retention.pdf
# COUNT 2
# Change of Business (SC_CLP_NZ2-26-0616_CB.1).pdf
# COUNT 3
# Section 1 - Molestation Exclusion.pdf
# COUNT 4
# Innkeepers Liability Extension.pdf
# COUNT 5
# Section 1 - AIDS and HIV Exclusion.pdf
# COUNT 6
# Efficacy Endorsement.pdf
# COUNT 7
# Valet Car Parking Extension.pdf
# COUNT 8
# Contractual Liability – Umbrella Endorsement (SC_UMLNZ_092016.CL.1).pdf
# COUNT 9
# USA and Canada Activities Extension for Local Operations.pdf
# COUNT 10
# Section 1 - Carriers Liability Extension (SC_WCLNZ02_120_0318_CLE.1).pdf
# COUNT 11
# Vibration and Removal of Support (Amended Sub Limit) (SC_CLP_NZ2-26-0616_VRS-ASL.1).pdf
# COUNT 12
# Professional Liability Exclusion (Except First Aid).pdf
# COUNT 13
# Communicable Disease Exclusion - Scheduled Activities (SC_CLP_NZ2-26-0616_CDESA.1).pdf
# COUNT 14
# Underground Services (Amended Sub Limit) (SC_CLP_NZ2-26-0616_US-ASL.1).pdf
# COUNT 15
# Australian Contractors Exclusion.pdf
# COUNT 16
# AIDS and HIV Exclusion (SC_CLP_NZ2-26-0616_AHE.1).pdf
# COUNT 17
# Construction Work and Building Activities Exclusion (SC_GGMNL_NZ2-39-0516.CWBAE.1).pdf
# COUNT 18
# Section 1 - Care Custody and Control - Amended Sub Limit.pdf
# COUNT 19
# Section 1 - USA and Canada Exclusion.pdf
# COUNT 20
# Latex Exclusion.pdf
# COUNT 21
# Care Custody Control Exclusion - Umbrella Endorsement (SC_UMLNZ_092016.CCCE.1).pdf
# COUNT 22
# Section 1 - Valet Car Parking Extension.pdf
# COUNT 23
# Electrical and Electromagnetic Field (EFL and EMF) Exclusion (SC_CLP_NZ2-26-0616_EFLEMFE.1).pdf
# COUNT 24
# Innkeepers Liability Extension (SC_CLP_NZ2-26-0616_IKLE.1).pdf
# COUNT 25
# Securities Extension (Statutory Liability) (SC_CLP_NZ2-26-0616_SESL.1).pdf
# COUNT 26
# Energy Exclusions.pdf
# COUNT 27
# Electrical & Electromagnetic Field (EFL & EMF) Exclusion.pdf
# COUNT 28
# Section 1 - Drones Endorsement.pdf
# COUNT 29
# Service and Repair – Amended Sub Limit.pdf
# COUNT 30
# Genetically Modified Organism (GMO) Exclusion.pdf
# COUNT 31
# Blasting Operations Exclusion.pdf
# COUNT 32
# Section 1 - Professional Negligence – Absolute Exclusion.pdf
# COUNT 33
# Self-Insured Retention (SC_CLP_NZ2-26-0616_SIR.1).pdf
# COUNT 34
# Liability Consequential Loss Endorsement.pdf
# COUNT 35
# Pipes, cables, structures and underground services (occurrence) (SC_CLP_NZ2-26-0616_PCSUS.1).pdf
# COUNT 36
# Carriers Liability Extension.pdf
# COUNT 37
# Section 1 - Cellular Phone Radiation Exclusion.pdf
# COUNT 38
# Professional Negligence - Absolute Exclusion (SC_GGMNL_NZ2-39-0516.PN-AE.1).pdf
# COUNT 39
# Named Insured Endorsement (Statutory Liability) (SC_CLP_NZ2-26-0616_NIESL.1).pdf
# COUNT 40
# E-Cigarettes Exclusion.pdf
# COUNT 41
# New Zealand Jurisdiction Endorsement.pdf
# COUNT 42
# Recruitment Consultant Endorsement.pdf
# COUNT 43
# Blasting Operations Exclusion (SC_CLP_NZ2-26-0616_BOE.1).pdf
# COUNT 44
# Section 1 - Service and Repair – Amended Sub Limit.pdf
# COUNT 45
# Goods on Hook Extension (SC_CLP_NZ2-26-0616_GOHE.1).pdf
# COUNT 46
# Statutory Liability Policy Endorsement Securities Extension (for wordings where Section 3 are the Exclusions).pdf
# COUNT 47
# Batch Endorsement.pdf
# COUNT 48
# Service and Repair Amended Sub Limit.pdf
# COUNT 49
# Pharmaceuticals Exclusion (SC_CLP_NZ2-26-0616_PE.1).pdf
# COUNT 50
# Supply Service Repair Excl (Computer Hardware Software Electronic Equipment) (SC_CLP_NZ2-26-0616_SSRE.1).pdf
# COUNT 51
# Contractual Liability Specified Contracts.pdf
# COUNT 52
# Copper Chromium Arsenic (CCA) Exclusion.pdf
# COUNT 53
# Supply, Service and Repair Exclusion Computer Hardware, Software and Electronic Equipment.pdf
# COUNT 54
# Products Recall Expenses Endorsement – Extended Coverage (SC_GGMNL_NZ2-39-0516.PREE-EC.1).pdf
# COUNT 55
# Latex Exclusion (SC_CLP_NZ2-26-0616_LTXE.1).pdf
# COUNT 56
# Difference in Limit Endorsement Draft.pdf
# COUNT 57
# Silica Exclusion (SC_CLP_NZ2-26-0616_SE.1).pdf
# COUNT 58
# Difference in Conditions Endorsement (SC_GGMNL_NZ2-39-0516.DIC.1).pdf
# COUNT 59
# Section 3 - Employers Liability - Separate Limits for Damages, Defence Costs.pdf
# COUNT 60
# Pharmaceuticals Exclusion.pdf
# COUNT 61
# Goods on Hook Extension.pdf
# COUNT 62
# Section 1 - Absolute Watercraft Exclusion.pdf
# COUNT 63
# Valet Car Parking Extension with Sublimit and Deductible.pdf
# COUNT 64
# Statutory Liability Policy Endorsement Securities Extension (for wordings where Section 4 are the Exclusions).pdf
# COUNT 65
# Diving Endorsement.pdf
# COUNT 66
# Section 1 - Construction Work and Building Activities Exclusion.pdf
# COUNT 67
# 02. Additional Insured Primary and NonContributory Insurance (SC_GGMNL_NZ2-39-0516.02AddInsd.1).pdf
# COUNT 68
# Polychlorinated Biphenyls (PCB’s) Exclusion.pdf
# COUNT 69
# Absolute Pollution Exclusion.pdf
# COUNT 70
# Chubb Excess Liability Quote.pdf
# COUNT 71
# Drones Endorsement.pdf
# COUNT 72
# Electrical and Electromagnetic Field (EFL and EMF) Exclusion.pdf
# COUNT 73
# Section 1 - Absolute Navigation Exclusion.pdf
# COUNT 74
# Animal Diseases Exclusion.pdf
# COUNT 75
# Manufacturers Professional Indemnity (SC_CLP_NZ2-26-0616_MPI.1).pdf
# COUNT 76
# Section 1 - Lost Master Keys Extension.pdf
# COUNT 77
# Absolute Watercraft Exclusion (SC_CLP_NZ2-26-0616_AWE.1).pdf
# COUNT 78
# Lost Master Keys Extension.pdf
# COUNT 79
# Section 1 - Batch Endorsement.pdf
# COUNT 80
# Section 1 - Care Custody Control Exclusion – Grape and Wine Products Only.pdf
# COUNT 81
# Products Recall Expenses Endorsement (Extended Coverage) (SC_CLP - Copy.pdf
# COUNT 82
# Change of Business.pdf
# COUNT 83
# Section 3 - Employers Liability Separate Limits for Damages and Defence Costs.pdf
# COUNT 84
# Section 1 - Wine Bottling Extension.pdf
# COUNT 85
# Care Custody and Control Exclusion.pdf
# COUNT 86
# NZ Exemplary Damages Amended Sub Limit.pdf
# COUNT 87
# Diving Endorsement.2.pdf
# COUNT 88
# Difference in Conditions Endorsement.pdf
# COUNT 89
# Chubb(NZ)2.26.0616 Combined Liability Policy Wording v3 (16.1.17)  - Portal Version.pdf
# COUNT 90
# PASS
# Contents  Contents ......................................................................................................1  Section One: Public and Products Liability Policy.............................................1  Section Two: Statutory Liability Policy .......................................................... 17  1.  Insuring Agreement  2. Automatic Coverage Extensions  3. Definitions  4. Exclusions  5. General Conditions  1.  Insuring Agreement  2. Automatic Coverage Extensions  3. Definitions  4. Exclusions  5. Conditions  1.  Insuring Agreement  2. Definitions  3. Exclusions  4. Conditions  Section Three: Employers Liability Policy......................................................25  1  2  7  10  13  17  17  18  20  22  25  25  27  28        Chubb  Combined  Liability Policy Wording, New Zealand.  Published 01/2017.  © 2017 Chubb.  Coverages underwritten  by one or more subsidiary companies.  Not all coverages available in all jurisdictions. Chubb ®,  its   respective  logos, and Chubb.Insured.℠  are protected  trademarks of Chubb.          Section One: Public and Products Liability Policy  1.   Insuring Agreement  In consideration of the premium being paid by the Insured to Chubb Insurance New Zealand Limited  (hereinafter called 'Chubb') and in reliance upon the written proposal agreement and declaration which shall  be deemed to be the basis of this Policy, Chubb  agrees to indemnify the Insured as follows:  1.1  Public and Products Liability Coverage  Subject to the terms, conditions, limitations and exclusions of this Policy all sums which the Insured  shall be legally liable to pay as Compensation on account of:  a)  b)  Personal Injury; or  Property Damage,  1.2  Limit of Liability  1.3  Supplementary Payments  occurring within the Policy Territory during the Policy Period as a result of an Occurrence  happening in connection with the Business of the Insured.  Chubb's liability under this Policy shall not exceed the Limit of Liability stipulated in Item 6 of the  Schedule.  In addition to the Limit of Liability stipulated in Item 6 of the Schedule, Chubb  will pay:  a)  b)  c)  all reasonable charges, expenses and legal costs incurred by either Chubb or the Insured  with the written consent of Chubb in the settlement or defence of any claim for  Compensation in respect of which the Insured is entitled to indemnity under this Policy;   all charges, expenses and legal costs recoverable from the Insured by claimants in  connection with such Compensation;   in the event of a claim being made against the Insured in any court or before any other  legally constituted body in the United States of America, Canada or their respective  protectorates and territories, the total amount payable in respect of the claim by Chubb  under this Policy including all charges, legal costs and expenses will not exceed the Limit of  Liability stipulated in Item 6 of the Schedule.  provided that Chubb's liability to pay either or both of these types of charges, expenses or legal costs  shall cease upon the Limit of Liability stipulated in Item 6 of the Schedule having been exhausted by  payment of judgments or settlements.  1.4   Deductible  The Deductible is the amount stipulated in Item 8 of the Schedule payable by the Insured. The  Deductible applies to each Occurrence and is payable by the Insured at such time required by  Chubb. Chubb’s liability to indemnify the Insured under this Policy is over and above the  Deductible.  Chubb  Combined  Liability Policy Wording, New Zealand.  Published 01/2017.  © 2017 Chubb.  Coverages underwritten  by one or more subsidiary companies.  Not all coverages available in all jurisdictions. Chubb ®,  its   respective  logos, and Chubb.Insured.℠  are protected  trademarks of Chubb.
# Aviation Products Exclusion.pdf
# COUNT 91
# Manufacturers Professional Indemnity (Inadequate Manufacture) (SC_CLP_NZ2-26-0616_MPI-IM.1).pdf
# COUNT 92
# Winemakers Processing Risk- revised.pdf
# COUNT 93
# Animal Diseases Exclusion (SC_CLP_NZ2-26-0616_ADE.1).pdf
# COUNT 94
# Cellular Phone Radiation Exclusion.pdf
# COUNT 95
# Product Recall Expenses Amended Sub Limit.pdf
# COUNT 96
# Rip and Tear Exclusion.pdf
# COUNT 97
# Statutory Liability Policy Endorsement Separate Limits for Damages and Defence Costs - Standalone version (Aon version).pdf
# COUNT 98
# Named Insured Endorsement Statutory Liability.pdf
# COUNT 99
# Section 1 - Carriers Liability Extension.pdf
# COUNT 100
# Section 1 - NZ Exemplary Damages – (Amended Sub Limit.pdf
# COUNT 101
# Manufacturers Professional Indemnity (Global Guard) (SC_GGMNL_NZ2-39-0516.MPI.1).pdf
# COUNT 102
# Employers liability Policy Endorsement Marsh Agreed Employers Extensions (SC_CLP_NZ2-26-0616_ELPEMAEE.1).pdf
# COUNT 103
# Section 1 - Winemakers Processing Risk.pdf
# COUNT 104
# Care Custody and Control - Amended Sub Limit.pdf
# COUNT 105
# Watercraft – Absolute Exclusion.pdf
# COUNT 106
# Product Recall Expenses Absolute Exclusion.pdf
# COUNT 107
# Section 1 - Absolute Failure to Supply Exclusion.pdf
# COUNT 108
# Defective Workmanship Endorsement PPL Wording.pdf
# COUNT 109
# Difference in Conditions and Difference in Limit Endorsement.pdf
# COUNT 110
# Advertising Injury Exclusion.pdf
# COUNT 111
# Section 1 - Difference in Conditions and Difference in Limit Endorsement.pdf
# COUNT 112
# Difference in Limits and USA Endorsement DC Equipment.pdf
# COUNT 113
# Communicable Disease Exclusion - Scheduled Activities (SC_EXLNZ_092016_CDESA.1).pdf
# COUNT 114
# Absolute Failure to Supply Exclusion (SC_CLP_NZ2-26-0616_AFSE.1).pdf
# COUNT 115
# Vibration and Removal of Support Amended Sub Limit.pdf
# COUNT 116
# Additional Excluded Acts.pdf
# COUNT 117
# Efficacy Endorsement (SC_CLP_NZ2-26-0616_EFFE.1).pdf
# COUNT 118
# Grape Harvesting Endorsement.pdf
# COUNT 119
# Care Custody and Control Amended Sub Limit.pdf
# COUNT 120
# Excess Motor Liability – Amended Attachment Point (SC_GGMNL_NZ2-39-0516.EML-AAP.1).pdf
# COUNT 121
# Genetically Modified Organism (GMO) Defence Costs.pdf
# COUNT 122
# Warrant of Fitness Extension Endorsement.pdf
# COUNT 123
# Section 2 - Named Insured Endorsement (SC_WCLNZ02_120_0318_NIE2.1).pdf
# COUNT 124
# Section 1 - Product Recall Expenses – Absolute Exclusion.pdf
# COUNT 125
# Care Custody and Control Exclusion (SC_CLP_NZ2-26-0616_CCCE.1).pdf
# COUNT 126
# Transmissible Spongiform Encephalopathies (TSE) Exclusion (SC_CLP_NZ2-26-0616_TSE.1).pdf
# COUNT 127
# Transmissible Spongiform Encephalopathies (TSE) Exclusion.pdf
# COUNT 128
# Pipes, Cables, Structures and Underground Services (Occurrence).pdf
# COUNT 129
# Self-Insured Retention (in respect of contractors in Australia) (SC_GGMNL_NZ2-39-0516.SIR-CA.1).pdf
# COUNT 130
# Absolute Watercraft Exclusion.pdf
# COUNT 131
# Genetically Modified Organism (GMO) Defence Costs (SC_CLP_NZ2-26-0616_GMODC.1).pdf
# COUNT 132
# Product Recall Expenses (Amended Sub Limit) (SC_CLP_NZ2-26-0616_ - Copy.pdf
# COUNT 133
# NZ Statutory Liability Policy.pdf
# COUNT 134
# PASS
#   Contents  Contents ..................................................................................................... 2  Important Notices........................................................................................ 3  Policy Schedule............................................................................................ 5  Endorsements ............................................................................................. 6  Statutory Liability Policy .............................................................................. 7  Privacy Statement ....................................................................................... 14  About Chubb in New Zealand ....................................................................... 15  Contact Us ................................................................................................. 15    Chubb  Statutory Liability Policy, New Zealand.  Published 05/2016.  Chubb®,  its logos, and Chubb.Insured.SM  are protected  trademarks of Chubb.
# USA and Canada Activities Extension Installation by NZ Resident Employees.pdf
# COUNT 135
# Defective Workmanship Endorsement Comprehensive.pdf
# COUNT 136
# Iran Exclusion Territory Jurisdiction.pdf
# COUNT 137
# Defective Workmanship Endorsement.pdf
# COUNT 138
# Change of Policy Period DRAFT.pdf
# COUNT 139
# Aircraft and Related Activities Exclusion.pdf
# COUNT 140
# Lost Master Keys Extension (SC_CLP_NZ2-26-0616_LMKE.1).pdf
# COUNT 141
# Section 1 - Care Custody and Control Exclusion.pdf
# COUNT 142
# Personal Liability of Seconded Staff Sublimit.pdf
# COUNT 143
# Joint Venture Operations (SC_CLP_NZ2-26-0616_JVO.1).pdf
# COUNT 144
# Section 1 - Policy Territory and Overseas Visits Endorsement.pdf
# COUNT 145
# Absolute Watercraft Exlcusion.pdf
# COUNT 146
# Foreign Entity Loss Endorsement (SC_CLP_NZ2-26-0616_FELE.1).pdf
# COUNT 147
# Australian Contractors Exclusion (SC_CLP_NZ2-26-0616_ACE.1).pdf
# COUNT 148
# Chubb Umbrella Liability Binder.pdf
# COUNT 149
# Construction Work and Building Activities Exclusion.pdf
# COUNT 150
# USA and Canada Exclusion (SC_CLP_NZ2-26-0616_USACE.1).pdf
# COUNT 151
# Personal Liability of Seconded Staff - Sublimit (SC_GGMNL_NZ2-39-0516.PLSS.1).pdf
# COUNT 152
# Separate Insured Endorsement.pdf
# COUNT 153
# Canada Activities Extension Product Exposure But No Employees.pdf
# COUNT 154
# Communicable Disease Exclusion EL (SC_CLP_NZ2-26-0616_CDEEL.1).pdf
# COUNT 155
# Product Recall Expenses Absolute Exclusion (SC_CLP_NZ2-26-0616_PREAE.1).pdf
# COUNT 156
# Energy Exclusions (SC_CLP_NZ2-26-0616_EE.1).pdf
# COUNT 157
# Chubb Combined Liability Binder.pdf
# COUNT 158
# Section 1 - Blasting Operations Exclusion.pdf
# COUNT 159
# Automobile Endorsement.pdf
# COUNT 160
# Construction Work and Building Activities Exclusion (SC_CLP_NZ2-26-0616_CWBAE.1).pdf
# COUNT 161
# Silica Exclusion (SC_GGMNL_NZ2-39-0516.SE.1).pdf
# COUNT 162
# Section 1 - Property in the Insured's Care Custody and Control - Amended Sub Limit.pdf
# COUNT 163
# Property Developers Limitation (SC_CLP_NZ2-26-0616_PDL.1).pdf
# COUNT 164
# Aircraft and Related Activities Exclusion (SC_CLP_NZ2-26-0616_ARAE.1).pdf
# COUNT 165
# Data and Cyber Exclusion.pdf
# COUNT 166
# Section 1 - Named Insured Endorsement.pdf
# COUNT 167
# Difference in Conditions and Difference in Limit Endorsement NDA.pdf
# COUNT 168
# Lead Exclusion.pdf
# COUNT 169
# Enforceable Undertaking Extension.pdf
# COUNT 170
# AIDS and HIV Exclusion.pdf
# COUNT 171
# Carriers Liability Extension (SC_CLP_NZ2-26-0616_CLE.1).pdf
# COUNT 172
# Wine Bottling Extension (SC_CLP_NZ2-26-0616_WBE.1).pdf
# COUNT 173
# Rip and Tear Exclusion (SC_CLP_NZ2-26-0616_RTE.1).pdf
# COUNT 174
# Property Developers Limitation.pdf
# COUNT 175
# Section 1 - NZ Policy Territory Jurisdiction.pdf
# COUNT 176
# Section 1 - Separate Insured Endorsemen.pdf
# COUNT 177
# Section 1 - Professional Liability Exclusion (Except First Aid).pdf
# COUNT 178
# Excess Motor Liability Amended Attachment Point.pdf
# COUNT 179
# Expona Endorsement.pdf
# COUNT 180
# Section 1 - Aviation Products Exclusion.pdf
# COUNT 181
# Section 1 - Absolute Pollution Exclusion.pdf
# COUNT 182
# Section 1 - Total Design, Specification, Formula Exclusion.pdf
# COUNT 183
# Product Recall Expenses Absolute Exclusion (SC_CLP_NZ2-26-0616_P - Copy.pdf
# COUNT 184
# Joint Venture Operations.pdf
# COUNT 185
# Marsh Agreed Statutory Extensions updated Feb 2018.pdf
# COUNT 186
# Watercraft - Limitation (SC_CLP_NZ2-26-0616_WCL.1).pdf
# COUNT 187
# Electrical and Electromagnetic Field Extension (SC_CLP_NZ2-26-0616_EEFE.1).pdf
# COUNT 188
# Volunteers Extension.pdf
# COUNT 189
# Employers Liability Policy Endorsement Separate Limits for Damages and Defence Costs (SC_CLP_NZ2-26-0616_ELPESLDDC.1).pdf
# COUNT 190
# Wineries Combined Liability Liability Consequential Loss Endorsement.pdf
# COUNT 191
# Care Custody and Control Amended Sub Limit (SC_GGMNL_NZ2-39-0516.CCCAmdSL.1).pdf
# COUNT 192
# Section 1 - Joint Venture Operations.pdf
# COUNT 193
# USA Canada Exclusion (covers visits) (SC_GGMNL_NZ2-39-0516.USACANExl.1).pdf
# COUNT 194
# Property Worked Upon Writeback Endorsement.pdf
# COUNT 195
# Section 1 - Advertising Injury Exclusion.pdf
# COUNT 196
# Section 1 - NZ Exemplary Damages – Amended Sub Limit.pdf
# COUNT 197
# Forest and Rural Fires Act 1977 (Amended Sub Limit) (SC_CLP_NZ2-26-0616_FRFA.1).pdf
# COUNT 198
# Australian Contractors Exclusion (SC_GGMNL_NZ2-39-0516.ACE.1).pdf
# COUNT 199
# Policy Territory and Overseas Visits Endorsement (SC_CLP_NZ2-26-0616_PTOVE.1).pdf
# COUNT 200
# Section 1 - Efficacy Endorsement.pdf
# COUNT 201
# Amended Marsh Fiji Molestation Exclusion.pdf
# COUNT 202
# Section 1 - Polychlorinated Biphenyls (PCB’s) Exclusion.pdf
# COUNT 203
# EL Policy Endorsement for Separate Limits for Damages and Defence Costs (SC_CLP_NZ2-26-0616_ELPESLD.1).pdf
# COUNT 204
# Automobile Endorsement (SC_CLP_NZ2-26-0616_AE.1).pdf
# COUNT 205
# Molestation Exclusion.pdf
# COUNT 206
# Care Custody and Control - Amended Sub Limit (SC_CLP_NZ2-26-0616_CCC-ASL.1).pdf
# COUNT 207
# Defective Workmanship Endorsement (Damage while working on, and damage to Insureds Products) (SC_GGMNL_NZ2-39-0516.DWEDWWODIP.1).pdf
# COUNT 208
# Statutory Liability Policy Endorsement Separate Limits for Damages and Defence Costs - Standalone version.pdf
# COUNT 209
# Offshore Exclusion (SC_CLP_NZ2-26-0616_OSE.1).pdf
# COUNT 210
# Products Recall Expenses Endorsement (Extended Coverage) (SC_CLP_NZ2-26-0616_PREE.1).pdf
# COUNT 211
# Section 1 - Transmissible Spongiform Encephalopathies (TSE) Exclusion.pdf
# COUNT 212
# SL Policy Endorsement for Separate Limits for Damages and Defence Costs (SC_CLP_NZ2-26-0616_PESLDDC.1).pdf
# COUNT 213
# Australia Consumer Protection Cover.pdf
# COUNT 214
# Named Insured Endorsement (Public Liability) (SC_CLP_NZ2-26-0616_NIEPL.1).pdf
# COUNT 215
# OFAC Sanctions Clause.pdf
# COUNT 216
# Polychlorinated Biphenyls (PCBs) Exclusion.pdf
# COUNT 217
# Section 1 - Australian Contractors Exclusion.pdf
# COUNT 218
# Self-Insured Retention (SC_GGMNL_NZ2-39-0516.SIR.1).pdf
# COUNT 219
# Contractors and Subcontractors Endorsement (Extension) (SC_GGMNL_NZ2-39-0516.CSCEndExt.1).pdf
# COUNT 220
# Electrical and Electromagnetic Field Extension.pdf
# COUNT 221
# Excess Motor Liability (Amended Attachment Point) (SC_CLP_NZ2-26-0616_EML.1).pdf
# COUNT 222
# Public and Products Liability Insurance.pdf
# COUNT 223
# PASS
#     Contents  Contents ..................................................................................................... 2  Important Notices........................................................................................ 3  Policy Schedule............................................................................................ 5  Endorsements ............................................................................................. 6  1.  2.   Insuring Agreements ........................................................................... 7  Automatic Coverage Extensions............................................................ 8  3.   Definitions ........................................................................................ 14  4.   Exclusions ......................................................................................... 17  5.   General Conditions............................................................................. 21  Privacy Statement .......................................................................................24  About Chubb in New Zealand .......................................................................25  Contact Us .................................................................................................25  Chubb  Public and Products Liability Insurance  Policy, New Zealand.  Published  05/2016.  Chubb®,  its logos, and Chubb.Insured.SM  are protected  trademarks of Chubb.
# E-Cigarette Products Endorsement (SC_GGMNL_NZ2-39-0516.ECigsPrdEnd.1).pdf
# COUNT 224
# Section 1 - Goods on Hook Extension.pdf
# COUNT 225
# Chubb Combined Liability Quote Template.pdf
# COUNT 226
# Section 1 - Electrical and Electromagnetic Field (EFL and EMF) Exclusion.pdf
# COUNT 227
# Named Insured Endorsement (SC_GGMNL_NZ2-39-0516.NIE.1).pdf
# COUNT 228
# Polychlorinated Biphenyls (PCBs) Exclusion (SC_CLP_NZ2-26-0616_PCBE.1).pdf
# COUNT 229
# Efficacy Endorsement (SC_GGMNL_NZ2-39-0516.EE.1).pdf
# COUNT 230
# USA and Canada Product Runoff Endorsement.pdf
# COUNT 231
# Increased Limits Extension (SC_CLP_NZ2-26-0616_ILE.1).pdf
# COUNT 232
# Section 1 -  Liability Consequential Loss Endorsement.pdf
# COUNT 233
# Player vs Player Exclusion.pdf
# COUNT 234
# Manufacturers Professional Indemnity.pdf
# COUNT 235
# NZ Exemplary Damages (Amended Sub Limit) (SC_CLP_NZ2-26-0616_NZED.1).pdf
# COUNT 236
# Care Custody Control Exclusion for Grape and Wine Products (Wineries Only) (SC_CLP_NZ2-26-0616_CCCE-GWP.1).pdf
# COUNT 237
# Section 1 - Contract Vineyard Spraying Endorsement.pdf
# COUNT 238
# Section 1 - Separate Insured Endorsement.pdf
# COUNT 239
# Section 2 - Statutory Liability – Securities Extension.pdf
# COUNT 240
# Batch Endorsement (SC_CLP_NZ2-26-0616_BE.1).pdf
# COUNT 241
# Increased Limits Extension.pdf
# COUNT 242
# Underground Services Amended Sub Limit.pdf
# COUNT 243
# Section 1 - Vibration and Removal of Support – Amended Sub Limit.pdf
# COUNT 244
# Professional Negligence Absolute Exclusion (SC_EXLNZ_092016.PrfNegAbsExcl.1).pdf
# COUNT 245
# Section 1 - Silica Exclusion.pdf
# COUNT 246
# Professional Negligence (Absolute Exclusion) (SC_CLP_NZ2-26-0616_PNAE.1).pdf
# COUNT 247
# Professional Negligence Absolute Exclusion.pdf
# COUNT 248
# Service and Repair (Amended Sub Limit) (SC_CLP_NZ2-26-0616_SR-ASL.1).pdf
# COUNT 249
# Section 2 - Named Insured Endorsement.pdf
# COUNT 250
# Products Recall Expenses Endorsement Extended Coverage.pdf
# COUNT 251
# Professional Liability Exclusion (Except First Aid) (SC_CLP_NZ2-26-0616_PLE.1).pdf
# COUNT 252
# Total Design, Specification, Formula Exclusion.pdf
# COUNT 253
# Valet Car Parking Extension (SC_CLP_NZ2-26-0616_VCPE.1).pdf
# COUNT 254
# Mobile Phone Exclusion (SC_GGMNL_NZ2-39-0516.MPE.1).pdf
# COUNT 255
# Foreign Entity Loss Endorsement.pdf
# COUNT 256
# Excess Liability Policy Wording.pdf
# COUNT 257
# PASS
#     Contents  Chubb Excess Liability Insurance Policy Wording ............................................1  Limits of Liability .................................................................................1  1.  Definitions ......................................................................................... 2  Exclusions .......................................................................................... 3  Conditions.......................................................................................... 5  About Chubb in New Zealand ........................................................................ 6  Contact Us .................................................................................................. 6  2.  3.  4.      Chubb  Excess Liability Insurance  Policy Wording ,  New Zealand.  Published 10/2020.  ©2020 Chubb  Insurance New Zealand  Limited.  Chubb®,  its logos, and  Chubb.Insured.SM  are protected  trademarks of Chubb.
# Self-Insured Retention.pdf
# COUNT 258
# USA and Canada Activities Extension.pdf
# COUNT 259
# Section 1 - Additional Insured Endorsement.pdf
# COUNT 260
# Absolute Pollution Exclusion (SC_CLP_NZ2-26-0616_APE.1).pdf
# COUNT 261
# Communicable Disease Exclusion Resorts.pdf
# COUNT 262
# Absolute Failure to Supply Exclusion.pdf
# COUNT 263
# Contract Vineyard Spraying Endorsement (Wineries only) (SC_CLP_NZ2-26-0616_CVSE.1).pdf
# COUNT 264
# Total Design, Specification, Formula Exclusion (SC_CLP_NZ2-26-0616_TDSFE.1).pdf
# COUNT 265
# Separate Insured Endorsement (SC_CLP_NZ2-26-0616_SIE.1).pdf
# COUNT 266
# Named Insured Endorsement.pdf
# COUNT 267
# Cellular Phone Radiation Exclusion (SC_CLP_NZ2-26-0616_CPRE.1).pdf
# COUNT 268
# Section 2 - Statutory Liability – Separate Limits for Damages and Defence Costs.pdf
# COUNT 269
# Additional Insured Endorsement.pdf
# COUNT 270
# Chubb(NZ)2-26-0616 Combined Liability Policy Wording v3 (16-1-17) - Final.pdf
# COUNT 271
# USA and Canada Activities Extension Product Exposure but no Employees.pdf
# COUNT 272
# Watercraft - Limitation.pdf
# COUNT 273
# Manufacturers Professional Indemnity Inadequate Manufacture.pdf
# COUNT 274
# Watercraft Limitation.pdf
# COUNT 275
# Contractors and Subcontractors Endorsement (Extension).pdf
# COUNT 276
# Molestation Exclusion (SC_CLP_NZ2-26-0616_ME.1).pdf
# COUNT 277
# Winemakers Processing Risk (SC_CLP_NZ2-26-0616_WMPR.1).pdf
# COUNT 278
# Communicable Disease Exclusion - Combined Liability (SC_EXLNZ_092016_CDECL.1).pdf
# COUNT 279
# Lead Exclusion (SC_CLP_NZ2-26-0616_LDE.1).pdf
# COUNT 280
# Service and Repair Exclusion.pdf
# COUNT 281
# Wine Bottling Extension.pdf
# COUNT 282
# Medical Malpractice and Professional Services Exclusion.pdf
# COUNT 283
# NZ Policy Territory Jurisdiction.pdf
# COUNT 284
# Property Worked Upon Endorsement.pdf
# COUNT 285
# USA and Canada Exclusion.pdf
# COUNT 286
# Global Guard Multinational Liability Policy Wording (Chubb_GGMNL_NZ2-39-0516).pdf
# COUNT 287
# PASS
#   Chubb Global Guard  Multinational Liability Insurance  Policy Wording    Name of Insured:   Period of Insurance (both dates inclusive)          Contents  Important Notices........................................................................................ 3  Policy Schedule............................................................................................ 5  Endorsements ............................................................................................. 6  1.  2.  3.  4.  5.  6.  Insuring Agreement ............................................................................ 7  Definitions ......................................................................................... 8  Exclusions ......................................................................................... 12  Extensions......................................................................................... 17  Conditions.........................................................................................23  Special Conditions..............................................................................27  Privacy Statement .......................................................................................32  About Chubb in New Zealand .......................................................................33  Contact Us .................................................................................................33    Chubb  Global Guard Multinational Liability Policy, New Zealand.  Published  05/2016.  Chubb®,  its logos, and Chubb.Insured.SM  are protected  trademarks of Chubb.
# Silica Exclusion.pdf
# COUNT 288
# Player vs Player Exclusion (SC_CLP_NZ2-26-0616_PPE.1).pdf
# COUNT 289
# Section 1 - Aircraft and Related Activities Exclusion.pdf
# COUNT 290
# Policy Territory and Overseas Visits Endorsement.pdf
# COUNT 291
# Difference in Conditions and Difference in Limit Endorsement (SC_CLP_NZ2-26-0616_DCDLE.1).pdf
# COUNT 292
# Section 1 - Animal Diseases Exclusion.pdf
# COUNT 293
# Communicable Disease Exclusion - Combined Liability (SC_CLP_NZ2-26-0616_CDECL.1).pdf
# COUNT 294
# Absolute Watercraft Exclusion with Silt Curtain Write Back.pdf
# COUNT 295
# Section 1 - Player vs Player Exclusion.pdf
# COUNT 296
# Defective Workmanship Endorsement PPL Wording (Includes Vehicles and Watercraft).pdf
# COUNT 297
# Section 1 - Pharmaceuticals Exclusion.pdf
# COUNT 298
# OFAC Sanctions Clause (SC_CLP_NZ2-26-0616_OFACSC.1).pdf
# COUNT 299
# Named Insured Endorsement (SC_CLP_NZ2-26-0616_NIE.1).pdf
# COUNT 300
# Product Recall Expenses (Amended Sub Limit) (SC_CLP_NZ2-26-0616_PREASL.1).pdf
# COUNT 301
# Industry Standard Wording SUBDIR!!!!!!!!!!!!!
# Broker wording SUBDIR!!!!!!!!!!!!!
# Section 2 - Statutory Liability – Separate Limits for Damages and Defence Costs (SC_MPSL -CLNZ1807_SLDDC.1).pdf
# COUNT 302
# Section 2 - Statutory Liability – Securities Extension (SC_MPSL -CLNZ1807_SLSE.1).pdf
# COUNT 303
# Section 3 - Employers Liability Separate Limits for Damages and Defence Costs (SC_MPSL -CLNZ1807_ELSLDDC.1).pdf
# COUNT 304
# Section 2 - Marsh Agreed Statutory Extensions (SC_MPSL -CLNZ1807_MASE.1).pdf
# COUNT 305
# Section 3 - Marsh Agreed Employers Liability Extensions (SC_MPSL -CLNZ1807_MAELE.1).pdf
# COUNT 306

# %%
len(local_indexed)
# Out:
# 541

# %%
from azure.cosmos import exceptions, CosmosClient, PartitionKey

cosmo_endpoint="https://nf-poc-cdb-sql.documents.azure.com"
cosmo_key="iEcEfrxYe0Fm9QtoxDrOpLvGsfzjowwybULlWT9Uz4XxV4RmOIAnRuLdgRFUu1LPU5Vwk3UGivRrPrxnk7083w=="
client = CosmosClient(cosmo_endpoint, cosmo_key)
database=client.get_database_client('policy-analysis')
container=database.get_container_client('casualty-wordings')

# %%
for key,value in local_indexed.items():
    doc={}
    doc['text']=key
    doc['page']=int(value[1])
    if value[4]==True or value[0].find('Exclusion')!=-1:
        doc['IsExclusion']=True
    else:
        doc['IsExclusion']=False
    doc['doc_name']=value[0].replace('.pdf','')
    doc['id']=doc['doc_name']+' '+str(doc['page'])
    doc['bold_phrases']=value[2]
    doc['plain_text']=value[3]
    doc['excl_count']=value[5]
    doc['excl_pos']=value[6]
    doc['folder']=value[7]
    doc['definitions']=[{'name':key,'text':value} for key,value in re.findall('###(.*?)@@(.*?)%%%',doc['text'])]
    doc['country']=value[9]
    doc['language']=value[10]
    doc['definition_text']=value[11]
#     print(doc['definition_text'],'\n\n')
    if doc['definition_text']:
        doc['definition_flag']=True
    else:
        doc['definition_flag']=False
    if value[14]==True or 'endorsement' in value[0].lower(): 
        doc['endorsements']=True
    else:
        doc['endorsements']=value[13]
    doc['excl_text']=value[14]
    doc['cond_text']=value[15]
    doc['cond_flag']=value[16]
    doc['cond_count']=value[17]
    doc['cond_pos']=value[18]
    doc['definitions_in_page']=value[19]
    doc['ext_text']=value[20]
    doc['ext_flag']=value[21]
    doc['ext_count']=value[22]
    doc['ext_pos']=value[23]
    
    try:       
        container.create_item(body=doc)
    except Exception as err:
        print(err)
        pass

# %%
print('added to cosmos')
# Out:
# added to cosmos
