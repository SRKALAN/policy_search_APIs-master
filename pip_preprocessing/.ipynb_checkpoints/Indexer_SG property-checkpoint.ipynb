# %%
# %load_ext autoreload
# %autoreload 15

# %%
# !pip3 install azure-cosmos

# %%
# !pip3 install comtypes

# %%
# !pip3 install pdfminer.six

# %%
import json
import re
from bs4 import BeautifulSoup
import os
import requests
from pprint import pprint
import uuid
from statistics import mode
from nltk.corpus import stopwords
from pdf2txt import convert_pdf
# !pip install tika
import tika
from definitions_v3 import *
# Out:
# /opt/app/RB/.local/lib/python3.6/site-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.2) or chardet (4.0.0) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
pointsRE_heading=re.compile('(?:\s*\([a-z]{1,3}\)|[A-Z]{1}\s+[a-zA-Z0-9_\s]{5})')
stop_words = list(set(stopwords.words('english')))
y_cordinate_Re=re.compile('top:(\d{1,5})px')
height_re=re.compile('height:(\d{1,5})px')

# %%
def check_underline(positions,y_cord_text):
    positions=[i for i in positions if y_cord_text<=i< y_cord_text+16]
    if positions:
        return True
    else:
        return False

# %%
def get_pages_no(soup):
    total_items = int(soup.find('span', id='NewReleases_total').text)
    items_per_page = int(soup.find('span', id='NewReleases_end').text)
    return round(total_items/items_per_page)

# %%
from pdfminer.high_level import extract_pages

# print(len(list(extract_pages('test/Chubb16-250-1019 Chubb EBM Business Pack Product Disclosure Statement (PDS) and Policy Wording.pdf'))))

# %%
def get_underlines(soup):
    positions=[]
    for span in soup.find_all('span'):
        y_cord_list=y_cordinate_Re.findall(str(span))
        if y_cord_list:
            y_cord=int(y_cord_list[0])
        else:
            continue
        style="position:absolute; border: black 1px solid" in str(span)
        height_px_li=height_re.findall(str(span))
        if height_px_li:
            height_px=height_px_li[0]
        else:
            continue
        height=int(height_px)<15
        if all([style,height]):
            positions.append(y_cord)
    return list(set(positions))

# %%
def ext_extract(text_list,language):
    ext_flag=False
    if language=='english':
        ext_lis=['extension']
    else:
        ext_lis=['extensión','extensiones']
   
    ext_count=0
    position_list=[]
    position=0
    for text in text_list:
        # if any two of 'exclusion ,condition or extension is present in the text, that text is omitted from the logic'
        bool_list=['condition' in text.lower(),'exclusion' in text.lower(),'extension' in text.lower()]
        if sum(bool_list)>=2:
            continue
        for i in ext_lis:
            for match in re.finditer(i, text.lower()):
                position_list.append(position+match.start())               
                ext_count+=1
        position+=len(text)
    if ext_count>=1:
        ext_flag=True
    return(ext_flag,ext_count,position_list)

# %%
def excl_extract(text_list,language):
    exclusion_flag=False
    if language=='english':
        excl_lis=['exclud','not cover','except','does not mean','not includ','exclusion']
    else:
        excl_lis=['excepto','excepción','no in cluido','exclusión','excluidos','excluirlo','excluyendo','exclusiones','exclusion','excluyen','excluyentes']
   
    exclusion_count=0
    position_list=[]
    position=0
    for text in text_list:
        # if any two of 'exclusion ,condition or extension is present in the text, that text is omitted from the logic'
        bool_list=['condition' in text.lower(),'exclusion' in text.lower(),'extension' in text.lower()]
        if sum(bool_list)>=2:
            continue
        for i in excl_lis:
            for match in re.finditer(i, text.lower()):
                position_list.append(position+match.start())               
                exclusion_count+=1
        position+=len(text)
    if exclusion_count>=1:
        exclusion_flag=True
    return(exclusion_flag,exclusion_count,position_list)

# %%
def cond_extract(text_list,language):
    cond_flag=False
    if language=='english':
        cond_lis=['condition']
    else:
        cond_lis=['condición','condiciones','condicionado']
   
    cond_count=0
    position_list=[]
    position=0
    for text in text_list:
        # if any two of 'exclusion ,condition or extension is present in the text, that text is omitted from the logic'
        bool_list=['condition' in text.lower(),'exclusion' in text.lower(),'extension' in text.lower()]
        if sum(bool_list)>=2:
            continue
        for i in cond_lis:
            for match in re.finditer(i, text.lower()):
                position_list.append(position+match.start())               
                cond_count+=1
        position+=len(text)
    if cond_count>=1:
        cond_flag=True
    return(cond_flag,cond_count,position_list)

# %%
def font_extraction(soup):
    fontsizes=[]
    for divs in soup.findAll('div'):
        for j in divs.find_all('span'):
            ext_size=re.findall(r'font-size:(.*)px">',str(j))
            if ext_size:
                fontsizes.append(int(ext_size[0]))
    return(fontsizes)

# %%
def stopword_check(word,text,language):
    if language=='spanish':
        stop_words = list(set(stopwords.words('spanish')))
    else:
        stop_words = list(set(stopwords.words('english')))
        transition="although  instead  whereas  despite  conversely  otherwise  however moreover  likewise  comparatively  correspondingly  similarly  furthermore  additionallyver  rather  nevertheless  nonetheless  regardless  notwithstanding consequently  therefore  thereupon  forthwith  accordingly  henceforth"
        transition_words=transition.split()
        transition_words
        stop_words.extend(transition_words)

    if exclusion_check(text,language):
        return True
    if word.lower() in stop_words:
        return False
    else:
        return True

# %%
def exclusion_check(text,language):
    if language=='spanish':
        exclusion_bag=['excepto','excepción','no in cluido','exclusión','excluidos','excluirlo','excluyendo',' excluyen','exclusiones','exclusiones','exclusion','excluyentes']
    else:
        exclusion_bag=['exclusion','excluded','not covered','will not cover','will not pay']
    for word in exclusion_bag:
        if word in text.lower():
            return True
    return False

# %%
def criteria_check(text,language):
    if language=='spanish':
        exclusion_bag=['condición','condiciones','condicionado']
    else:
        exclusion_bag=['condition','conditions']
    for word in exclusion_bag:
        if word in text.lower():
            return True
    return False

# %%
def ext_check(text,language):
    if language=='english':
        ext_bag=['extension']
    else:
        ext_bag=['extensión','extensiones']
    for word in ext_bag:
        if word in text.lower():
            return True
    return False

# %%
start=re.compile('.*\d{1,3}.*(?:\-|\.|–)')
def clean(text):
    text=text.replace('\n','').replace('\t',' ')
    text=start.sub('',text).strip()
    

    return(text)
def clean_pharses(phrases):
    phrases=[clean(i) for i in phrases if len(i)> 3]
    phrases=list(set(phrases))
    return phrases

# %%
def create_local_index(path,subdir,language,country):
    pointsRE_heading=re.compile('(?:\s*\([a-z]{1,3}\)|(?<![A-z])[A-Z]{1}\s+[a-zA-Z0-9_\s]{5})')
    pageNumRE=re.compile('Page\s*(\d{1,3})',re.IGNORECASE)
    neglect_def=['policy','insured','schedule']
    local_indexed={}
    previous_span=''
    bold_phrases_indexed={}
    for file in os.listdir(path):
        if file.endswith('.pdf'):
            print(file)
            global file_count
            file_count+=1
            
            print("COUNT",file_count)
            try:
                pg_no=len(list(extract_pages(os.path.join(path,file))))
            except:
                pg_no=0
            try:
                html=convert_pdf(os.path.join(path,file),'html')
            except:
                continue
            soup = BeautifulSoup(html, 'html5lib')
            underline_positions=get_underlines(soup)
            try:
                fontsizes=font_extraction(soup)
                file_font_size_mode=mode(fontsizes)
            except:
                file_font_size_mode=8
                
            text_para,text_plain_para='',''
            text_lis,text_plain_lis,bold_lis,page_list,=[],[],[],[]
            bold=False
            sub_page_def_list=[]
            try:
                definitions=def_extraction(os.path.join(path,file))
            except:
                continue
            definitions={key:value for key,value in definitions.items() if key.lower().strip() not in neglect_def}
            def_terms=list(definitions.keys())
#             print(len(def_terms),'LEN DEFINITIONS')
#             print(definitions)
            definition_text=''
            header_match_object=(0,'',False)
            cond_header_match_object=(0,'',False)
            ext_header_match_object=(0,'',False)
            second_category=False
            head_found=False
            def_flag=False
            cond_head_found=False
            ext_head_found=False
            single_page_head_found=False
            condition_text=''
            ext_text=''
            excl_text=''
            previous_pg_num=[]
            def_in_page=[]
            cond_single_page_head_found=False
            ext_single_page_head_found=False
            
            font_size=file_font_size_mode

            for divs in soup.findAll('div'):
                div_text_list=[span.text for span in divs.find_all('span') ]
                page_str=str(divs.find_all('a'))
                page_num_results=pageNumRE.findall(page_str)
                if page_num_results:
                    pagenum=page_num_results[0]
#                     print(pagenum)
                    if pagenum!=previous_pg_num:
                        sub_definitions_in_page=[]
                    previous_pg_num=pagenum
#                     definition_text=''
                    
                    #only for pdfs
                    if(int(pagenum) in [1,2]) and 'Wording' in file and pg_no >20:
#                     print('Continued on wording 2')
                        continue

                    if text_lis:
                        text_lis=text_lis[:-1]
                        text_para=''.join(text_lis)
                        text_plain_lis=text_plain_lis[:-1]
                        text_plain_para=''.join(text_plain_lis)
                        if(len(re.findall('\.',text_para))>(len(text_para)/3) or (len(re.findall('\d',text_para))>80 and int(pagenum)<4 and  pg_no>20 and 'content' in text_para.lower())) :
                            print('PASS')
                            print(text_plain_para)
                            text_para,text_plain_para=' ',' '
                            text_lis,text_plain_lis=[],[]
                            single_page_head_found=False
                            head_found=False
                            cond_head_found=False
                            ext_head_found=False
                            continue
                        
                        else:
                            bold_lis=clean_pharses(bold_lis)
                            pagenum=int(pagenum)-1
                            excl_flag,excl_count,excl_pos_lis=excl_extract(text_plain_lis,language)
                            cond_flag,cond_count,cond_pos_lis=cond_extract(text_plain_lis,language)
                            ext_flag,ext_count,ext_pos_lis=ext_extract(text_plain_lis,language)
                            if int(pagenum)==1:
                                if head_found or single_page_head_found or excl_count>0:
#                                     print(pagenum,True,'!!!')
                                    excl_flag=True
                                else:
                                    excl_flag=False
                            else:
                                if head_found or single_page_head_found:
#                                     print(pagenum,True,'!!!',excl_count)
                                    excl_flag=True
#                                     print(excl_flag,'EXCL')
#                                 else:
#                                     print(pagenum,excl_flag,'\n')
# #                             print(excl_text)
#                             print(condition_text)
                            if cond_head_found or cond_single_page_head_found or cond_count>0:
                                cond_flag=True
#                                 print('COND','TRUE')
                            else:
#                                 print('COND','FALSE')
                                cond_flag=False
    
                            if ext_head_found or ext_single_page_head_found or ext_count>0:
                                ext_flag=True
#                                 print('EXT','TRUE',pagenum)
                            else:
#                                 print('EXT','FALSE',pagenum)
                                ext_flag=False
#                             def_in_page=[{'name':k,'text':v[0] for k,v in definitions.items() if v[1]=pagenum}]
                            for term,defs in definitions.items():
#                                 print(defs[1])
                                if defs[1]==pagenum:  ###defs[1] is the pagenumber
                                    definition_text=definition_text+'          '+term+' '+defs[0]
                                    def_in_page.append({'name':term,'text':defs[0]})
#                                     def_in_page{'name':}
#                             print(definition_text)
                            if definition_text:
                                def_flag=True
                            
                            if def_flag:
                                def_search_flag=True
#                                 print('DEF','TRUE')
                            else:
#                                 print('DEF', 'FALSE')
                                def_search_flag=False   
                            
                            if pg_no>2:
                                endorsements=False
                            else:
                                endorsements=True
#                             print(endorsements,'ENDORSEMENTS!!!')
                            if text_para in local_indexed.keys():
                                text_para=text_para+' '
                            
                            local_indexed[text_para]=(file,pagenum,bold_lis,text_plain_para,excl_flag,excl_count,excl_pos_lis,subdir,sub_page_def_list,country,language,definition_text,def_search_flag,endorsements,excl_text,condition_text,cond_flag,cond_count,cond_pos_lis,def_in_page,ext_text,ext_flag,ext_count,ext_pos_lis)
#                             print(sub_page_def_list,'DEF LIST!!!!!1')
                            sub_page_def_list=[]
                            page_list.append(pagenum)
                            text_para,text_plain_para='',''
                            text_lis,text_plain_lis,bold_lis=[],[],[]
                            definition_text=''
                            cond_single_page_head_found=False
                            ext_single_page_head_found=False
                            condition_text=''
                            ext_text=''
                            excl_text=''
                            single_page_head_found=False
                            def_in_page=[]
                            def_flag=False
                for span in divs.find_all('span'):

                    bold=False
                    upper=False
                    bullet=False
                    def_flag=False
                    span_position=div_text_list.index(span.text)
                    
                    if "Bold" in str(span) or 'CIDFont+F3' in str(span):
                        bold_lis.append(span.text)
                        bold=True
                    if span.text.isupper():
                        upper=True
                    font_family_match=re.findall(r"font-family: b'(.*)';",str(span))
                    if font_family_match:
                        font_family=font_family_match[0]
                    else:
                        font_family=''
#                     print(font_family)
                    font_size_match=re.findall(r'font-size:(.*)px">',str(span))
                    if font_size_match:
                        font_size=int(font_size_match[0])
                    if pointsRE_heading.findall(span.text):
                        bullet=True
#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
                    y_cord_list=y_cordinate_Re.findall(str(divs))
                    if y_cord_list:
                        y_cord=int(y_cord_list[0])
                    underlined_text=check_underline(underline_positions,y_cord)
                    if span.text.split('\n')[0]!='' and span.text.split('\n')[0]!=' ':
                        head_check_text=span.text.split('\n')[0]
                    elif len(span.text.split('\n'))>1:
                        head_check_text=span.text.split('\n')[1]
                    else:
                        head_check_text=''
##############################3  
                    if str(previous_span).endswith('<br/></span>'):
                        span_position=0
                    ##################INSERT FUNCTION####################z
                    #EXCLUSION 
                    if  span_position==0 and (bold or font_size>= file_font_size_mode +2 ) and (font_size> file_font_size_mode or upper) and 5<len(head_check_text.strip())<80:                    
                        if exclusion_check(head_check_text,language) and not head_found: 
                            head_found=True
                            header_match_object=(font_size,font_family,bold,upper,bullet)
                            First_category=True
                            second_category=False
                            single_page_head_found=True
#                             print('FOUND Heading for exclusion ...',span.text)
                        
                    
                        elif ((font_size,font_family,bold,upper,bullet)==header_match_object  or font_size>header_match_object[0] ) and head_found and not exclusion_check(head_check_text,language):
                            head_found=False
                            single_page_head_found=True
#                             print('FOUND Closure for exclusion ...',span.text)
#                     if 'CLAIMS CONDITIONS' in span.text:
#                         print ('^^^^^^^',(font_size,font_family,bold,upper,bullet),header_match_object, font_size>header_match_object[0] , head_found , not exclusion_check(head_check_text,language))
#                         print(pointsRE_heading.findall(span.text))
                    words_title=[word.istitle() for word in head_check_text.split() if stopword_check(word,head_check_text,language) and not word.isdigit() ]
                    if span_position==0 and all(words_title) and head_check_text.strip() not in definitions and  (len(words_title) >1 or underlined_text )and 5<len(head_check_text.strip())<80 :
#                         print('MMMMMMMMARARARA',span.text)

                        if exclusion_check(head_check_text,language) and  not head_found:
                            head_found=True
                            second_category=True
                            First_category=False
                            single_page_head_found=True
                            header_match_object=(font_size,font_family,bold,upper,bullet)
#                             print("FOUND heading type2 ....",span.text)
                        elif head_found and not exclusion_check(head_check_text,language) and second_category and ((font_size,font_family,bold,upper,bullet)==header_match_object or font_size > header_match_object[0] ) :
                            head_found=False
                            second_category=False
                            single_page_head_found=True
#                             print('FOUND closure type 2',span.text)
                    if head_found:
                        excl_text=excl_text+' '+span.text     
                     
                    #CONDITIONS
#                     if 'Condition' in span.text:
# #                         print('text:',str(span.text),'head check',head_check_text,'length of head check',len(head_check_text))
# #                         print(span_position==0,(bold or font_size>= file_font_size_mode +2 ), (font_size> file_font_size_mode or upper), 5<len(head_check_text.strip())<80)
# #                         print(font_size,file_font_size_mode,cond_head_found,criteria_check(head_check_text,language))
                    if  span_position==0 and (bold or font_size>= file_font_size_mode +2 ) and (font_size> file_font_size_mode or upper) and 5<len(head_check_text.strip())<80:                    
                        if criteria_check(head_check_text,language) and not cond_head_found: 
                            cond_head_found=True
                            cond_header_match_object=(font_size,font_family,bold,upper,bullet)
                            cond_First_category=True
                            cond_second_category=False
                            cond_single_page_head_found=True
#                             print('FOUND Heading for condition...',span.text)
                    
                        elif ((font_size,font_family,bold,upper,bullet)==cond_header_match_object or font_size>cond_header_match_object[0] ) and not criteria_check(head_check_text,language)  and cond_head_found:
                            cond_head_found=False
                            cond_single_page_head_found=True
#                             print('FOUND Closure for condition ...',span.text)
                
                    
                    cond_words_title=[word.istitle() for word in head_check_text.split() if stopword_check(word,head_check_text,language) and not word.isdigit() ]
                    if span_position==0 and all(cond_words_title) and head_check_text.strip() not in definitions and  (len(words_title) >1 or underlined_text )and 5<len(head_check_text.strip())<80 :
#                         print('MMMMMMMMARARARA',span.text)

                        if criteria_check(head_check_text,language) and  not cond_head_found:
                            cond_head_found=True
                            cond_second_category=True
                            cond_First_category=False
                            cond_single_page_head_found=True
                            cond_header_match_object=(font_size,font_family,bold,upper,bullet)
#                             print("FOUND heading type2 ....",span.text)
                        elif cond_head_found and not criteria_check(head_check_text,language) and cond_second_category and ((font_size,font_family,bold,upper,bullet)==cond_header_match_object or font_size > cond_header_match_object[0] ) :
                            cond_head_found=False
                            cond_second_category=False
                            cond_single_page_head_found=True
#                             print('FOUND closure type 2',span.text)

                    if cond_head_found==True:
                        condition_text=condition_text+' '+span.text
                            
                    
                    #####EXTENSIONS
                    #CONDITIONS
#                     if 'Extension' in span.text:
#                         print(span.text)
#                         print('text:',str(span.text),'head check',head_check_text,'length of head check',len(head_check_text))
#                         print(span_position==0,(bold or font_size>= file_font_size_mode +2 ), (font_size> file_font_size_mode or upper), 5<len(head_check_text.strip())<80)
#                         print(font_size,file_font_size_mode,cond_head_found,criteria_check(head_check_text,language))
                    if  span_position==0 and (bold or font_size>= file_font_size_mode +2 ) and (font_size> file_font_size_mode or upper) and 5<len(head_check_text.strip())<80:                    
                        if ext_check(head_check_text,language) and not ext_head_found: 
                            ext_head_found=True
                            ext_header_match_object=(font_size,font_family,bold,upper,bullet)
                            ext_First_category=True
                            ext_second_category=False
                            ext_single_page_head_found=True
#                             print('FOUND Heading for ext...',span.text)
                    
                        elif ((font_size,font_family,bold,upper,bullet)==ext_header_match_object or font_size>ext_header_match_object[0] ) and not ext_check(head_check_text,language)  and ext_head_found:
                            ext_head_found=False
                            ext_single_page_head_found=True
#                             print('FOUND Closure for ext ...',span.text)
                
                    
                    ext_words_title=[word.istitle() for word in head_check_text.split() if stopword_check(word,head_check_text,language) and not word.isdigit() ]
                    if span_position==0 and all(ext_words_title) and head_check_text.strip() not in definitions and  (len(words_title) >1 or underlined_text )and 5<len(head_check_text.strip())<80 :
#                         print('MMMMMMMMARARARA',span.text)

                        if ext_check(head_check_text,language) and  not ext_head_found:
                            ext_head_found=True
                            ext_second_category=True
                            ext_First_category=False
                            ext_single_page_head_found=True
                            ext_header_match_object=(font_size,font_family,bold,upper,bullet)
#                             print("FOUND heading type2 ext....",span.text)
                        elif ext_head_found and not ext_check(head_check_text,language) and ext_second_category and ((font_size,font_family,bold,upper,bullet)==ext_header_match_object or font_size > ext_header_match_object[0] ) :
                            ext_head_found=False
                            ext_second_category=False
                            ext_single_page_head_found=True
#                             print('FOUND closure type 2 ext',span.text)
# 
                    if ext_head_found==True:
                        ext_text=ext_text+' '+span.text
                            
    #                     else:
###############################             
                        
                    if font_size_match:
                        if font_size<=file_font_size_mode-1:
                            text_lis.append(' ')
                    text=span.text.replace('\n',' ')
                    text_plain=text.replace('\n',' ')
                    for term in def_terms:
                        if term.lower().strip() in text.lower() and definitions[term][0].strip() not in text and term not in sub_definitions_in_page:
#                             def_page.append(definitions[term])
#                             print(pagenum)
                            src_str  = re.compile(re.escape(term), re.IGNORECASE)
                            text=src_str.sub('###{}@@{}%%%'.format(term,definitions[term][0]),text)
#                             print(text,'\n',term,'TERM!!!!@#$%^&*&^%#$%^&')
                            sub_definitions_in_page.append(term)
                            sub_page_def_list.append({'name':term,'text':definitions[term][0]})
#                             print(definitions_in_page)
                            break
#                     print(definitions_in_page)

                    
                    text_lis.append(text)
                    text_plain_lis.append(text_plain)
                    previous_span=span
                    

            if text_lis:
                if(int(pagenum) in [1,2]) and 'Wording' in file and pg_no >20:
#                     print('Continued on wording 2')
                    continue

                text_lis=text_lis[:-1]
                text_para=''.join(text_lis)
                text_plain_lis=text_plain_lis[:-1]
                text_plain_para=''.join(text_plain_lis)
                if(len(re.findall('\.',text_para))>(len(text_para)/3) or (len(re.findall('\d',text_para))>80 and int(pagenum)<4 and pg_no>20 and 'content' in text_para.lower())) :
                    print('PASS')
                    print(text_plain_para)
                    text_para,text_plain_para=' ',' '
                    text_lis,text_plain_lis=[],[]
                    single_page_head_found=False
                    head_found=False
                    cond_head_found=False
                    ext_head_found=False
                    continue
                else:
                    bold_lis=clean_pharses(bold_lis)
                    if pagenum in page_list and pagenum!='1':
                        pagenum=int(pagenum)+1
                    excl_flag,excl_count,excl_pos_lis=excl_extract(text_plain_lis,language)
                    cond_flag,cond_count,cond_pos_lis=cond_extract(text_plain_lis,language)
                    ext_flag,ext_count,ext_pos_lis=ext_extract(text_plain_lis,language)
                    if int(pagenum)==1:
                        if head_found or single_page_head_found or excl_count>0:
#                             print(pagenum,True,'!!!',excl_count)
                            excl_flag=True
                        else:
                            excl_flag=False
                    else:
                        if head_found or single_page_head_found:
#                             print(pagenum,True,'!!!')
                            excl_flag=True
#                             print(excl_flag,'EXCL')
                        
                    #####################
                    if cond_head_found or cond_single_page_head_found or cond_count>0:
                        cond_flag=True
#                         print('COND','TRUE')
                    else:
                        cond_flag=False
                    
                    if ext_head_found or ext_single_page_head_found or ext_count>0:
                        ext_flag=True
#                         print('EXT','TRUE',pagenum)
                    else:
#                         print('EXT','FALSE',pagenum)
                        ext_flag=False
#                         print('COND','FALSE')
#                     page_def_list.append({'name':term,'text':definitions[term][0]}
#                     def_in_page=[{'name':k,'text':v[0]} for k,v in definitions.items() if v[1]==pagenum]  
#                     print(def_in_page,'!!!!!!!!!!!!!!!!!!!!!!!!!!!!!')
                    for term,defs in definitions.items():
                        if defs[1]==pagenum:  ###defs[1] is the pagenumber
                            definition_text=definition_text+'          '+term+' '+defs[0]
                            def_in_page.append({'name':term,'text':defs[0]})        
#                     print(definition_text)
                    if definition_text:
                        def_flag=True

                    if def_flag:
                        def_search_flag=True
#                         print('DEF','TRUE')
                    else:
                        def_search_flag=False
#                         print('DEF','FALSE')
                    
                    if pg_no>2:
                        endorsements=False
                    else:
                        endorsements=True
#                     print(endorsements,'ENDORSEMENTS!!!')        
                    if text_para in local_indexed.keys():
                        text_para=text_para+' '
                    local_indexed[text_para]=(file,pagenum,bold_lis,text_plain_para,excl_flag,excl_count,excl_pos_lis,subdir,sub_page_def_list,country,language,definition_text,def_search_flag,endorsements,excl_text,condition_text,cond_flag,cond_count,cond_pos_lis,def_in_page,ext_text,ext_flag,ext_count,ext_pos_lis)
#                     print(sub_page_def_list,'DEF LIST!!!!!1')
                    sub_page_def_list=[]
                    text_para,text_plain_para='','' 
                    text_plain_lis,text_lis,bold_lis=[],[],[]
                    definition_text=''
                    single_page_head_found=False
                    cond_single_page_head_found=False
                    ext_single_page_head_found=False
                    condition_text=''
                    ext_text=''
                    excl_text=''
                    def_in_page=[]
                    def_flag=False
    return(local_indexed)

# %%
def doc_pdf_path(path):
    file_list=os.listdir(path)
    for file in file_list:
        raw_filename=file[:file.rfind(".")]
        pdf_filename=raw_filename+'.pdf'
#         print(raw_filename,pdf_filename,'FILE!!')
        if pdf_filename in file_list:
            print('continued!!!!!!!!!!!!!')
            continue
        if file.endswith('doc') or file.endswith('docx'):
            print('processing!!!')
            wordToPdf(os.path.join(path,file))

# %%
# rootDir='V://COG//AU- Property//'
# for dirname,subdirlist,filelist in os.walk(rootDir):
#     print(dirname)
#     for subdir in subdirlist:
#         path=os.path.join(dirname,subdir)
# #         doc_pdf_path(path)

# %%
# import os
file_count=0
rootDir='Documents/UK-Property/'
country='uk'
local_indexed={}
language='english'
if 'spanish' in rootDir:
    language='spanish'
for dirname,subdirlist,filelist in os.walk(rootDir):
    for subdir in subdirlist:
        print(subdir, 'SUBDIR!!!!!!!!!!!!!')
        path=os.path.join(dirname,subdir)    
        local_indexed_subdir=create_local_index(path,subdir,language,country)
        local_indexed.update(local_indexed_subdir)
# Out:
# Other Carrier Wording SUBDIR!!!!!!!!!!!!!
# Broker Wording SUBDIR!!!!!!!!!!!!!
# Chubb Standard Wording SUBDIR!!!!!!!!!!!!!
# Animal Diseases Exclusion (SC_HREL1603.ADE.1).pdf
# COUNT 1
# Compensation For Court Attendance (SC_BFSG1607.CCA.1).pdf
# COUNT 2
# Traditional Chinese Medicine (TCM) Extension (WGSG00026) (SC_WGPP_SG0416.26.1).pdf
# COUNT 3
# Specified Activities Exclusion (SC_BFSG1607.SAE.1).pdf
# COUNT 4
# Silica, Dust and Particulate Matter Exclusion (WCSI01) (SC_WGPP_SG0416.101.1).pdf
# COUNT 5
# Exchange Rate Clause (SC_BFSG1607.EXRC.1).pdf
# COUNT 6
# Contingent Liability to Independent Contractors ( WGSG00001) (SC_WG_SG1412.01.1).pdf
# COUNT 7
# Physical Participation Exclusion (SC_BFSG1607.PPE.1).pdf
# COUNT 8
# Part Timers, Temporary Contract Employees (WCPA01) (SC_WG_SG1412.PA01.1).pdf
# COUNT 9
# Exchange Rate Clause (Vietnam) (SC_BFSG1607.ERCVN.1).pdf
# COUNT 10
# Failure to Supply (S&A Damage) (SC_BFSG1607.FSSAD.1).pdf
# COUNT 11
# Chubb Umbrella Liability Wording (Chubb_UMB_SG1604).pdf
# COUNT 12
# 19 False
#
# Non-Accumulation of Limits and Sub-Limits Endorsement (SC_HREL1603.NALSL.1).pdf
# COUNT 13
# Demonstrations and Exhibitions (SC_BFSG1607.DEMEX.1).pdf
# COUNT 14
# PCB Exclusion (SC_HREL1603.PCBE.1).pdf
# COUNT 15
# Chubb WorkGuard Wording (Chubb_WG_SG1912).pdf
# COUNT 16
# PASS
#                     Contents  Important Notices........................................................................................ 3  Chubb Work Guard Policy ............................................................................ 4  Details of Employees Covered ....................................................................... 5  Chubb Work Guard Insurance Policy Wording................................................ 6  Chubb Work Guard Compensation Insurance Policy Clauses .......................... 11  Appendix 1: Attaching to and forming part of Policy Number XXXX  ................ 14  About Chubb in Singapore ........................................................................... 17  Contact Us ................................................................................................. 17  Chubb  Work Guard Insurance  Policy Schedule  and Wording. Singapore.  Published  12/2019.  © 2019 Chubb.  Coverages underwritten  by one  or more subsidiary companies.  Not all coverages  available in all jurisdictions. Chubb®  and its respective  logos, and Chubb.  Insured.TM  are protected  trademarks of Chubb.
# 17 False
#
# Electronic Data Exclusion. (SC_BFSG1607.EDE.1).pdf
# COUNT 17
# Contractual Liability Extension (SC_HREL1603.CLE.1).pdf
# COUNT 18
# Non Resident Employees Voluntary Extension (WGSG00003) (SC_WGPP_SG0416.03.1).pdf
# COUNT 19
# 2 False
#
# Breach of Conditions and Warranties (SC_BFSG1607.BCW.1).pdf
# COUNT 20
# CYBER4A Personal Data Breach and Cyber Attack Writeback (SC_BFSG1607.CYBER4A.1).pdf
# COUNT 21
# 2 False
#
# Failure to Supply (S&A Damage, Sub-Limit) (SC_BFSG1607.FSSADSL.1).pdf
# COUNT 22
# Neon And Advertising Signs (SC_HREL1603.NAS.1).pdf
# COUNT 23
# Premium Payment Warranty (30 Days) (SC_BFSG1607.PPW30.1).pdf
# COUNT 24
# Social Recreational Acitivities (WGSG00002) (SC_WGPP_SG0416.02.1).pdf
# COUNT 25
# Property Owner's Liability (SC_BFSG1607.POL.1).pdf
# COUNT 26
# PROPERTY WORKED UPON EXTENSION (SC_HREL1603 .PWUE.1).pdf
# COUNT 27
# Traditional Chinese Medicine Extension (WGSG00019) (SC_WG_SG1412.19.1).pdf
# COUNT 28
# EMF EMR Exclusion. (SC_BFSG1607.EMFR.1).pdf
# COUNT 29
# Travelling To and From Work (Including Meal Breaks) (WCTR01) (SC_WGPP_SG0416.TFW.1).pdf
# COUNT 30
# Exchange Rate Clause (SC_HREL1603.ERC.1).pdf
# COUNT 31
# Care Custody and Control Extension 4.9(e)(ii) (Amended) (SC_HREL1603.CCC4.9.1).pdf
# COUNT 32
# Social and Recreational Activities (SC_WGPP_SG0416.SRA.1).pdf
# COUNT 33
# Employees Insured Under Separate Insurances Exclusion WG_SG1912 60103534.pdf
# COUNT 34
# Guests Effects (SC_BFSG1607.GE.1).pdf
# COUNT 35
# Claims Made Basis (Products Liability Only) (SC_BFSG1607.CMBPL.1).pdf
# COUNT 36
# Fungus Mould Exclusion.(SC_BFSG1607.FME.1).pdf
# COUNT 37
# Fire And Explosion (SC_HREL1603.FX.1).pdf
# COUNT 38
# Waiver of Subrogation (Principals) (SC_HREL1603.WSP.1).pdf
# COUNT 39
# Mine Related Land Movement Exclusion (SC_BFSG1607.MRLME.1).pdf
# COUNT 40
# 24-Hours Cover On Worldwide Business Travel (WGSG00004) (SC_WGPP_SG0416.04.1).pdf
# COUNT 41
# Waiver of Subrogation (Insured) (SC_BFSG1607.WSI.1).pdf
# COUNT 42
# Food and Drinks (SC_BFSG1607.FD.1).pdf
# COUNT 43
# Waiver of Subrogation (Specified Entities) (SC_BFSG1607.WSSE.1).pdf
# COUNT 44
# Change of Deductible Endorsement (SC_BFSG1607.CODE.1).pdf
# COUNT 45
# Participation Exclusion. (SC_BFSG1607.PRTE.1).pdf
# COUNT 46
# S&A Pollution (Named Perils, 72 Hours) (SC_BFSG1607.SAPNP72.1).pdf
# COUNT 47
# Entertainers' Liability. (SC_BFSG1607.EL.1).pdf
# COUNT 48
# Demining Related Exclusions (SC_BFSG1607.DRE.1).pdf
# COUNT 49
# Tanning Exclusion (SC_BFSG1607.TE.1).pdf
# COUNT 50
# Social and Recreational Activities (SC_WG_SG1412.SRA.1).pdf
# COUNT 51
# Mobile Phone Exclusion (SC_BFSG1607.MPE.1).pdf
# COUNT 52
# Project Property Exclusion (SC_HREL1603.PPE.1).pdf
# COUNT 53
# EMPLOYER'S LIABILITY WOR_001 (SC_WG_SG1412.ELW1.1).pdf
# COUNT 54
# Failure Collapse of Temporary Structure Exclusion. (SC_BFSG1607.FCTSE.1).pdf
# COUNT 55
# Boiler and Pressure Vessel (SC_BFSG1607.BPV.1).pdf
# COUNT 56
# Wildfire Exclusion (SC_BFSG1607.WFE.1).pdf
# COUNT 57
# Blood Products Exclusion (SC_BFSG1607.BPE.1).pdf
# COUNT 58
# Products Liability Exclusion (SC_HREL1603.PLE.1).pdf
# COUNT 59
# Boiler or Pressure Vessel Explosion (SC_BFSG1607.BPVE.1).pdf
# COUNT 60
# Premium Payment Warranty (60 Days) (SC_BFSG1607.PPW.1).pdf
# COUNT 61
# Breach of Conditions and Warranties (SC_HREL1603.BCW.1).pdf
# COUNT 62
# Insured Drone Extension (SC_GGSG1409.IDE.1).pdf
# COUNT 63
# Loss Notification (Unexpected and Unintended Delay) (SC_BFSG1607.LNUUID.1).pdf
# COUNT 64
# Products Liability Exclusion (SC_BFSG1607.PLE.1).pdf
# COUNT 65
# CYBER4B Personal and Corporate Data Breach and Cyber Attack Writeback (SC_GGSG1409.CYBER4B.1).pdf
# COUNT 66
# 2 False
#
# Abuse (Claims Made and Notified) Endorsement (SC_BFSG1607.ABCMN.1).pdf
# COUNT 67
# 2 False
#
# Waiver of Subrogation (SC_WG_SG1412.WVS.1).pdf
# COUNT 68
# Mine Land or Mineral Resources Reserves Exclusion (SC_BFSG1607.MLMRRE.1).pdf
# COUNT 69
# Waiver of Subrogation (SHIPYARD) (SC_BFSG1607.WSSY.1).pdf
# COUNT 70
# 3 True
#
# DMF Exclusion (SC_BFSG1607.DMFE.1).pdf
# COUNT 71
# Efficacy Exclusion (SC_BFSG1607.EE.1).pdf
# COUNT 72
# Communicable Disease Exclusion - Scheduled Activities Only (SC_XOL1701.CDESA.1).pdf
# COUNT 73
# Non-Accumulation of Limits and Sub-Limits Endorsement (SC_BFSG1607.NALE.1).pdf
# COUNT 74
# Claims Made Basis (SC_HREL1603.CMB.1).pdf
# COUNT 75
# Autonomous or Semi-Autonomous Safety-Critical Automotive Products Exclusion (SC_BFSG1607.ASASCAP.1).pdf
# COUNT 76
# Communicable Disease Exclusion (Blanket) (SC_Chubb_ XOL1701.CDEB.1).pdf
# COUNT 77
# Vendor's Liability Extension (Scheduled Vendors) (SC_BFSG1607.VLE-SV.1).pdf
# COUNT 78
# Additional Insured (SHIPYARD) (WGSG00010) (SC_WG_SG1412.10.1).pdf
# COUNT 79
# 3 True
#
# Waiver of Subrogation (Principals) (WGSG00025)(SC_WGPP_SG0416.WSP.1).pdf
# COUNT 80
# Chubb Global Guard Casualty Multinational Policy (Chubb_GG_SG1409).pdf
# COUNT 81
# 25 False
#
# Change of Insured Endorsement (SC_HREL1603.CIE.1).pdf
# COUNT 82
# Extended Period Agreement (3 Years) (SC_BFSG1607.EPA3Y.1).pdf
# COUNT 83
# 2 False
#
# Change of Insured Endorsement (SC_BFSG1607.COIE.1).pdf
# COUNT 84
# Tobacco Products (Manufacturers) Exclusion. (SC_BFSG1607.TPME.1).pdf
# COUNT 85
# Employer's Liability Extension (Specified Nationalities, Jurisdiction, Sub-Limit) (SC_BFSG1607.ELE-SNJSL.1).pdf
# COUNT 86
# Communicable Disease Exclusion (Blanket) (SC_UMB_SG1604.CDEB.1).pdf
# COUNT 87
# Cellular or Wireless Radiation Exclusion (SC_BFSG1607.CWRE.1).pdf
# COUNT 88
# Change of Business Description Endorsement (SC_HREL1603.CBDE.1).pdf
# COUNT 89
# Care, Custody and Control Extension 4.3(d) (More Specific Policies) (SC_BFSG1607.CCCE4.3D.1).pdf
# COUNT 90
# GMO Exclusion. (SC_BFSG1607.GMOE.1).pdf
# COUNT 91
# Employer's Liability Extension (Specified Nationalities) (SC_BFSG1607.ELE-SN.1).pdf
# COUNT 92
# Lead Exclusion. (SC_BF1607.LDE.1).pdf
# COUNT 93
# Keppel Shipyard Endorsement. (SC_BFSG1607.KSYE.1).pdf
# COUNT 94
# Hot Work Exclusion (SC_HREL1603.HWE.1).pdf
# COUNT 95
# Sembcorp Jurong Shipyard Endorsement. (SC_BFSG1607.SJSE.1).pdf
# COUNT 96
# Fungus, Mould or Spore Exclusion (SC_BFSG1607.FMSE.1).pdf
# COUNT 97
# Intellectual Property Rights or Laws Exclusion (SC_HREL1603.IPRLE.1).pdf
# COUNT 98
# Defective Sanitary Facilities (SC_BFSG1607.DSF.1).pdf
# COUNT 99
# Underground Property Damage Endorsement (SC_BFSG1607.UPDE.1).pdf
# COUNT 100
# Business Disruption Assistance Benefits (WGSG00018) (SC_WGPP_SG0416.18A.1).pdf
# COUNT 101
# High Risk Sports and Sporting Activities Exclusion (SC_BFSG1607.HRSSAE.1).pdf
# COUNT 102
# Lead Exclusion (SC_HREL1603.LDE.1).pdf
# COUNT 103
# Contractual Liability Extension (SC_BFSG1607.CLE.1).pdf
# COUNT 104
# Melamine (Personal Injury) Exclusion (SC_BFSG1607.MPIE.1).pdf
# COUNT 105
# Food and Drinks (Sub-Limit) (SC_GGSG1409.FDSL.1).pdf
# COUNT 106
# Insured Drone Extension (SC_BFSG1607.IDE.1).pdf
# COUNT 107
# 2 False
#
# Breach of Warranties (SC_HREL1603.BW.1).pdf
# COUNT 108
# Loss Notification (Unexpected and Inadvertent Delay) (SC_HREL1603.LNUID.1).pdf
# COUNT 109
# Aquafanatics Water Activities Endorsement - HREL1603 - SS&L Beach DRAFT 20191125.pdf
# COUNT 110
# Airport Hangar Operators Exclusion (SC_BFSG1607.AHOE.1).pdf
# COUNT 111
# Financial Interests (Non-Participant) Exclusion (SC_BFSG1607.FINPE.1).pdf
# COUNT 112
# Chubb Advantage Exporters Occ (Chubb_AEOCC_SG1604).pdf
# COUNT 113
# PASS
#                   Contents  Contents ..................................................................................................... 2  Policy Schedule............................................................................................ 4  Policy Wording ............................................................................................ 5  Introduction  How To Read This Policy  You, Your, We, Us and Our  Words In Quotation Marks  1.  2.  3.  Insuring Agreements  Exclusions  Supplementary Payments  Section I – Coverage..................................................................................... 5  Section II – Who Is An Insured ..................................................................... 9  Section III – Limit Of Insurance .................................................................... 9  Section IV – Deductible ...............................................................................10  Section V – Definitions ................................................................................10  Section VI – General Policy Conditions ......................................................... 12  12  Bankruptcy  1.  2.  Duties in the Event of Occurrence, Offence Claim or Suit  3.  Legal Action Against Us  4.  Other Insurance  Premium Audit  5.  6.  Representations  7.  8.  9.  Cancellation  10.  Changes  Separation of Insureds  Transfer of Rights of Recovery Against Others to Us  11.  Examination of Your Books and Records  12.  Inspections and Surveys  13.  Premiums  14.  Transfer of Your Rights and Duties Under This Policy  15.  Applicable Law  Chubb  Advantage Exporter’s Liability Policy Wording. Singapore.  Published 04/2016.  © 2016 Chubb.  Coverages underwritten  by one  or more subsidiary companies.  Not all coverages  available in all jurisdictions. Chubb®  and its respective  logos, and Chubb.  Insured.SM  are protected  trademarks of Chubb.  5  5  5  5  5  6  8  12  12  13  13  13  13  14  14  14  14  14  15  15  15
# PASS
#                         16.  Condition Precedent  15  Premium Payment Warranty........................................................................ 15  Contracts (Rights Of Third Parties) Act 2001 Exclusion .................................. 16  Electronic Media Endorsement .................................................................... 16  Memo A ..................................................................................................... 16  Products Efficacy Exclusion ......................................................................... 17  Professional Liability Exclusion.................................................................... 17  Punitive Damage Exclusion.......................................................................... 17  Supplementary Payment Amendment ........................................................... 17  Terrorism Exclusion Endorsement ............................................................... 17  Contact Us .................................................................................................18  About Chubb in Singapore ...........................................................................18  Chubb  Advantage Exporter’s Liability Policy Wording. Singapore.  Published 04/2016.  © 2016 Chubb.  Coverages underwritten  by one  or more subsidiary companies.  Not all coverages  available in all jurisdictions. Chubb®  and its respective  logos, and Chubb.  Insured.SM  are protected  trademarks of Chubb.
# Overseas Medical Expense (WGSG00017) (SC_WGPP_SG0416.17A.1).pdf
# COUNT 114
# Part Timers, Temporary Contract Employees (WCPA01) (SC_WGPP_SG0416PTTC.1).pdf
# COUNT 115
# Care, Custody or Control Extension (Deleted and Replaced) (SC_BFSG1607.CCCEDR.1).pdf
# COUNT 116
# Product Recall Expense (Pre) Extension. (SC_BFSG1607.PRERE.1).pdf
# COUNT 117
# 2 False
#
# Specified Sub-Limit (SC_BFSG1607.SSL-A.1).pdf
# COUNT 118
# CYBER1C Cyber Liability Exclusion (SC_GGSG1409.CYBER1C.1).pdf
# COUNT 119
# Employees Effects (SC_BFSG1607.EMPE.1).pdf
# COUNT 120
# Waiver of Subrogation (SHIPYARD) (WGSG00013) (SC_WGPP_SG0416.13.1).pdf
# COUNT 121
# Claims Made Basis (Products Liability Only) (SC_HREL1603.CMBPL.1).pdf
# COUNT 122
# WC24HRS - 24 Hours Cover on Worldwide Business Travel (SC_WG_SG1412.WC24.1).pdf
# COUNT 123
# Land or Mineral Resources Reserves Exclusion (SC_BFSG1607.LMRRE.1).pdf
# COUNT 124
# Pyrotechnics and Explosives Exclusion. (SC_BFSG1607.PYEE.1).pdf
# COUNT 125
# WGSG00026 Repatriation Expenses Benefit (SC_WG_SG1412.26.1).pdf
# COUNT 126
# Indemnity to Principals Extension. (SC_BFSG1607.IPE.1).pdf
# COUNT 127
# Travelling To and From Work (Excluding Meal Breaks) (WCTR04) (SC_WGPP_SG0416.TR4.1).pdf
# COUNT 128
# Indemnity to Principals Extension (SC_HREL1603.IPE.1).pdf
# COUNT 129
# Silica, Dust and Particulate Matter Exclusion ( WCSI01) (SC_WG_SG1412.WCSI0.1).pdf
# COUNT 130
# Principal's Existing Property Endorsement (Aggregate Sub-Limit) (SC_BFSG1607.PEPEASL.1).pdf
# COUNT 131
# Excess Motor Liability Extension (Owned, Hired or Non-Owned) - Sub-Limit (SC_BFSG1607.EMLESL.1).pdf
# COUNT 132
# 2 False
#
# EMPLOYER'S LIABILITY WOR_001 (SC_WGPP_SG0416.ELW.1).pdf
# COUNT 133
# Additional Insured (SHIPYARD) (WGSG00010) (SC_WGPP_SG0416.10.1).pdf
# COUNT 134
# 3 True
#
# Communicable Disease Exclusion (Blanket) (SC_OFF_SG1511.CDEB.1).pdf
# COUNT 135
# Private Work for Directors and Executives (SC_HREL1603.PWDE.1).pdf
# COUNT 136
# Additional Insured Clause (SC_HREL1603.AIC.1).pdf
# COUNT 137
# Failure to Supply (Sub-Limit) (SC_BFSG1607.FSSL.1).pdf
# COUNT 138
# Chubb Hotelier and Real Estate Liability Policy Form (Chubb_HREL_1603).pdf
# COUNT 139
# PASS
#                               Contents  Important Notices........................................................................................ 3  Your Duty of Disclosure .......................................................................... 3  Consequences of Non-Disclosure ............................................................. 3  Subrogation ........................................................................................... 3  Privacy Statement ........................................................................................ 4  Policy Schedule............................................................................................ 5  Policy Wording ............................................................................................ 6  Definitions .................................................................................................. 7  Exclusions .................................................................................................. 11  Extensions ................................................................................................. 15  Conditions ................................................................................................. 19  Endorsements ............................................................................................22  Terrorism Exclusion ..............................................................................22  Endorsement Title .................................................................................22  About Chubb in Singapore ...........................................................................23  Contact Us .................................................................................................23  Hotelier  and Real Estate Liability Policy. Singapore.  Published 06/2016.  © 2016 Chubb.  Coverages underwritten  by one  or more subsidiary companies.  Not all coverages  available in all jurisdictions. Chubb®  and its respective  logos, and Chubb.  Insured.SM  are protected  trademarks of Chubb.
# 23 False
#
# Batch Clause (SC_BFSG1607.BC.1).pdf
# COUNT 140
# GPA Extension (SC_WG_SG1412.GPA.1).pdf
# COUNT 141
# Care Custody and Control Extension 4.3(d)(Amended) (SC_BFSG1607.CCCD.1).pdf
# COUNT 142
# Personal Injury (Broad Definition) (SC_BFSG1607.PIBD.1).pdf
# COUNT 143
# CLAIMS MADE TRIGGER ENDT (SC_WGPP_SG0416.CMT.1).pdf
# COUNT 144
# 2 False
#
# Rip and Tear Exclusion (SC_BFSG1607.RTE.1).pdf
# COUNT 145
# Change of Deductible Endorsement (SC_HREL1603.CDE.1).pdf
# COUNT 146
# Principals as Additional Insured Extension (SC_BFSG1607.PAIE.1).pdf
# COUNT 147
# Premium Adjustment Clause (Turnover) (SC_BFSG1607.PACTO.1).pdf
# COUNT 148
# Errors and Omissions (Claims Made and Notified) Endorsement (SC_HREL1603.EOCM.1).pdf
# COUNT 149
# 3 False
#
# Defective Sanitary Facilities (SC_HREL1603.DSF.1).pdf
# COUNT 150
# PCB Exclusion - BF20.pdf
# COUNT 151
# Chubb Advantage Exporters CM (Chubb_AECM_SG1604).pdf
# COUNT 152
# PASS
#                   Contents  Contents ..................................................................................................... 2  Policy Schedule............................................................................................ 4  Policy Wording ............................................................................................ 5  Section I – Coverage..................................................................................... 5  1.  2.  2.  Insuring Agreements  Exclusions  Supplementary Payments  Section II – Who Is An Insured ..................................................................... 9  Section III  – Limit Of Insurance ................................................................... 9  Section IV – Deductible ...............................................................................10  Section V – Definitions ................................................................................10  Section VI – Basic Extended Reporting Period............................................... 12  Section VII – General Conditions ................................................................. 13  2.  Duties in the event of occurrence, offence claim or suit  1.  Bankruptcy  Legal Action Against Us  3.  4.  Other Insurance  Premium Audit  5.  6.  Representations  7.  8.  9.  Cancellation  11.  Changes  Separation of Named Insureds  Transfer of Rights of Recovery Against Others to Us  10.  Your Right to Claim and Occurrence Information  12.  Examination of Your Books and Records  13.  Inspections and Surveys  14.  Premiums  15.  Transfer of Your Rights and Duties Under This Policy  16.  Applicable Law  17.  Condition Precedent  Premium Payment Warranty........................................................................ 17  Chubb  Advantage Exporter’s Liability  (Claims-Made)  Policy Wording. Singapore. Published  04/2016.  © 2016 Chubb.  Coverages underwritten  by one  or more subsidiary companies.  Not all coverages  available in all jurisdictions. Chubb®  and its respective  logos, and Chubb.  Insured.SM  are protected  trademarks of Chubb.  5  6  8  13  13  14  14  15  15  15  15  15  16  16  16  16  16  16  17  17
# PASS
#   Contracts (Rights Of Third Parties) Act 2001 Exclusion .................................. 17  Electronic Media Endorsement ....................................................................18  Intellectual Property Rights Exclusion ..........................................................18  Memo A – Known Claims Or Circumstances Exclusion...................................18  Product Warranties/Guarantees Exclusion....................................................18  Products Efficacy Exclusion ......................................................................... 19  Professional Liability Exclusion.................................................................... 19  Punitive Damage Exclusion.......................................................................... 19  Supplementary Payment Amendment ........................................................... 19  Terrorism Exclusion Endorsement ............................................................... 19  Warranted that products conform to National Standards ................................ 19  Contact Us ................................................................................................ 20  About Chubb in Singapore .......................................................................... 20                        Chubb  Advantage Exporter’s Liability  (Claims-Made)  Policy Wording. Singapore. Published  04/2016.  © 2016 Chubb.  Coverages underwritten  by one  or more subsidiary companies.  Not all coverages  available in all jurisdictions. Chubb®  and its respective  logos, and Chubb.  Insured.SM  are protected  trademarks of Chubb.
# 20 False
#
# Project Property Exclusion. (SC_BFSG1607.PPE.1).pdf
# COUNT 153
# Travelling To and From Work (on Public Transport) (SC_WG_SG1412.TWPT.1).pdf
# COUNT 154
# Approved Adjuster Assessor (SC_HREL1603.AAA.1).pdf
# COUNT 155
# Public Liability Exclusion (SC_HREL1603.PLE.1).pdf
# COUNT 156
# Blood Products Exclusion (SC_HREL1603.BPE.1).pdf
# COUNT 157
# CYBER1A Data Risk and Cyber Liability Exclusion (SC_BFSG1607.CYBER1A.1).pdf
# COUNT 158
# Vehicle Use Exclusion (SC_BFSG1607.VUE.1).pdf
# COUNT 159
# CYBER3B Personal and Corporate Data Breach Writeback (SC_BFSG1607.CYBER3B.1).pdf
# COUNT 160
# Social, Recreational Activities (WCSO01) (SC_WG_SG1412.SRA1.1).pdf
# COUNT 161
# Contractors Indemnity Liability - Banyan Tree Global Guard Policies 20190201.pdf
# COUNT 162
# 2 False
#
# Public Liability Exclusion. (SC_BFSG1607.PBLE.1).pdf
# COUNT 163
# Traditional Chinese Medicine Extension (WGSG00019) (SC_WGPP_SG0416.19A.1).pdf
# COUNT 164
# Organophosphates Exclusion (SC_BFSG1607.OPHOS.1).pdf
# COUNT 165
# Liquor Liability (SC_BFSG1607.LL.1).pdf
# COUNT 166
# Keppel Shipyard Endorsement (Shipyard) (WGSG00020) (SC_WGPP_SG0416.20.1).pdf
# COUNT 167
# 2 False
#
# Fire or Explosion (SC_BFSG1607.FOE.1).pdf
# COUNT 168
# Demolition Exclusion (SC_HREL1603.DME.1).pdf
# COUNT 169
# Care Custody and Control Extension 4.3(d)(ii)(Amended) (SC_BFSG1607.CCCD2.1).pdf
# COUNT 170
# Foetal Alcohol Spectrum Disorders Exclusion (SC_BFSG1607.FASDE.1).pdf
# COUNT 171
# Cellular EMF EMR Exclusion (SC_BFSG1607.CEMFR.1).pdf
# COUNT 172
# Chubb Marine Services Liability Policy Form (Chubb_MSL_SG1511).pdf
# COUNT 173
# 20 False
#
# Property Worked Upon Extension (SC_BFSG1607.PWUE.1).pdf
# COUNT 174
# S&A Pollution USA_Canada Sub-Limit (Named Perils, 72 Hours) (SC_BFSG1607.SAPUCSLNP72.1).pdf
# COUNT 175
# Named Affiliates Endorsement (SC_BFSG1607.NAE.1).pdf
# COUNT 176
# Pharmaceutical or Herbaceutical Exclusion (SC_BFSG1607.PHE.1).pdf
# COUNT 177
# CYBER3A Personal Data Breach Writeback (SC_GGSG1409.CYBER3A.1).pdf
# COUNT 178
# Non-Contribution Clause (SC_BFSG1607.NCC.1).pdf
# COUNT 179
# EMF EMR Exclusion (SC_HREL1603.EMFRE.1).pdf
# COUNT 180
# Social Recreational Acitivities (WGSG00002) (SC_WG_SG1412.02.1).pdf
# COUNT 181
# Legionnaires Disease Exclusion (SC_HREL1603.LDE.1).pdf
# COUNT 182
# Repatriation Expenses Benefit (WGSG00026) (SC_WGPP_SG0416.26.1).pdf
# COUNT 183
# Spray Drift Exclusion (SC_BFSG1607.SDE.1).pdf
# COUNT 184
# Latex Exclusion (SC_HREL1603.LTXE.1).pdf
# COUNT 185
# Waiver of Subrogation (SC_WGPP_SG0416.WVS.1).pdf
# COUNT 186
# Intellectual Property Rights or Laws Exclusion. (SC_BFSG1607.IPRLE.1).pdf
# COUNT 187
# Marine Liability Exclusion - Gulf Asia GG1409 70552245.pdf
# COUNT 188
# CLAIMS MADE TRIGGER ENDT (SC_WG_SG1412.CMT.1).pdf
# COUNT 189
# 2 False
#
# CYBER1A Data Risk and Cyber Liability Exclusion (SC_GGSG1409.CYBER1A.1).pdf
# COUNT 190
# Sembcorp Jurong Shipyard Endorsement (SHIPYARD) (WGSG00012) (SC_WGPP_SG0416.12.1).pdf
# COUNT 191
# Entertainers' Liability (SC_HREL1603.ENL.1).pdf
# COUNT 192
# Communicable Disease Exclusion - Scheduled Activities Only (SC_GGSG1409.CDESA.1).pdf
# COUNT 193
# Foetal Child Alcohol Injury Exclusion (SC_BFSG1607.FCAIE.1).pdf
# COUNT 194
# Care Custody and Control Extension 4.9(e) (Amended) -(SC_HREL1603.CCCE.1).pdf
# COUNT 195
# Specified Substances Exclusion (SC_BFSG1607.SSE.1).pdf
# COUNT 196
# Contingent Liability to Independent Contractors (WGSG00001) (SC_WGPP_SG0416.01.1).pdf
# COUNT 197
# Travelling To and From Work (Excluding Meal Breaks) (WCTR04) (SC_WG_SG1412.TR04.1).pdf
# COUNT 198
# Pharmaceutical or Herbaceutical Exclusion (SC_BFSG1607.PHE.2).pdf
# COUNT 199
# Live Animals Exclusion (SC_BFSG1607.LAE.2).pdf
# COUNT 200
# Social, Rectreational Activities (Within Singapore and Malaysia) (WCSO02) (SC_WGPP_SG0416.SRA.1).pdf
# COUNT 201
# Waiver of Subrogation (Principals) (WGSG00025)(SC_WG_SG1412.WSP.1).pdf
# COUNT 202
# Tobacco and Non-Tobacco Products Health Exclusion (SC_BFSG1607.TNTPHE.1).pdf
# COUNT 203
# VWRS Endorsement (Sub-Limit) (SC_BFSG1607.VWRSESL.1).pdf
# COUNT 204
# 2 False
#
# Contractual Liability Extension (Designated Contract) (SC_HREL1603.CLEDC.1).pdf
# COUNT 205
# Premium Payment Warranty (60 Days) (SC_HREL1603.PPW60.1).pdf
# COUNT 206
# 120-Day Policy Period Extension Option (SC_BFSG1607.120.1).pdf
# COUNT 207
# VWRS Endorsement (Aggregate Sub-Limit) (SC_BFSG1607.VWRS-ASL.1).pdf
# COUNT 208
# 2 False
#
# Travel to and From Work Extension - including 2 wheelers (SC_WGPP_SG0416.TFW.1).pdf
# COUNT 209
# Claims Made Basis (SC_BFSG1607.CMB.1).pdf
# COUNT 210
# Movement of Person (Personal Injury) Exclusion (SC_BFSG1607.MPPIE.1).pdf
# COUNT 211
# CYBER1C Cyber Liability Exclusion (SC_BFSG1607.CYBER1C.1).pdf
# COUNT 212
# Pharmaceutical Herbaceutical Exclusion. (SC_BFSG1607.PMHBE.1).pdf
# COUNT 213
# Additional Insured (SHIPYARD) (SC_BFSG1607.AISY.1).pdf
# COUNT 214
# 3 True
#
# Business Disruption Assistance Benefits (WGSG00018) (SC_WG_SG1412.18A.1).pdf
# COUNT 215
# Event Endorsement (SC_HREL1603.EE.1).pdf
# COUNT 216
# Terrorism Exclusion (Deleted) (SC_BFSG1607.TED.1).pdf
# COUNT 217
# CYBER1B Data Risk Exclusion (SC_BFSG1607.CYBER1B.1).pdf
# COUNT 218
# Performers and Crew Exclusion. (SC_BFSG1607.PCE.1).pdf
# COUNT 219
# Pollution Exclusion (Total) (SC_BFSG1607.PET.1).pdf
# COUNT 220
# CYBER4A Personal Data Breach and Cyber Attack Writeback (SC_GGSG1409.CYBER4A.1).pdf
# COUNT 221
# 2 False
#
# Traditional Chinese Medicine Extension (WGSG00019) (SC_WGPP_SG0416.19.1).pdf
# COUNT 222
# Failure Collapse of Temporary Structure Exclusion (SC_BFSG1607.FCTSE.1).pdf
# COUNT 223
# Robbery or Burglary (Sub-Limit) (SC.BF20RBSL.1).pdf
# COUNT 224
# Non-Contribution Clause (Other CAR or EAR Insurances) (SC_BFSG1607.NCCCAREAR.1).pdf
# COUNT 225
# Employer's Liability Extension (Specified Nationalities, Jurisdiction, Excess) (SC_BFSG1607.ELE-SNJXS.1).pdf
# COUNT 226
# Blasting and Explosives Exclusion (SC_HREL1603.BEE.1).pdf
# COUNT 227
# Waiver of Subrogation (For Contract) (SC_WGPP_SG0416.WVS.1).pdf
# COUNT 228
# Event Endorsement. (SC_BFSG1607.EVE.1).pdf
# COUNT 229
# Lithium Ion Batteries Exclusion (SC_BFSG1607.LIBE.1).pdf
# COUNT 230
# Part-Timers Temporary Contract Employees (WGSG00006) (SC_WG_SG1412.06.1).pdf
# COUNT 231
# CYBER3A Personal Data Breach Writeback (SC_BFSG1607.CYBER3A.1).pdf
# COUNT 232
# Business Disruption Assistance Benefits (WGSG00018) (SC_WG_SG1412.18.1).pdf
# COUNT 233
# E-Cigarettes Exclusion (SC_BFSG1607.ECE.1).pdf
# COUNT 234
# Food and Drinks (SC_GGSG1409.FD.1).pdf
# COUNT 235
# Overseas Medical Expense (WGSG00017) (SC_WG_SG1412.17A.1).pdf
# COUNT 236
# Breach of Conditions or Warranties (SC_BFSG1607.BCW.1).pdf
# COUNT 237
# Contingent Liability for Concessionaires (SC_BFSG1607.CLC.1).pdf
# COUNT 238
# Sembcorp Jurong Shipyard Endorsement (SHIPYARD) (WGSG00012) (SC_WG_SG1412.12.1).pdf
# COUNT 239
# Overseas Medical Expense (WGSG00017) (SC_WGPP_SG0416.17.1).pdf
# COUNT 240
# W216 Indemnity to Principals (WGSG00016) (SC_WGPP_SG0416.16.1).pdf
# COUNT 241
# EMF_EMR Endorsement (SC_BFSG1607.EMFEMRE.1).pdf
# COUNT 242
# Exchange Rate Clause. (SC_BFSG1607.ERC.1).pdf
# COUNT 243
# Non Contribution Clause ( WGSG00005) (SC_WG_SG1412.05.1).pdf
# COUNT 244
# CYBER2 Cyber Attack Writeback (SC_BFSG1607.CYBER2.1).pdf
# COUNT 245
# Pyrotechnics and Explosives Exclusion (SC_HREL1603.PEE.1).pdf
# COUNT 246
# Trainee Clause (WGSG00008) (SC_WG_SG1412.08.1).pdf
# COUNT 247
# Business Disruption Assistance Benefits (WGSG00018) (SC_WGPP_SG0416.18.1).pdf
# COUNT 248
# Communicable Disease Exclusion - Scheduled Activities Only (SC_BFSG1607.CDE-SAO.1).pdf
# COUNT 249
# Products Recall Expense (PRE) Extension (SC_HREL1603.PRE.1).pdf
# COUNT 250
# 2 False
#
# Communicable Disease Exclusion (Blanket) (SC_HREL1603.CDEB.1).pdf
# COUNT 251
# Principal's Existing Property Endorsement (Sub-Limit) (SC_BFSG1607.PEPESL.1).pdf
# COUNT 252
# Employer's Liability Extension (Specified Jurisdiction, Sub-Limit) (SC_BFSG1607.ELE-SJSL.1).pdf
# COUNT 253
# Communicable Disease Exclusion (Blanket) (SC_BFSG1607.CDE-B.1).pdf
# COUNT 254
# Plant and Machinery (Including Cranes, Elevators, Escalators, Hoists, Lifts) (SC_HREL1603.PM.1).pdf
# COUNT 255
# Non-Insured's Goods Products Services Exclusion (SC_BFSG1607.NIGPS.1).pdf
# COUNT 256
# 30 Days Cancellation (WGSG00009) (SC_WG_SG1412.09.1).pdf
# COUNT 257
# Failure to Supply Exclusion. (SC_BFSG1607.FSE.1).pdf
# COUNT 258
# Waiver of Subrogation (Principals). (SC_BFSG1607.WSP.1).pdf
# COUNT 259
# Private Work for Directors and Executives (SC_BFSG1607.PWDE.1).pdf
# COUNT 260
# Traditional Chinese Medicine (TCM) Extension (SC_WG_SG1412.TCM.1).pdf
# COUNT 261
# Food and Drinks (Sub-Limit) (SC_BFSG1607.FDSL.1).pdf
# COUNT 262
# 24-Hours Cover On Worldwide Business Travel (WGSG00004) (SC_WG_SG1412.04.1).pdf
# COUNT 263
# Concussion Injury Endorsement (SC_BFSG1607.CIE.1).pdf
# COUNT 264
# Tobacco Products (Manufacturers) Exclusion (SC_HREL1603.TPME.1).pdf
# COUNT 265
# Extended Period Agreement (rev) (SC_XOL1701_EPA.1).pdf
# COUNT 266
# 2 False
#
# Plant and Machinery (Including Cranes, Elevators, Escalators, Hoists, Lifts) (SC_BFSG1607.PM.1).pdf
# COUNT 267
# Business Disruption Assistance Benefits Extension (WGSG00024) (SC_WG_SG1412.24.1).pdf
# COUNT 268
# Design Exclusion. (SC_BFSG1607.DE.1).pdf
# COUNT 269
# Electronic Data Exclusion (SC_BFSG1607.EDE.1).pdf
# COUNT 270
# Premium Payment Warranty (90 Days) (SC_BFSG1607.PPW90.1).pdf
# COUNT 271
# Care, Custody and Control Extension (Deleted and Replaced) (SC_BFSG1607.CCCDR.1).pdf
# COUNT 272
# CHEMICALS List A Materials Exclusion (SC_BFSG1607.CLAME.1).pdf
# COUNT 273
# Excess Motor Liability Extension (Owned, Hired or Non-Owned) - Non-Owned Sub-Limit (SC_BFSG1607.EMLNOSL.1).pdf
# COUNT 274
# 2 False
#
# Cross Liability Clause (WGSG00024) (SC_WGPP_SG0416.CLC.1).pdf
# COUNT 275
# Overseas Medical Expense (WGSG00017) (SC_WG_SG1412.17.1).pdf
# COUNT 276
# Change of Business Description Endorsement (SC_BFSG1607.CBDE.1).pdf
# COUNT 277
# Melamine Exclusion (SC_BFSG1607.ME.1).pdf
# COUNT 278
# Demostrations and Exhibitions (SC_HREL1603.DE.1).pdf
# COUNT 279
# Communicable Disease Exclusion - Scheduled Activities Only (SC_MSL_SG1511.CDESA.1).pdf
# COUNT 280
# Performers and Crew Exclusion (SC_HREL1603.PCE.1).pdf
# COUNT 281
# Specified Sub-Limits (SC_BFSG1607.SSL.1).pdf
# COUNT 282
# GMO Exclusion (SC_HREL1603.GMOE.1).pdf
# COUNT 283
# Contractual Liability Extension (Blanket) (SC_BFSG1607.CLEB.1).pdf
# COUNT 284
# Neon and Advertising Signs. (SC_BFSG1607.NAS.1).pdf
# COUNT 285
# Latex Exclusion. (SC_BFSG1607.LTXE.1).pdf
# COUNT 286
# Non-Immediate Medical Attention (WGSG00015) (SC_WG_SG1412.15.1).pdf
# COUNT 287
# Non-Contribution Clause (Other Insurances) (SC_BFSG1607.NCCOI.1).pdf
# COUNT 288
# Social, Recreational Activities (WCSO01) (SC_WGPP_SG0416.SRA.1).pdf
# COUNT 289
# Self Insured Retention (SIR) (SC_BFSG1607.SIR.1).pdf
# COUNT 290
# Abuse Exclusion (SC_BFSG1607.AE.10).pdf
# COUNT 291
# Contractual Liability Extension (Blanket) (SC_HREL1603.CLEB.1).pdf
# COUNT 292
# Employer's Liability Extension (Specified Jurisdiction) (SC_BFSG1607.ELE-SJ.1).pdf
# COUNT 293
# Approved Adjuster Assessor (SC_BFSG1607.AAA.1).pdf
# COUNT 294
# Participation Exclusion (SC_HREL1603.PE.1).pdf
# COUNT 295
# Insured Drone Extension (Thailand) (SC_BFSG1607.IDETH.1).pdf
# COUNT 296
# 2 False
#
# Blasting and Explosives Exclusion (SC_BFSG1607BEE.1).pdf
# COUNT 297
# Contingent Liability for Concessionaires (Aggregate Sub-Limit) (SC_BFSG1607.CLCASL.1).pdf
# COUNT 298
# Liquor Liability (F&B) (SC_BFSG1607.LLFB.1).pdf
# COUNT 299
# Oil Industry Limitation Endorsement (SC_HREL1603.OILE.1).pdf
# COUNT 300
# Trainee Endorsement (WCTR02)(SC_WG_SG1412.TR02.1).pdf
# COUNT 301
# Entertainment Performers and Crew Exclusion (SC_BFSG1607.EPCE.1).pdf
# COUNT 302
# Claims Co-operation Clause (Reinsurance) - REGIONAL TEMPLATE 20160908 (SC_BFSG1607.CCCRI.1).pdf
# COUNT 303
# Additional Insured Clause (SC_BFSG1607.AIC.1).pdf
# COUNT 304
# Efficacy Exclusion (Unintentional Defect). (SC_BFSG1607.EEUD.1).pdf
# COUNT 305
# Working Load Limit Exclusion (SC_BFSG1607.WLLE.1).pdf
# COUNT 306
# Excess Motor Liability Extension (Owned, Hired or Non-Owned) (SC_BFSG1607.EMLE.1).pdf
# COUNT 307
# 2 False
#
# W216 Indemnity to Principals (WGSG00016) (SC_WG_SG1412.16.1).pdf
# COUNT 308
# Chubb Offshore Liability Wording (Chubb_OFF_SG1511).pdf
# COUNT 309
# 21 False
#
# Premium Adjustment Clause (Contract Value) (SC_BFSG1607.PACCV.1).pdf
# COUNT 310
# Underground Facilities Condition Precedent. (SC_BFSG1607.UGFCP.1).pdf
# COUNT 311
# Waiver of Subrogation (Named Affiliates) (SC_BFSG1607.WSNA.1).pdf
# COUNT 312
# Care, Custody and Control Extension 4.3(d)(ii) (Amended) (SC_BFSG1607.CCCE4.3Dii.1).pdf
# COUNT 313
# Non-Invalidation (SC_BFSG1607.NIV.1).pdf
# COUNT 314
# Non Contribution Clause (WGSG00005) (SC_WGPP_SG0416.05.1).pdf
# COUNT 315
# Travelling To and From Work (Including Meal Breaks) (WCTR01)(SC_WG_SG1412.TR01.1).pdf
# COUNT 316
# Extended Period Agreement (2 Years) (SC_BFSG1607.EPA2Y.1).pdf
# COUNT 317
# 2 False
#
# Fire and Explosion. (SC_BFSG1607.FE.1).pdf
# COUNT 318
# Employer's Liability Extension. (SC_BFSG1607.ELE.1).pdf
# COUNT 319
# 2 False
#
# Non-Invalidation (SC_HREL1603.NI.1).pdf
# COUNT 320
# Aviation Exclusion (SC_HREL1603.AE.1).pdf
# COUNT 321
# Principals Indemnity (SC_BFSG1607.PLSI.1).pdf
# COUNT 322
# Errors and Omissions (Claims Made and Notified) Endorsement. (SC_BFSG1607.EOCMN.1).pdf
# COUNT 323
# 2 False
#
# Contingent Liability For Contractors And Sub-Contractors (Sub-Limit) (SC_BFSG1607.CLCSCSL.1).pdf
# COUNT 324
# HIV Aids and Blood Borne Diseases Exclusion (SC_HREL1603.HIVABD.1).pdf
# COUNT 325
# Legionnaires Disease Exclusion. (SC_BFSG1607.LEGDE.1).pdf
# COUNT 326
# Liquor Liability Clause (Hotel Operations). (SC_BFSG1607.LLCHO.1).pdf
# COUNT 327
# Claims Made Basis (Products Liability Only) – WMI, WCC (Ghim Li Global Pte Ltd (70552152PR)).pdf
# COUNT 328
# Failure to Supply (Loss of Use) Exclusion (SC_HREL1603.FSLU.1).pdf
# COUNT 329
# Action Over Indemnity Extension - Strategic Marine 70554239 DRAFT 20200214.pdf
# COUNT 330
# 30-Day Policy Period Extension Option (SC_BFSG1607.30.1).pdf
# COUNT 331
# 2 False
#
# Contingent Liab for Independent Cons (SHIPYARD) (WGSG00011)  (SC_WGPP_SG0416.11.1).pdf
# COUNT 332
# Terrorism Exclusion (SC_WG_SG1412.TRXC.1).pdf
# COUNT 333
# Communicable Disease Exclusion - Scheduled Activities Only (SC_UMB_SG1604.CDESA.1).pdf
# COUNT 334
# Known Claims or Circumstances Exclusion (SC_BFSG1607.KCCE.1).pdf
# COUNT 335
# Tanning (Personal Injury) Exclusion (SC_BFSG1607.TPIE.1).pdf
# COUNT 336
# Animal Diseases Exclusion (SC_BFSG1607.ADE.1).pdf
# COUNT 337
# Silica, Dust, and Particulate Matter Exclusion (SC_BFSG1607.SDPME.1).pdf
# COUNT 338
# Offshore Industry Limitations (SC_BFSG1607.OSIL.1).pdf
# COUNT 339
# Organophosphates Exclusion (SC_HREL1603.OE.1).pdf
# COUNT 340
# Approved or Nominated Adjusters Assessors (SC_BFSG1607.ANAA.1).pdf
# COUNT 341
# Tobacco Health Exclusion (SC_BFSG1607.TBHE.1).pdf
# COUNT 342
# Chubb Excess Liability Follow Form (Chubb_ XOL1701.2).pdf
# COUNT 343
# PASS
#                   Contents  Important Notices........................................................................................ 3  Your Duty of Disclosure........................................................................... 3  Consequences of Non-Disclosure ............................................................. 3  Subrogation ........................................................................................... 3  Policy Schedule............................................................................................ 4  Policy Wording ............................................................................................ 5  Insuring Agreement ................................................................................ 5  Definitions ............................................................................................. 6  Exclusions.............................................................................................. 8  Conditions ............................................................................................10  Endorsements ............................................................................................ 13  Terrorism Exclusion .............................................................................. 13  Endorsement Title ................................................................................. 13  Privacy Statement ....................................................................................... 14  About Chubb in Singapore ........................................................................... 15  Contact Us ................................................................................................. 15  Chubb  Excess Liability Policy Wording. Singapore.  Published 1/2017.  © 2017 Chubb.  Coverages underwritten  by one or more subsidiary companies.  Not all coverages  available in all jurisdictions. Chubb®  and its respective  logos, and Chubb.  Insured.TM  are protected  trademarks of Chubb.
# 15 False
#
# Movement of Person Exclusion (SC_BFSG1607.MPE.1).pdf
# COUNT 344
# Claims Made Basis (Products Liability Only) – for others not WMI, WCC (Ghim Li Global Pte Ltd (70552152PR)).pdf
# COUNT 345
# Extended Period Agreement (SC_HREL1603.EPA.1).pdf
# COUNT 346
# 2 False
#
# Non Resident Employees Voluntary Extension (WGSG00003) (SC_WG_SG1412.03.1).pdf
# COUNT 347
# 2 False
#
# Contingent Liab for Independent Cons (SHIPYARD) (WGSG00011) (SC_WG_SG1412.11.1).pdf
# COUNT 348
# CYBER4B Personal and Corporate Data Breach and Cyber Attack Writeback (SC_BFSG1607.CYBER4B.1).pdf
# COUNT 349
# 2 False
#
# Non-Contribution Clause (SC_HREL1603.NCC.1).pdf
# COUNT 350
# Professional Liability (Total) Exclusion (SC_BFSG1607.PLTE.1).pdf
# COUNT 351
# Approved Adjusters Assessors (Default And Nominated) (SC_BFSG1607.AAADN.1).pdf
# COUNT 352
# CYBER2 Cyber Attack Writeback (SC_GGSG1409.CYBER2.1).pdf
# COUNT 353
# Drugs Exclusion. (SC_BFSG1607.DRGE.1).pdf
# COUNT 354
# Chubb As Subscribing Insurer (SC_BFSG1607.CSI.1).pdf
# COUNT 355
# Efficacy Exclusion. (SC_BFSG1607.EE.1).pdf
# COUNT 356
# Contingent Liability for Concessionaires (Sub-Limit) (SC_BFSG1607.CLCSL.1).pdf
# COUNT 357
# E-Cigarettes Health Exclusion (SC_BFSG1607.ECHE.1).pdf
# COUNT 358
# Vendor's Liability Extension. (SC_BFSG1607.VLE.1).pdf
# COUNT 359
# Waiver of Subrogation (SHIPYARD) (WGSG00013) (SC_WG_SG1412.13.1).pdf
# COUNT 360
# Excess Motor Liability Extension (Owned, Hired or Non-Owned) (ASEAN) (SC_BFSG1607.EMLE-ASEAN.1).pdf
# COUNT 361
# 2 False
#
# Working Load Limit Exclusion (SC_HREL1603.WLLE.1).pdf
# COUNT 362
# VWRS Exclusion (SC_BFSG1607.VWRSX.1).pdf
# COUNT 363
# Cancellation (60 Days) (SC_BFSG1607.C60D.1).pdf
# COUNT 364
# Breach of Warranties (SC_BFSG1607.BOW.1).pdf
# COUNT 365
# Chubb WorkGuard Wording (Project PAT) (Chubb_WG_SG1912).pdf
# COUNT 366
# PASS
#                     Contents  Important Notices........................................................................................ 3  Chubb Work Guard Policy ............................................................................ 4  Details of Employees Covered ....................................................................... 5  Chubb Work Guard Insurance Policy Wording................................................ 6  Chubb Work Guard Compensation Insurance Policy Clauses .......................... 11  Appendix 1: Attaching to and forming part of Policy Number XXXX  ................ 14  About Chubb in Singapore ........................................................................... 17  Contact Us ................................................................................................. 17  Chubb  Work Guard Insurance  Policy Schedule  and Wording. Singapore.  Published  12/2019.  © 2019 Chubb.  Coverages underwritten  by one  or more subsidiary companies.  Not all coverages  available in all jurisdictions. Chubb®  and its respective  logos, and Chubb.  Insured.TM  are protected  trademarks of Chubb.
# 17 False
#
# Communicable Disease Exclusion - Scheduled Activities Only (SC_HREL1603.CDESA.1).pdf
# COUNT 367
# Failure to Supply Exclusion (SC_HREL1603.FSE.1).pdf
# COUNT 368
# Chubb Broadform Liability Policy Form BF20_SG.pdf
# COUNT 369
# PASS
#                   Contents  Important Notices........................................................................................ 3  Your Duty of Disclosure........................................................................... 3  Consequences of Non-Disclosure ............................................................. 3  Subrogation ........................................................................................... 3  Policy Schedule............................................................................................ 4  Policy Wording ............................................................................................ 5  Insuring Agreement ................................Error! Bookmark not defined.  Definitions ............................................................................................. 5  Exclusions.............................................................................................. 9  Extensions ............................................................................................ 12  Conditions ............................................................................................ 14  Endorsements ............................................................................................ 17  Terrorism Exclusion ...............................Error! Bookmark not defined.  Endorsement Title ..................................Error! Bookmark not defined.  Privacy Statement .......................................................................................18  Contact Us ................................................................................................. 19  About Chubb in Singapore ........................................................................... 19  Chubb  Broadform Liability Policy Wording. Singapore.  Published  Feb 2020.  © 2020 Chubb.  Coverages underwritten  by one or more subsidiary companies.  Not all coverages  available in all jurisdictions. Chubb®  and its respective  logos, and Chubb.  Insured.TM  are protected  trademarks of Chubb.
# 19 False
#
# Employer's Liability Extension (SC_HREL1603.ELE.1).pdf
# COUNT 370
# 2 False
#
# Blasting & Explosives Exclusion (SC_BFSG1607.BEE.1).pdf
# COUNT 371
# Known Claims or Circumstances Exclusion (SC_HREL1603.KCCE.1).pdf
# COUNT 372
# Aviation Exclusion (SC_BFSG1607.AVE.1).pdf
# COUNT 373
# PCB Exclusion. (SC_BFSG1607.PCBE.1).pdf
# COUNT 374
# PPL Shipyard Endorsement (Shipyard) (WGSG00021) (SC_WG_SG1412.21.1).pdf
# COUNT 375
# 2 False
#
# Construction Property Exclusion (SC_BFSG1607.CPE.1).pdf
# COUNT 376
# Communicable Disease Exclusion (Blanket) (SC_MSL_SG1511.CDEB.1).pdf
# COUNT 377
# Motor Liability Exclusion (SC_BFSG1607.MLE.1).pdf
# COUNT 378
# CYBER3B Personal and Corporate Data Breach Writeback (SC_GGSG1409.CYBER3B.1).pdf
# COUNT 379
# Products Recall Expense Endorsement (SC_BFSG1607.PREE.1).pdf
# COUNT 380
# 2 False
#
# Keppel Shipyard Endorsement (Shipyard) (WGSG00020) (SC_WG_SG1412.20.1).pdf
# COUNT 381
# 2 False
#
# PPL Shipyard Endorsement (Shipyard) (WGSG00021)(SC_WGPP_SG0416.21.1).pdf
# COUNT 382
# 2 False
#
# Failure to Supply (SC_BFSG1607.FTS.1).pdf
# COUNT 383
# Contractual Liability Extension (Designated Contract) (SC_BFSG1607.CLEDC.1).pdf
# COUNT 384
# Specified Ingredients_Substances Exclusion (SC_BFSG1607.SISE.1).pdf
# COUNT 385
# 60-Day Policy Period Extension Option (SC_BFSG1607.60.1).pdf
# COUNT 386
# Extended Period Agreement. (SC_BFSG1607.EPA.1).pdf
# COUNT 387
# 2 False
#
# Neon or Advertising Signs (SC_BFSG1607.NAS.1).pdf
# COUNT 388
# 90-Day Policy Period Extension Option (SC_BFSG1607.90.1).pdf
# COUNT 389
# Cross Liability Clause (WGSG00024) (SC_WG_SG1412.CLC.1).pdf
# COUNT 390
# Vocation Training (WGSG00007) (SC_WG_SG1412.07.1).pdf
# COUNT 391
# Contingent Liability For Contractors And Sub-Contractors (SC_BFSG1607.CLCSC.1).pdf
# COUNT 392
# Waiver of Subrogation (SC_BFSG1607.WS.1).pdf
# COUNT 393
# Indemnity to Specified Principals Extension (SC_BFSG1607.ISPE.1).pdf
# COUNT 394
# Cellular EMF EMR Exclusion (SC_HREL1603.CEMFR.1).pdf
# COUNT 395
# Traditional Chinese Medicine Extension (WGSG00019) (SC_WG_SG1412.19A.1).pdf
# COUNT 396
# Advertising Liability Endorsement (SC_BFSG1607_ALE.1).pdf
# COUNT 397
# 2 False
#
# Injury to Contractors and Sub-Contractors Exclusion (SC_BFSG1607.ICSCE.1).pdf
# COUNT 398
# WC24HRS - 24 Hours Cover on Worldwide Business Travel (SC_WGPP_SG0416.C24.1).pdf
# COUNT 399
# Care Custody or Control (Including Innkeeper's and Valet Liability) Extension (SC_BFSG1607.CCCIKVLE.1).pdf
# COUNT 400
# Pharmaceutical Herbaceutical Exclusion (SC_HREL1603.PHE.1).pdf
# COUNT 401
# Care, Custody and Control Exclusion (SC_BFSG1607.CCCX.1).pdf
# COUNT 402
# Loss Notification (Unexpected and Inadvertent Delay). (SC_BFSG1607.LN.1).pdf
# COUNT 403
# Demolition Exclusion (SC_BFSG1607.DEME.1).pdf
# COUNT 404
# Oil Industry Limitation Endorsement (SC_BFSG1607.OILE.1).pdf
# COUNT 405
# Underground Property Damage Exclusion (SC_BFSG1607.UPDEX.1).pdf
# COUNT 406
# Social, Rectreational Activities (Within Singapore and Malaysia) (WCSO02) (SC_WG_SG1412.SRA2.1).pdf
# COUNT 407
# Professional Services (Including Professional Healthcare Services) Exclusion (SC_BFSG1607.PSE.1).pdf
# COUNT 408
# Medical Expenses Extension - BF20.pdf
# COUNT 409
# Design Exclusion (SC_HREL1603.DSE.1).pdf
# COUNT 410
# Medical Expenses Extension. (SC_BFSG1607.MEE.1).pdf
# COUNT 411
# Failure Collapse of Temporary Structure Exclusion (SC_HREL1603.FCTS.1).pdf
# COUNT 412
# Misdescription (SC_HREL1603.MD.1).pdf
# COUNT 413
# Tailings Dams Exclusion (SC_BFSG1607.TDE.1).pdf
# COUNT 414
# Travelling to and from Work inc. meal breaks (inc. two wheelers) (WGSG00014) (SC_WGPP_SG0416.14.1).pdf
# COUNT 415
# Non-Immediate Medical Attention (SC_WGPP_SG0416.15.1) (WGSG00015).pdf
# COUNT 416
# HIV Aids and Blood Borne Diseases Exclusion. (SC_BFSG1607.HIVBD.1).pdf
# COUNT 417
# Errors & Omissions Endorsement (SC_BFSG1607.EOE.1).pdf
# COUNT 418
# 3 False
#
# Employer's Liability Extension (Specified Jurisdiction, Sub-Limit, Excess) (SC_BFSG1607.ELE-SJSLXS.1).pdf
# COUNT 419
# Sexual Abuse Exclusion. (SC_BFSG1607.SAME.1).pdf
# COUNT 420
# Vocation Training (WGSG00007) (SC_WGPP_SG0416.07.1).pdf
# COUNT 421
# Several Liability Clause (SC_BFSG1607.SLC.1).pdf
# COUNT 422
# Working Load Limit Exclusion. (SC_BFSG1607.WLLE.1).pdf
# COUNT 423
# Nose Coverage Endorsement (SC_BFSG1607.NCE.1).pdf
# COUNT 424
# High Risk Cosmetic or Recreational Services Exclusion (SC_BFSG1607.HRCRSE.1).pdf
# COUNT 425
# Blasting and Explosives Operations (SC_HREL1603.BEO.1).pdf
# COUNT 426
# Part-Timers Temporary Contract Employees (WGSG00006) (SC_WGPP_SG0416.06.1).pdf
# COUNT 427
# Premium Payment Warranty (60 Days) (SC_BFSG1607.PPW60.1).pdf
# COUNT 428
# Efficacy Exclusion (Unintentional Defect) (SC_HREL1603.EEUD.1).pdf
# COUNT 429
# Boiler And Pressure Vessel (SC_HREL1603.BPV.1).pdf
# COUNT 430
# Known Claims or Circumstances Exclusion (Specified Example) (SC_BFSG1607.KCCESE.1).pdf
# COUNT 431
# Communicable Disease Exclusion - Scheduled Activities Only (SC_OFF_SG1511.CDESA.1).pdf
# COUNT 432
# Travelling To and From Work (Excluding Motorcycle) (WCTR05) (SC_WG_SG1412.TR05.1).pdf
# COUNT 433
# Offshore Risks Limitations (SC_BFSG1607.ORL.1).pdf
# COUNT 434
# Travel to and From Work Extension - including 2 wheelers (SC_WG_SG1412.TFW.1).pdf
# COUNT 435
# Efficacy Exclusion (SC_HREL1603.EE.1).pdf
# COUNT 436
# Pharmaceutical Herbaceutical Exclusion (SC_HREL1603.PHE.2).pdf
# COUNT 437
# Travelling to and from Work inc. meal breaks (inc. two wheelers) (WGSG00014) (SC_WG_SG1412.14.1).pdf
# COUNT 438
# Not in Use - Chubb Excess Liability Wording (Chubb_EXL_SG1502).pdf
# COUNT 439
# PASS
#                     Contents  Contents ..................................................................................................... 2  Policy Schedule............................................................................................ 3  Policy Wording ............................................................................................ 4  The Company……………………………………………………………………………………….. 4  Insuring Agreements……………………………………………………………………………… 4  Definitions……………………………………………………………………………………………. 4  Exclusions ................................................................................................... 5  Nuclear Energy Liability Endorsement (Broad Form)……………………………….. 5  Asbestos……………………………………………………………………………………………….. 6  Conditions .................................................................................................. 7  1.  Payment of Costs…………………………………………………………………………… 7  2.  Maintenance of Primary Insurance…………………………………………………. 7  3.  Premium………………………………………………………………………………………. 7  4.  Right of Appeal………………………………………………………………………………8  Subrogation………………………………………………………………………………….. 8  5.  6.  Notification of Claims……………………………………………………………………. 8  Cancellation…………………………………………………………………………………..8  7.  8.  Condition Precedent……………………………………………………………………… 8  Premium Payment Warranty......................................................................... 9  Contracts (Rights of Third Parties) Act 2001 Exclusion.................................... 9  Terrorism Exclusion Endorsement ...............................................................10  Contact Us ................................................................................................. 11  About Chubb in Singapore ........................................................................... 11    Chubb  Excess Liability Insurance  Policy Schedule  and Wording. Singapore.  Published 04/2016.  © 2016 Chubb.  Coverages underwritten  by one  or more subsidiary companies.  Not all coverages  available in all jurisdictions. Chubb®  and its respective  logos, and Chubb.  Insured.SM  are protected  trademarks of Chubb.
# GPA Extension (SC_WGPP_SG0416.GPA.1).pdf
# COUNT 440
# Contingent Liability For Contractors And Sub-Contractors (Aggregate Sub-Limit) (SC_BFSG1607.CLCSCASL.1).pdf
# COUNT 441
# Terrorism Cover (WGSG00027) (SC_WG_SG1412.27.1).pdf
# COUNT 442
# Minor Alterations (SC_BFSG1607.MA.1).pdf
# COUNT 443
# Hot Work Exclusion (SC_BFSG1607.HWE.1).pdf
# COUNT 444
# Overseas Medical Expenses (WGSG00025) (SC_WG_SG1412.25.1).pdf
# COUNT 445
# Contractual Liability Extension (SC_BFSG1607.CL.1).pdf
# COUNT 446
# Travelling To and From Work (on Public Transport) (SC_WGPP_SG0416.TWP.1).pdf
# COUNT 447
# Underground Facilities Condition Precedent (SC_HREL1603.UFCP.1).pdf
# COUNT 448
# Food and Drinks (Aggregate Sub-Limit SGD300k) - Eng Hup Shipping 70550907 DRAFT 20190218.pdf
# COUNT 449
# Waiver of Subrogation (For Contract) (SC_WG_SG1412.WVSC.1).pdf
# COUNT 450
# Misdescription (SC_BFSG1607.MISD.1).pdf
# COUNT 451
# Formaldehyde Exclusion (SC_BFSG1607.FE.1).pdf
# COUNT 452
# Business Disruption Assistance Benefits Extension (WGSG00024) (SC_WGPP_SG0416.24.1).pdf
# COUNT 453
# Communicable Disease Exclusion (Blanket) (SC_GGSG1409.CDEB.1).pdf
# COUNT 454
# CYBER1B Data Risk Exclusion (SC_GGSG1409.CYBER1B.1).pdf
# COUNT 455
# Failure to Supply (Loss of Use) Exclusion. (SC_BFSG1607.FSLUE.1).pdf
# COUNT 456
# Terrorism Cover (WGSG00027) (SC_WGPP_SG0416.27.1).pdf
# COUNT 457
# Trainee Endorsement (WCTR02) (SC_WGPP_SG0416.TE.1).pdf
# COUNT 458
# Terrorism Liability Endorsement (SC_BFSG1607.TLE.1).pdf
# COUNT 459
# 2 False
#
# Travelling To and From Work (Excluding Motorcycle) (WCTR05) (SC_WGPP_SG0416.TR5.1).pdf
# COUNT 460
# Waiver of Subrogation (Specified Principals) (SC_BFSG1607.WSSP.1).pdf
# COUNT 461
# Vendor's Liability Extension (SC_HREL1603.VLE.1).pdf
# COUNT 462
# Terrorism Exclusion (SC_WGPP_SG0416.TRE.1).pdf
# COUNT 463
# Arms or Explosives Exclusion - Highland Security Services 70553756.pdf
# COUNT 464
# Drugs Exclusion (SC_HREL1603.DRGE.1).pdf
# COUNT 465
# Trainee Clause (WGSG00008) (SC_WGPP_SG0416.08.1).pdf
# COUNT 466
# Primary Insurance (SC_BFSG1607.PI.1).pdf
# COUNT 467
# Care Custody and Control Extension (Including Shipyard Risks) (SC_BFSG1607.CCCE.1).pdf
# COUNT 468
# Absolute Pollution Exclusion (SC_BFSG1607.APE.1).pdf
# COUNT 469
# Underwater Activites Apparatus or Mechanically-Propelled Water Sports Exclusion. (SC_BFSG1607.UWA.1).pdf
# COUNT 470
# PPL Shipyard Endorsement. (SC_BFSG1607.PPLS.1).pdf
# COUNT 471
# Employer's Liability Extension (Specified Nationalities, Sub-Limit) (SC_BFSG1607.ELE-SNSL.1).pdf
# COUNT 472
# Work From Home (WGSG00028) (SC_WG_SG1412.WFH.1).pdf
# COUNT 473
# Property Owner's Liability (SC_HREL1603.POL.1).pdf
# COUNT 474
# Labour Disturbance (SC_BFSG1607.LD.1).pdf
# COUNT 475
# Hot Work (SC_BFSG1607.HW.1).pdf
# COUNT 476
# 30 Days Cancellation (WGSG00009) (SC_WGPP_SG0416.09.1).pdf
# COUNT 477
# Employer's Liability Extension (Specified Nationalities, Jurisdiction) (SC_BFSG1607.ELE-SNJ.1).pdf
# COUNT 478
# Industry Standard Wording SUBDIR!!!!!!!!!!!!!
# Bespoke Wording SUBDIR!!!!!!!!!!!!!
# Bespoke Wording - Sakari Resources Limited - 70552448 PoI - 01-01-2019 to 31-12-2019.pdf
# COUNT 479
# 42 False

# %%
len(local_indexed)
# Out:
# 269

# %%
from azure.cosmos import exceptions, CosmosClient, PartitionKey

cosmo_endpoint="https://nf-poc-cdb-sql.documents.azure.com"
cosmo_key="iEcEfrxYe0Fm9QtoxDrOpLvGsfzjowwybULlWT9Uz4XxV4RmOIAnRuLdgRFUu1LPU5Vwk3UGivRrPrxnk7083w=="
client = CosmosClient(cosmo_endpoint, cosmo_key)
database=client.get_database_client('policy-analysis')
container=database.get_container_client('property-wordings')

# %%
for key,value in local_indexed.items():
    doc={}
    doc['text']=key
    doc['page']=int(value[1])
    if value[4]==True or value[0].find('Exclusion')!=-1:
        doc['IsExclusion']=True
    else:
        doc['IsExclusion']=False
    doc['doc_name']=value[0].replace('.pdf','')
    doc['id']=doc['doc_name']+' '+str(doc['page'])
    doc['bold_phrases']=value[2]
    doc['plain_text']=value[3]
    doc['excl_count']=value[5]
    doc['excl_pos']=value[6]
    doc['folder']=value[7]
    doc['definitions']=[{'name':key,'text':value} for key,value in re.findall('###(.*?)@@(.*?)%%%',doc['text'])]
    doc['country']=value[9]
    doc['language']=value[10]
    doc['definition_text']=value[11]
#     print(doc['definition_text'],'\n\n')
    if doc['definition_text']:
        doc['definition_flag']=True
    else:
        doc['definition_flag']=False
    if value[14]==True or 'endorsement' in value[0].lower(): 
        doc['endorsements']=True
    else:
        doc['endorsements']=value[13]
    doc['excl_text']=value[14]
    doc['cond_text']=value[15]
    doc['cond_flag']=value[16]
    doc['cond_count']=value[17]
    doc['cond_pos']=value[18]
    doc['definitions_in_page']=value[19]
    doc['ext_text']=value[20]
    doc['ext_flag']=value[21]
    doc['ext_count']=value[22]
    doc['ext_pos']=value[23]
    
    try:       
        container.create_item(body=doc)
    except Exception as err:
        print(err)
        pass

# %%
print('added to cosmos')
# Out:
# added to cosmos
