# %%
# %load_ext autoreload
# %autoreload 15

# %%
# !pip3 install azure-cosmos

# %%
# !pip3 install comtypes

# %%
# !pip3 install pdfminer.six

# %%
import json
import re
from bs4 import BeautifulSoup
import os
import requests
from pprint import pprint
import uuid
from statistics import mode
from nltk.corpus import stopwords
from pdf2txt import convert_pdf
# !pip install tika
import tika
from definitions_v4 import *

# %%
pointsRE_heading=re.compile('(?:\s*\([a-z]{1,3}\)|[A-Z]{1}\s+[a-zA-Z0-9_\s]{5})')
stop_words = list(set(stopwords.words('english')))
y_cordinate_Re=re.compile('top:(\d{1,5})px')
height_re=re.compile('height:(\d{1,5})px')

# %%
def check_underline(positions,y_cord_text):
    positions=[i for i in positions if y_cord_text<=i< y_cord_text+16]
    if positions:
        return True
    else:
        return False

# %%
def get_pages_no(soup):
    total_items = int(soup.find('span', id='NewReleases_total').text)
    items_per_page = int(soup.find('span', id='NewReleases_end').text)
    return round(total_items/items_per_page)

# %%
from pdfminer.high_level import extract_pages

# print(len(list(extract_pages('test/Chubb16-250-1019 Chubb EBM Business Pack Product Disclosure Statement (PDS) and Policy Wording.pdf'))))

# %%
def get_underlines(soup):
    positions=[]
    for span in soup.find_all('span'):
        y_cord_list=y_cordinate_Re.findall(str(span))
        if y_cord_list:
            y_cord=int(y_cord_list[0])
        else:
            continue
        style="position:absolute; border: black 1px solid" in str(span)
        height_px_li=height_re.findall(str(span))
        if height_px_li:
            height_px=height_px_li[0]
        else:
            continue
        height=int(height_px)<15
        if all([style,height]):
            positions.append(y_cord)
    return list(set(positions))

# %%
def ext_extract(text_list,language):
    ext_flag=False
    if language=='english':
        ext_lis=['extension']
    else:
        ext_lis=['extensión','extensiones']
   
    ext_count=0
    position_list=[]
    position=0
    for text in text_list:
        # if any two of 'exclusion ,condition or extension is present in the text, that text is omitted from the logic'
        bool_list=['condition' in text.lower(),'exclusion' in text.lower(),'extension' in text.lower()]
        if sum(bool_list)>=2:
            continue
        for i in ext_lis:
            for match in re.finditer(i, text.lower()):
                position_list.append(position+match.start())               
                ext_count+=1
        position+=len(text)
    if ext_count>=1:
        ext_flag=True
    return(ext_flag,ext_count,position_list)

# %%
def excl_extract(text_list,language):
    exclusion_flag=False
    if language=='english':
        excl_lis=['exclud','not cover','except','does not mean','not includ','exclusion']
    else:
        excl_lis=['excepto','excepción','no in cluido','exclusión','excluidos','excluirlo','excluyendo','exclusiones','exclusion','excluyen','excluyentes']
   
    exclusion_count=0
    position_list=[]
    position=0
    for text in text_list:
        # if any two of 'exclusion ,condition or extension is present in the text, that text is omitted from the logic'
        bool_list=['condition' in text.lower(),'exclusion' in text.lower(),'extension' in text.lower()]
        if sum(bool_list)>=2:
            continue
        for i in excl_lis:
            for match in re.finditer(i, text.lower()):
                position_list.append(position+match.start())               
                exclusion_count+=1
        position+=len(text)
    if exclusion_count>=1:
        exclusion_flag=True
    return(exclusion_flag,exclusion_count,position_list)

# %%
def cond_extract(text_list,language):
    cond_flag=False
    if language=='english':
        cond_lis=['condition']
    else:
        cond_lis=['condición','condiciones','condicionado']
   
    cond_count=0
    position_list=[]
    position=0
    for text in text_list:
        # if any two of 'exclusion ,condition or extension is present in the text, that text is omitted from the logic'
        bool_list=['condition' in text.lower(),'exclusion' in text.lower(),'extension' in text.lower()]
        if sum(bool_list)>=2:
            continue
        for i in cond_lis:
            for match in re.finditer(i, text.lower()):
                position_list.append(position+match.start())               
                cond_count+=1
        position+=len(text)
    if cond_count>=1:
        cond_flag=True
    return(cond_flag,cond_count,position_list)

# %%
def font_extraction(soup):
    fontsizes=[]
    for divs in soup.findAll('div'):
        for j in divs.find_all('span'):
            ext_size=re.findall(r'font-size:(.*)px">',str(j))
            if ext_size:
                fontsizes.append(int(ext_size[0]))
    return(fontsizes)

# %%
def stopword_check(word,text,language):
    if language=='spanish':
        stop_words = list(set(stopwords.words('spanish')))
    else:
        stop_words = list(set(stopwords.words('english')))
        transition="although  instead  whereas  despite  conversely  otherwise  however moreover  likewise  comparatively  correspondingly  similarly  furthermore  additionallyver  rather  nevertheless  nonetheless  regardless  notwithstanding consequently  therefore  thereupon  forthwith  accordingly  henceforth"
        transition_words=transition.split()
        transition_words
        stop_words.extend(transition_words)

    if exclusion_check(text,language):
        return True
    if word.lower() in stop_words:
        return False
    else:
        return True

# %%
def exclusion_check(text,language):
    if language=='spanish':
        exclusion_bag=['excepto','excepción','no in cluido','exclusión','excluidos','excluirlo','excluyendo',' excluyen','exclusiones','exclusiones','exclusion','excluyentes']
    else:
        exclusion_bag=['exclusion','excluded','not covered','will not cover','will not pay']
    for word in exclusion_bag:
        if word in text.lower():
            return True
    return False

# %%
def criteria_check(text,language):
    if language=='spanish':
        exclusion_bag=['condición','condiciones','condicionado']
    else:
        exclusion_bag=['condition','conditions']
    for word in exclusion_bag:
        if word in text.lower():
            return True
    return False

# %%
def ext_check(text,language):
    if language=='english':
        ext_bag=['extension']
    else:
        ext_bag=['extensión','extensiones']
    for word in ext_bag:
        if word in text.lower():
            return True
    return False

# %%
start=re.compile('.*\d{1,3}.*(?:\-|\.|–)')
def clean(text):
    text=text.replace('\n','').replace('\t',' ')
    text=start.sub('',text).strip()
    

    return(text)
def clean_pharses(phrases):
    phrases=[clean(i) for i in phrases if len(i)> 3]
    phrases=list(set(phrases))
    return phrases

# %%
def create_local_index(path,subdir,language,country):
    pointsRE_heading=re.compile('(?:\s*\([a-z]{1,3}\)|(?<![A-z])[A-Z]{1}\s+[a-zA-Z0-9_\s]{5})')
    pageNumRE=re.compile('Page\s*(\d{1,3})',re.IGNORECASE)
    neglect_def=['policy','insured','schedule']
    local_indexed={}
    previous_span=''
    bold_phrases_indexed={}
    for file in os.listdir(path):
        if file.endswith('.pdf'):
            print(file)
            global file_count
            file_count+=1
            
            print("COUNT",file_count)
            try:
                
                pg_no=len(list(extract_pages(os.path.join(path,file))))
                print(pg_no)
            except Exception as e:
                print(e)
                pg_no=0
            try:
                html=convert_pdf(os.path.join(path,file),'html')
            except Exception as e:
                print(e)
                continue
            soup = BeautifulSoup(html, 'html5lib')
            underline_positions=get_underlines(soup)
            try:
                fontsizes=font_extraction(soup)
                file_font_size_mode=mode(fontsizes)
            except:
                file_font_size_mode=8
                
            text_para,text_plain_para='',''
            text_lis,text_plain_lis,bold_lis,page_list,=[],[],[],[]
            bold=False
            sub_page_def_list=[]
            try:
                definitions=def_extraction(os.path.join(path,file))
            except:
                continue
            definitions={key:value for key,value in definitions.items() if key.lower().strip() not in neglect_def}
            def_terms=list(definitions.keys())
#             print(len(def_terms),'LEN DEFINITIONS')
#             print(definitions)
            definition_text=''
            header_match_object=(0,'',False)
            cond_header_match_object=(0,'',False)
            ext_header_match_object=(0,'',False)
            second_category=False
            head_found=False
            def_flag=False
            cond_head_found=False
            ext_head_found=False
            single_page_head_found=False
            condition_text=''
            ext_text=''
            excl_text=''
            previous_pg_num=[]
            def_in_page=[]
            cond_single_page_head_found=False
            ext_single_page_head_found=False
            
            font_size=file_font_size_mode

            for divs in soup.findAll('div'):
                div_text_list=[span.text for span in divs.find_all('span') ]
                page_str=str(divs.find_all('a'))
                page_num_results=pageNumRE.findall(page_str)
                if page_num_results:
                    pagenum=page_num_results[0]
#                     print(pagenum)
                    if pagenum!=previous_pg_num:
                        sub_definitions_in_page=[]
                    previous_pg_num=pagenum
#                     definition_text=''
                    
                    #only for pdfs
                    if(int(pagenum) in [1,2]) and 'Wording' in file and pg_no >20:
#                     print('Continued on wording 2')
                        continue

                    if text_lis:
                        text_lis=text_lis[:-1]
                        text_para=''.join(text_lis)
                        text_plain_lis=text_plain_lis[:-1]
                        text_plain_para=''.join(text_plain_lis)
                        if(len(re.findall('\.',text_para))>(len(text_para)/3) or (len(re.findall('\d',text_para))>80 and int(pagenum)<4 and  pg_no>20 and 'content' in text_para.lower())) :
                            print('PASS')
                            print(text_plain_para)
                            text_para,text_plain_para=' ',' '
                            text_lis,text_plain_lis=[],[]
                            single_page_head_found=False
                            head_found=False
                            cond_head_found=False
                            ext_head_found=False
                            continue
                        
                        else:
                            bold_lis=clean_pharses(bold_lis)
                            pagenum=int(pagenum)-1
                            excl_flag,excl_count,excl_pos_lis=excl_extract(text_plain_lis,language)
                            cond_flag,cond_count,cond_pos_lis=cond_extract(text_plain_lis,language)
                            ext_flag,ext_count,ext_pos_lis=ext_extract(text_plain_lis,language)
                            if int(pagenum)==1:
                                if head_found or single_page_head_found or excl_count>0:
#                                     print(pagenum,True,'!!!')
                                    excl_flag=True
                                else:
                                    excl_flag=False
                            else:
                                if head_found or single_page_head_found:
#                                     print(pagenum,True,'!!!',excl_count)
                                    excl_flag=True
#                                     print(excl_flag,'EXCL')
#                                 else:
#                                     print(pagenum,excl_flag,'\n')
# #                             print(excl_text)
#                             print(condition_text)
                            if cond_head_found or cond_single_page_head_found or cond_count>0:
                                cond_flag=True
#                                 print('COND','TRUE')
                            else:
#                                 print('COND','FALSE')
                                cond_flag=False
    
                            if ext_head_found or ext_single_page_head_found or ext_count>0:
                                ext_flag=True
                                print('EXT','TRUE',pagenum)
                            else:
                                print('EXT','FALSE',pagenum)
                                ext_flag=False
#                             def_in_page=[{'name':k,'text':v[0] for k,v in definitions.items() if v[1]=pagenum}]
                            for term,defs in definitions.items():
#                                 print(defs[1])
                                if defs[1]==pagenum:  ###defs[1] is the pagenumber
                                    definition_text=definition_text+'          '+term+' '+defs[0]
                                    def_in_page.append({'name':term,'text':defs[0]})
#                                     def_in_page{'name':}
#                             print(definition_text)
                            if definition_text:
                                def_flag=True
                            
                            if def_flag:
                                def_search_flag=True
#                                 print('DEF','TRUE')
                            else:
#                                 print('DEF', 'FALSE')
                                def_search_flag=False   
                            
                            if pg_no>2:
                                endorsements=False
                            else:
                                endorsements=True
#                             print(endorsements,'ENDORSEMENTS!!!')
                            if text_para in local_indexed.keys():
                                text_para=text_para+' '
                            
                            local_indexed[text_para]=(file,pagenum,bold_lis,text_plain_para,excl_flag,excl_count,excl_pos_lis,subdir,sub_page_def_list,country,language,definition_text,def_search_flag,endorsements,excl_text,condition_text,cond_flag,cond_count,cond_pos_lis,def_in_page,ext_text,ext_flag,ext_count,ext_pos_lis)
#                             print(sub_page_def_list,'DEF LIST!!!!!1')
                            sub_page_def_list=[]
                            page_list.append(pagenum)
                            text_para,text_plain_para='',''
                            text_lis,text_plain_lis,bold_lis=[],[],[]
                            definition_text=''
                            cond_single_page_head_found=False
                            ext_single_page_head_found=False
                            condition_text=''
                            ext_text=''
                            excl_text=''
                            single_page_head_found=False
                            def_in_page=[]
                            def_flag=False
                for span in divs.find_all('span'):

                    bold=False
                    upper=False
                    bullet=False
                    def_flag=False
                    span_position=div_text_list.index(span.text)
                    
                    if "Bold" in str(span) or 'CIDFont+F3' in str(span):
                        bold_lis.append(span.text)
                        bold=True
                    if span.text.isupper():
                        upper=True
                    font_family_match=re.findall(r"font-family: b'(.*)';",str(span))
                    if font_family_match:
                        font_family=font_family_match[0]
                    else:
                        font_family=''
#                     print(font_family)
                    font_size_match=re.findall(r'font-size:(.*)px">',str(span))
                    if font_size_match:
                        font_size=int(font_size_match[0])
                    if pointsRE_heading.findall(span.text):
                        bullet=True
#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
                    y_cord_list=y_cordinate_Re.findall(str(divs))
                    if y_cord_list:
                        y_cord=int(y_cord_list[0])
                    underlined_text=check_underline(underline_positions,y_cord)
                    if span.text.split('\n')[0]!='' and span.text.split('\n')[0]!=' ':
                        head_check_text=span.text.split('\n')[0]
                    elif len(span.text.split('\n'))>1:
                        head_check_text=span.text.split('\n')[1]
                    else:
                        head_check_text=''
##############################3  
                    if str(previous_span).endswith('<br/></span>'):
                        span_position=0
                    ##################INSERT FUNCTION####################z
                    #EXCLUSION 
                    if  span_position==0 and (bold or font_size>= file_font_size_mode +2 ) and (font_size> file_font_size_mode or upper) and 5<len(head_check_text.strip())<80:                    
                        if exclusion_check(head_check_text,language) and not head_found: 
                            head_found=True
                            header_match_object=(font_size,font_family,bold,upper,bullet)
                            First_category=True
                            second_category=False
                            single_page_head_found=True
#                             print('FOUND Heading for exclusion ...',span.text)
                        
                    
                        elif ((font_size,font_family,bold,upper,bullet)==header_match_object  or font_size>header_match_object[0] ) and head_found and not exclusion_check(head_check_text,language):
                            head_found=False
                            single_page_head_found=True
#                             print('FOUND Closure for exclusion ...',span.text)
#                     if 'CLAIMS CONDITIONS' in span.text:
#                         print ('^^^^^^^',(font_size,font_family,bold,upper,bullet),header_match_object, font_size>header_match_object[0] , head_found , not exclusion_check(head_check_text,language))
#                         print(pointsRE_heading.findall(span.text))
                    words_title=[word.istitle() for word in head_check_text.split() if stopword_check(word,head_check_text,language) and not word.isdigit() ]
                    if span_position==0 and all(words_title) and head_check_text.strip() not in definitions and  (len(words_title) >1 or underlined_text )and 5<len(head_check_text.strip())<80 :
#                         print('MMMMMMMMARARARA',span.text)

                        if exclusion_check(head_check_text,language) and  not head_found:
                            head_found=True
                            second_category=True
                            First_category=False
                            single_page_head_found=True
                            header_match_object=(font_size,font_family,bold,upper,bullet)
#                             print("FOUND heading type2 ....",span.text)
                        elif head_found and not exclusion_check(head_check_text,language) and second_category and ((font_size,font_family,bold,upper,bullet)==header_match_object or font_size > header_match_object[0] ) :
                            head_found=False
                            second_category=False
                            single_page_head_found=True
#                             print('FOUND closure type 2',span.text)
                    if head_found:
                        excl_text=excl_text+' '+span.text     
                     
                    #CONDITIONS
#                     if 'Condition' in span.text:
# #                         print('text:',str(span.text),'head check',head_check_text,'length of head check',len(head_check_text))
# #                         print(span_position==0,(bold or font_size>= file_font_size_mode +2 ), (font_size> file_font_size_mode or upper), 5<len(head_check_text.strip())<80)
# #                         print(font_size,file_font_size_mode,cond_head_found,criteria_check(head_check_text,language))
                    if  span_position==0 and (bold or font_size>= file_font_size_mode +2 ) and (font_size> file_font_size_mode or upper) and 5<len(head_check_text.strip())<80:                    
                        if criteria_check(head_check_text,language) and not cond_head_found: 
                            cond_head_found=True
                            cond_header_match_object=(font_size,font_family,bold,upper,bullet)
                            cond_First_category=True
                            cond_second_category=False
                            cond_single_page_head_found=True
#                             print('FOUND Heading for condition...',span.text)
                    
                        elif ((font_size,font_family,bold,upper,bullet)==cond_header_match_object or font_size>cond_header_match_object[0] ) and not criteria_check(head_check_text,language)  and cond_head_found:
                            cond_head_found=False
                            cond_single_page_head_found=True
#                             print('FOUND Closure for condition ...',span.text)
                
                    
                    cond_words_title=[word.istitle() for word in head_check_text.split() if stopword_check(word,head_check_text,language) and not word.isdigit() ]
                    if span_position==0 and all(cond_words_title) and head_check_text.strip() not in definitions and  (len(words_title) >1 or underlined_text )and 5<len(head_check_text.strip())<80 :
#                         print('MMMMMMMMARARARA',span.text)

                        if criteria_check(head_check_text,language) and  not cond_head_found:
                            cond_head_found=True
                            cond_second_category=True
                            cond_First_category=False
                            cond_single_page_head_found=True
                            cond_header_match_object=(font_size,font_family,bold,upper,bullet)
#                             print("FOUND heading type2 ....",span.text)
                        elif cond_head_found and not criteria_check(head_check_text,language) and cond_second_category and ((font_size,font_family,bold,upper,bullet)==cond_header_match_object or font_size > cond_header_match_object[0] ) :
                            cond_head_found=False
                            cond_second_category=False
                            cond_single_page_head_found=True
#                             print('FOUND closure type 2',span.text)

                    if cond_head_found==True:
                        condition_text=condition_text+' '+span.text
                            
                    
                    #####EXTENSIONS
                    #CONDITIONS
#                     if 'Extension' in span.text:
#                         print(span.text)
#                         print('text:',str(span.text),'head check',head_check_text,'length of head check',len(head_check_text))
#                         print(span_position==0,(bold or font_size>= file_font_size_mode +2 ), (font_size> file_font_size_mode or upper), 5<len(head_check_text.strip())<80)
#                         print(font_size,file_font_size_mode,cond_head_found,criteria_check(head_check_text,language))
                    if  span_position==0 and (bold or font_size>= file_font_size_mode +2 ) and (font_size> file_font_size_mode or upper) and 5<len(head_check_text.strip())<80:                    
                        if ext_check(head_check_text,language) and not ext_head_found: 
                            ext_head_found=True
                            ext_header_match_object=(font_size,font_family,bold,upper,bullet)
                            ext_First_category=True
                            ext_second_category=False
                            ext_single_page_head_found=True
#                             print('FOUND Heading for ext...',span.text)
                    
                        elif ((font_size,font_family,bold,upper,bullet)==ext_header_match_object or font_size>ext_header_match_object[0] ) and not ext_check(head_check_text,language)  and ext_head_found:
                            ext_head_found=False
                            ext_single_page_head_found=True
#                             print('FOUND Closure for ext ...',span.text)
                
                    
                    ext_words_title=[word.istitle() for word in head_check_text.split() if stopword_check(word,head_check_text,language) and not word.isdigit() ]
                    if span_position==0 and all(ext_words_title) and head_check_text.strip() not in definitions and  (len(words_title) >1 or underlined_text )and 5<len(head_check_text.strip())<80 :
#                         print('MMMMMMMMARARARA',span.text)

                        if ext_check(head_check_text,language) and  not ext_head_found:
                            ext_head_found=True
                            ext_second_category=True
                            ext_First_category=False
                            ext_single_page_head_found=True
                            ext_header_match_object=(font_size,font_family,bold,upper,bullet)
#                             print("FOUND heading type2 ext....",span.text)
                        elif ext_head_found and not ext_check(head_check_text,language) and ext_second_category and ((font_size,font_family,bold,upper,bullet)==ext_header_match_object or font_size > ext_header_match_object[0] ) :
                            ext_head_found=False
                            ext_second_category=False
                            ext_single_page_head_found=True
#                             print('FOUND closure type 2 ext',span.text)
# 
                    if ext_head_found==True:
                        ext_text=ext_text+' '+span.text
                            
    #                     else:
###############################             
                        
                    if font_size_match:
                        if font_size<=file_font_size_mode-1:
                            text_lis.append(' ')
                    text=span.text.replace('\n',' ')
                    text_plain=text.replace('\n',' ')
                    for term in def_terms:
                        if term.lower().strip() in text.lower() and definitions[term][0].strip() not in text and term not in sub_definitions_in_page:
#                             def_page.append(definitions[term])
#                             print(pagenum)
                            src_str  = re.compile(re.escape(term), re.IGNORECASE)
                            text=src_str.sub('###{}@@{}%%%'.format(term,definitions[term][0]),text)
#                             print(text,'\n',term,'TERM!!!!@#$%^&*&^%#$%^&')
                            sub_definitions_in_page.append(term)
                            sub_page_def_list.append({'name':term,'text':definitions[term][0]})
#                             print(definitions_in_page)
                            break
#                     print(definitions_in_page)

                    
                    text_lis.append(text)
                    text_plain_lis.append(text_plain)
                    previous_span=span
                    

            if text_lis:
                if(int(pagenum) in [1,2]) and 'Wording' in file and pg_no >20:
#                     print('Continued on wording 2')
                    continue

                text_lis=text_lis[:-1]
                text_para=''.join(text_lis)
                text_plain_lis=text_plain_lis[:-1]
                text_plain_para=''.join(text_plain_lis)
                if(len(re.findall('\.',text_para))>(len(text_para)/3) or (len(re.findall('\d',text_para))>80 and int(pagenum)<4 and pg_no>20 and 'content' in text_para.lower())) :
                    print('PASS')
                    print(text_plain_para)
                    text_para,text_plain_para=' ',' '
                    text_lis,text_plain_lis=[],[]
                    single_page_head_found=False
                    head_found=False
                    cond_head_found=False
                    ext_head_found=False
                    continue
                else:
                    bold_lis=clean_pharses(bold_lis)
                    if pagenum in page_list and pagenum!='1':
                        pagenum=int(pagenum)+1
                    excl_flag,excl_count,excl_pos_lis=excl_extract(text_plain_lis,language)
                    cond_flag,cond_count,cond_pos_lis=cond_extract(text_plain_lis,language)
                    ext_flag,ext_count,ext_pos_lis=ext_extract(text_plain_lis,language)
                    if int(pagenum)==1:
                        if head_found or single_page_head_found or excl_count>0:
#                             print(pagenum,True,'!!!',excl_count)
                            excl_flag=True
                        else:
                            excl_flag=False
                    else:
                        if head_found or single_page_head_found:
                            print(pagenum,True,'!!!')
                            excl_flag=True
                            print(excl_flag,'EXCL')
                        
                    #####################
                    if cond_head_found or cond_single_page_head_found or cond_count>0:
                        cond_flag=True
#                         print('COND','TRUE')
                    else:
                        cond_flag=False
                    
                    if ext_head_found or ext_single_page_head_found or ext_count>0:
                        ext_flag=True
#                         print('EXT','TRUE',pagenum)
                    else:
#                         print('EXT','FALSE',pagenum)
                        ext_flag=False
#                         print('COND','FALSE')
#                     page_def_list.append({'name':term,'text':definitions[term][0]}
#                     def_in_page=[{'name':k,'text':v[0]} for k,v in definitions.items() if v[1]==pagenum]  
#                     print(def_in_page,'!!!!!!!!!!!!!!!!!!!!!!!!!!!!!')
                    for term,defs in definitions.items():
                        if defs[1]==pagenum:  ###defs[1] is the pagenumber
                            definition_text=definition_text+'          '+term+' '+defs[0]
                            def_in_page.append({'name':term,'text':defs[0]})        
#                     print(definition_text)
                    if definition_text:
                        def_flag=True

                    if def_flag:
                        def_search_flag=True
#                         print('DEF','TRUE')
                    else:
                        def_search_flag=False
#                         print('DEF','FALSE')
                    
                    if pg_no>2:
                        endorsements=False
                    else:
                        endorsements=True
#                     print(endorsements,'ENDORSEMENTS!!!')        
                    if text_para in local_indexed.keys():
                        text_para=text_para+' '
                    local_indexed[text_para]=(file,pagenum,bold_lis,text_plain_para,excl_flag,excl_count,excl_pos_lis,subdir,sub_page_def_list,country,language,definition_text,def_search_flag,endorsements,excl_text,condition_text,cond_flag,cond_count,cond_pos_lis,def_in_page,ext_text,ext_flag,ext_count,ext_pos_lis)
#                     print(sub_page_def_list,'DEF LIST!!!!!1')
                    sub_page_def_list=[]
                    text_para,text_plain_para='','' 
                    text_plain_lis,text_lis,bold_lis=[],[],[]
                    definition_text=''
                    single_page_head_found=False
                    cond_single_page_head_found=False
                    ext_single_page_head_found=False
                    condition_text=''
                    ext_text=''
                    excl_text=''
                    def_in_page=[]
                    def_flag=False
    return(local_indexed)

# %%
def doc_pdf_path(path):
    file_list=os.listdir(path)
    for file in file_list:
        raw_filename=file[:file.rfind(".")]
        pdf_filename=raw_filename+'.pdf'
#         print(raw_filename,pdf_filename,'FILE!!')
        if pdf_filename in file_list:
            print('continued!!!!!!!!!!!!!')
            continue
        if file.endswith('doc') or file.endswith('docx'):
            print('processing!!!')
            wordToPdf(os.path.join(path,file))

# %%
doc_pdf_path('/opt/app/RB/policy_search_APIs/tt_preprocessing/UK-Fire/Industry Standard Wording/')
# Out:
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!
# continued!!!!!!!!!!!!!

# %%
rootDir='V://COG//AU- Property//'
for dirname,subdirlist,filelist in os.walk(rootDir):
    print(dirname)
    for subdir in subdirlist:
        path=os.path.join(dirname,subdir)
#         doc_pdf_path(path)

# %%
# import os
file_count=0
rootDir='/opt/app/RB/policy_search_APIs/tt_preprocessing/UK-Fire/'
country='uk'
local_indexed={}
language='english'
if 'spanish' in rootDir:
    language='spanish'
for dirname,subdirlist,filelist in os.walk(rootDir):
    for subdir in subdirlist:
        print(subdir, 'SUBDIR!!!!!!!!!!!!!')
        path=os.path.join(dirname,subdir)    
        local_indexed_subdir=create_local_index(path,subdir,language,country)
        local_indexed.update(local_indexed_subdir)
# Out:
# Chubb Standard Wording SUBDIR!!!!!!!!!!!!!
# MP210 - FOETAL ALCOHOL HEALTH - PL.pdf
# COUNT 1
# 1
# MP233 - BUSINESS DESCRIPTION CHANGE - PL.pdf
# COUNT 2
# 1
# MP110a - BONA FIDE SUBCONTRACTORS (LIMIT STATED) - PL.pdf
# COUNT 3
# 1
# MP117 - CLINICAL TRIALS EXCLUSION - EL PL.pdf
# COUNT 4
# 1
# MP108 - BITUMEN HEATING CONDITIONS - PL.pdf
# COUNT 5
# 1
# MP180 - SHOPLIFTING ACCUSATION EXTENSION - PL.pdf
# COUNT 6
# 1
# MP234 - PERSONAL AND ADVERTISING INJURY - LIMIT OF LIABILITY - PL.pdf
# COUNT 7
# 1
# MP344 - FLOOD EXCESS.pdf
# COUNT 8
# 1
# MasterPackage Multinational-UK-2019 (Limit of Loss S 1 & 2)-SPECIMEN-(to 31-12-2020).pdf
# COUNT 9
# /opt/app/RB/.local/lib/python3.6/site-packages/pdfminer/pdfpage.py:140: PDFTextExtractionNotAllowedWarning: The PDF <_io.BufferedReader name='/opt/app/RB/policy_search_APIs/tt_preprocessing/UK-Fire/Chubb Standard Wording/MasterPackage Multinational-UK-2019 (Limit of Loss S 1 & 2)-SPECIMEN-(to 31-12-2020).pdf'> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding.
#   warnings.warn(warning_msg, PDFTextExtractionNotAllowedWarning)
# 114
# EXT FALSE 1
# PASS
# Section 1 Property Damage and Section 2 Business Interruption (Combined)  Contents  Introduction  Schedule      Data Protection  Complaints Procedure  Section 1 Property Damage  Cover  Basis of Valuation  Costs, Fees and Expenses  Extensions  Chubbflex  Special Conditions  Section 2 Business Interruption  Cover  Basis of Valuation  Extensions  Special Conditions  Special Provisions  Definitions  Exclusions  Cover  Terms and Conditions  Definitions  Exclusions  Cover  Extensions  Definitions  Exclusions  Special Conditions  Special Conditions  Cover  Extensions  Definitions  Exclusions    Section 3 Terrorism in Great Britain  Section 4 Employers’ Liability  Section 5 Public and Products Liability  (pages i, ii, iii etc…)  4  5  6  7  7  7  10  12  23  25  27  27  27  30  36  38  38  39  43  47  47  47  47  49  51  51  51  53  54  55  56  56  56  60  61  63  MN MasterPackage 2019     P a g e  | 2  01/10/19  SPECIME
# EXT TRUE 3
# EXT TRUE 4
# EXT TRUE 5
# EXT TRUE 6
# EXT TRUE 7
# EXT FALSE 8
# EXT FALSE 9
# EXT TRUE 10
# EXT FALSE 11
# EXT TRUE 12
# EXT FALSE 13
# EXT TRUE 14
# EXT TRUE 15
# EXT TRUE 16
# EXT TRUE 17
# EXT FALSE 18
# EXT FALSE 19
# EXT FALSE 20
# EXT TRUE 21
# EXT FALSE 22
# EXT FALSE 23
# EXT TRUE 24
# EXT TRUE 25
# EXT TRUE 26
# EXT TRUE 27
# EXT TRUE 28
# EXT TRUE 29
# EXT TRUE 30
# EXT TRUE 31
# EXT TRUE 32
# EXT TRUE 33
# EXT TRUE 34
# EXT TRUE 35
# EXT TRUE 36
# EXT TRUE 37
# EXT TRUE 38
# EXT TRUE 39
# EXT FALSE 40
# EXT TRUE 41
# EXT FALSE 42
# EXT FALSE 43
# EXT TRUE 44
# EXT TRUE 45
# EXT TRUE 46
# EXT TRUE 47
# EXT TRUE 48
# EXT TRUE 49
# EXT TRUE 50
# EXT FALSE 51
# EXT FALSE 52
# EXT FALSE 53
# EXT FALSE 54
# EXT FALSE 55
# EXT FALSE 56
# EXT TRUE 57
# EXT TRUE 58
# EXT TRUE 59
# EXT FALSE 60
# EXT FALSE 61
# EXT FALSE 62
# EXT FALSE 63
# EXT FALSE 64
# EXT TRUE 65
# EXT TRUE 66
# EXT TRUE 67
# EXT FALSE 68
# EXT FALSE 69
# EXT TRUE 70
# EXT TRUE 71
# EXT TRUE 72
# EXT TRUE 73
# EXT TRUE 74
# EXT FALSE 75
# EXT FALSE 76
# EXT FALSE 77
# EXT FALSE 78
# EXT FALSE 79
# EXT TRUE 80
# EXT TRUE 81
# EXT TRUE 82
# EXT TRUE 83
# EXT TRUE 84
# EXT TRUE 85
# EXT TRUE 86
# EXT TRUE 87
# EXT TRUE 88
# EXT TRUE 89
# EXT FALSE 90
# EXT FALSE 91
# EXT FALSE 92
# EXT TRUE 93
# EXT FALSE 94
# EXT FALSE 95
# EXT FALSE 96
# EXT FALSE 97
# EXT FALSE 98
# EXT FALSE 99
# EXT FALSE 100
# EXT FALSE 101
# EXT FALSE 102
# EXT FALSE 103
# EXT FALSE 104
# EXT FALSE 105
# EXT FALSE 106
# EXT TRUE 107
# EXT FALSE 108
# EXT TRUE 109
# EXT FALSE 110
# EXT FALSE 111
# EXT FALSE 112
# EXT FALSE 113
# 114 True !!!
# True EXCL
# MP204 - CUSTODY OR CONTROL EXTENSION - PL.pdf
# COUNT 10
# MP171 - PRODUCTS - INEVITABLE DAMAGE EXCLUSION - PL.pdf
# COUNT 139
# 1
# MP125a - DAMAGE TO UNDERGROUND SERVICES - PL.pdf
# COUNT 140
# 1
# MP306 - NOTIFIABLE DISEASES REDEFINITION.pdf
# COUNT 141
# 1
# MP101a - ABUSE EXCLUSION - PL.pdf
# COUNT 142
# 1
# MP312 - ELECTRICAL EQUIPMENT CONDITION.pdf
# COUNT 143
# 1
# MP217 - WELDING FUMES EXCLUSION - PL.pdf
# COUNT 144
# 1
# MP177 - RADIOACTIVE AND EXPLOSIVES MATERIAL EXCLUSION - PL.pdf
# COUNT 145
# 1
# MP342 - DENIAL OF ACCESS - FLOOD WAITING PERIOD.pdf
# COUNT 146
# 1
# MP200 - USE OF HEAT EQUIPMENT AWAY FROM PREMISES EXCLUSION - PL.pdf
# COUNT 147
# 1
# MasterPackage Multinational-UK-2019 (Full Value S 1 & 2)-SPECIMEN (to 31-12-2020).pdf
# COUNT 148
# /opt/app/RB/.local/lib/python3.6/site-packages/pdfminer/pdfpage.py:140: PDFTextExtractionNotAllowedWarning: The PDF <_io.BufferedReader name='/opt/app/RB/policy_search_APIs/tt_preprocessing/UK-Fire/Chubb Standard Wording/MasterPackage Multinational-UK-2019 (Full Value S 1 & 2)-SPECIMEN (to 31-12-2020).pdf'> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding.
#   warnings.warn(warning_msg, PDFTextExtractionNotAllowedWarning)
# 114
# EXT FALSE 1
# PASS
# Section 1 Property Damage and Section 2 Business Interruption (Combined)  Contents  Introduction  Schedule      Data Protection  Complaints Procedure  Section 1 Property Damage  Cover  Basis of Valuation  Costs, Fees and Expenses  Extensions  Chubbflex  Special Conditions  Section 2 Business Interruption  Cover  Basis of Valuation  Extensions  Special Conditions  Special Provisions  Definitions  Exclusions  Cover  Terms and Conditions  Definitions  Exclusions  Cover  Extensions  Definitions  Exclusions  Special Conditions  Special Conditions  Cover  Extensions  Definitions  Exclusions    Section 3 Terrorism in Great Britain  Section 4 Employers’ Liability  Section 5 Public and Products Liability  (pages i, ii, iii etc…)  4  5  6  7  7  7  10  12  23  25  27  27  27  30  36  38  38  39  43  47  47  47  47  49  51  51  51  53  54  55  56  56  56  60  61  63  MN MasterPackage 2019     P a g e  | 2  01/10/19  SPECIME
# EXT TRUE 3
# EXT TRUE 4
# EXT TRUE 5
# EXT TRUE 6
# EXT TRUE 7
# EXT FALSE 8
# EXT FALSE 9
# EXT TRUE 10
# EXT FALSE 11
# EXT TRUE 12
# EXT TRUE 13
# EXT TRUE 14
# EXT TRUE 15
# EXT FALSE 16
# EXT TRUE 17
# EXT FALSE 18
# EXT FALSE 19
# EXT FALSE 20
# EXT TRUE 21
# EXT FALSE 22
# EXT FALSE 23
# EXT TRUE 24
# EXT TRUE 25
# EXT TRUE 26
# EXT TRUE 27
# EXT TRUE 28
# EXT TRUE 29
# EXT TRUE 30
# EXT TRUE 31
# EXT TRUE 32
# EXT TRUE 33
# EXT TRUE 34
# EXT TRUE 35
# EXT TRUE 36
# EXT TRUE 37
# EXT TRUE 38
# EXT TRUE 39
# EXT FALSE 40
# EXT TRUE 41
# EXT FALSE 42
# EXT FALSE 43
# EXT TRUE 44
# EXT TRUE 45
# EXT TRUE 46
# EXT TRUE 47
# EXT TRUE 48
# EXT TRUE 49
# EXT TRUE 50
# EXT FALSE 51
# EXT FALSE 52
# EXT FALSE 53
# EXT FALSE 54
# EXT FALSE 55
# EXT FALSE 56
# EXT TRUE 57
# EXT TRUE 58
# EXT TRUE 59
# EXT FALSE 60
# EXT FALSE 61
# EXT FALSE 62
# EXT FALSE 63
# EXT FALSE 64
# EXT TRUE 65
# EXT TRUE 66
# EXT TRUE 67
# EXT FALSE 68
# EXT FALSE 69
# EXT TRUE 70
# EXT TRUE 71
# EXT TRUE 72
# EXT TRUE 73
# EXT TRUE 74
# EXT FALSE 75
# EXT FALSE 76
# EXT FALSE 77
# EXT FALSE 78
# EXT FALSE 79
# EXT TRUE 80
# EXT TRUE 81
# EXT TRUE 82
# EXT TRUE 83
# EXT TRUE 84
# EXT TRUE 85
# EXT TRUE 86
# EXT TRUE 87
# EXT TRUE 88
# EXT TRUE 89
# EXT FALSE 90
# EXT FALSE 91
# EXT FALSE 92
# EXT TRUE 93
# EXT FALSE 94
# EXT FALSE 95
# EXT FALSE 96
# EXT FALSE 97
# EXT FALSE 98
# EXT FALSE 99
# EXT FALSE 100
# EXT FALSE 101
# EXT FALSE 102
# EXT FALSE 103
# EXT FALSE 104
# EXT FALSE 105
# EXT FALSE 106
# EXT TRUE 107
# EXT FALSE 108
# EXT TRUE 109
# EXT FALSE 110
# EXT FALSE 111
# EXT FALSE 112
# EXT FALSE 113
# 114 True !!!
# True EXCL
# MP243 - FINANCIAL INSTITUTIONS EXCLUSION - PL.pdf
# COUNT 149
# 1
# MP147 - INFORMATION EXCLUSION - PL.pdf
# COUNT 150
# 1
# MP132 - EXCESS MOTOR LIABILITY EXCL PRIVATE MOTOR - PL.pdf
# COUNT 151
# 1
# MP196 - USA CANADA - DIRECT EXPORTS RUN OFF COVER EXCLUSION - PL.pdf
# COUNT 152
# 1
# MP223 - MACHINERY MANUFACTURERS'  PROPERTY BEING WORKED UPON - PL.pdf
# COUNT 153
# 1
# MP112 - BSE EXCLUSION - PL.pdf
# COUNT 154
# 1
# MP161 - MTBE EXCLUSION - PL.pdf
# COUNT 155
# 1
# CD2a - Communicable Disease Endt, Restrictions on Use of Premises restated(from 010720).pdf
# COUNT 156
# 1
# MP166 - OFFSHORE WORK EXCLUSION - PL.pdf
# COUNT 157
# 1
# MP128 - EMF (ELECTRO MAGNETIC FIELDS) EXCLUSION - PL.pdf
# COUNT 158
# 1
# MP163 - CONTRACTUAL LIABILITY EXTENSION (oil and gas industry) - PL.pdf
# COUNT 159
# 1
# MP164 - OFFSHORE EXTENSION- EL.pdf
# COUNT 160
# 1
# MP115 - CLAIMS MADE BASIS - PL.pdf
# COUNT 161
# 1
# MP118a - CLOAKROOM EXTENSION - PL.pdf
# COUNT 162
# 1
# MP174 - PROFESSIONAL ADVICE AND TREATMENT EXCLUSION - PL.pdf
# COUNT 163
# 1
# MP228 - LEAD - PL.pdf
# COUNT 164
# 1
# MP313 - FAT FRYING CONDITION.pdf
# COUNT 165
# 1
# MP349 - MORTGAGEE AND OTHER INTERESTS.pdf
# COUNT 166
# 1
# MP179 - RIGHTS OF RECOURSE - PL.pdf
# COUNT 167
# 1
# MP154 - MAINTENANCE OF VEHICLES EXCLUSION - PL.pdf
# COUNT 168
# 1
# MasterPackage -MP_16 _ 02-06-2017- No end date available.pdf
# COUNT 169
# 86
# EXT FALSE 1
# PASS
# General Provisions Applicable to All Sections of the Policy    Contents    Introduction  2  General Insuring Agreement  Definitions  Section 1. Property Damage  A. Costs, fees and expenses  B. Extensions  Chubbflex  Special Conditions - Valuation  Section 2. Business Interruption  Basis of Settlement  Extensions  Conditions applicable to sections 1 and 2  Section 3. Terrorism  A. Pool Re  B. Specified territory – Non-Pool Re (Wrap)  C. Outside specified territory – Non-Pool  Exclusions applicable to Section 1,2 and 3  Conditions applicable to Sections 1,2 and 3  Section 4.  Employers’ Liability  Limits of Liability  Extensions  Exclusions  Special Conditions  Section 5.  Public and Products Liability  Limits of Liability  Extensions  Exclusions  Special Conditions  Special Extension – Environmental liability  Extensions Applicable to sections 4 and 5  Claims Conditions applicable to Sections 4 and 5  Section 6 – Chubb Basket  Section 6A – Employee Fidelity  Limits of Liability applicable to Section 6A  Exclusions applicable to Section 6A  Conditions applicable to Section 6A  Section 6B – Cancellation of Event  Exclusions applicable to Section 6B  Section 6C – Marine Cargo  Marine Cover  Section 6D – Abduction And Extortion  Exclusions applicable to Section 6D  Section 6E Impairment of Computer Services  Special Conditions  Exclusions  Definitions applicable to all Sections of this Policy    Page  2  2  2  7  7  9  16  18  21  21  24  27  29  29  29  30  31  36  40  40  40  40  41  42  42  42  45  48  49  54  56  57  57  57  57  58  60  60  62  62  64  64  66  66  67  68  UK/CCI/CIS/MP_16/16 – POL 2/06/2017 v8  CLD1D2016/0
# EXT FALSE 3
# EXT FALSE 4
# EXT FALSE 5
# EXT FALSE 6
# EXT FALSE 7
# EXT TRUE 8
# EXT TRUE 9
# EXT TRUE 10
# EXT TRUE 11
# EXT TRUE 12
# EXT TRUE 13
# EXT TRUE 14
# EXT TRUE 15
# EXT TRUE 16
# EXT TRUE 17
# EXT TRUE 18
# EXT TRUE 19
# EXT TRUE 20
# EXT TRUE 21
# EXT TRUE 22
# EXT FALSE 23
# EXT FALSE 24
# EXT TRUE 25
# EXT TRUE 26
# EXT TRUE 27
# EXT TRUE 28
# EXT TRUE 29
# EXT TRUE 30
# EXT TRUE 31
# EXT TRUE 32
# EXT FALSE 33
# EXT TRUE 34
# EXT TRUE 35
# EXT FALSE 36
# EXT FALSE 37
# EXT FALSE 38
# EXT FALSE 39
# EXT FALSE 40
# EXT TRUE 41
# EXT FALSE 42
# EXT TRUE 43
# EXT TRUE 44
# EXT TRUE 45
# EXT TRUE 46
# EXT FALSE 47
# EXT TRUE 48
# EXT TRUE 49
# EXT TRUE 50
# EXT TRUE 51
# EXT TRUE 52
# EXT TRUE 53
# EXT FALSE 54
# EXT TRUE 55
# EXT TRUE 56
# EXT TRUE 57
# EXT FALSE 58
# EXT FALSE 59
# EXT FALSE 60
# EXT FALSE 61
# EXT FALSE 62
# EXT FALSE 63
# EXT FALSE 64
# EXT FALSE 65
# EXT FALSE 66
# EXT FALSE 67
# EXT FALSE 68
# EXT TRUE 69
# EXT FALSE 70
# EXT TRUE 71
# EXT FALSE 72
# EXT FALSE 73
# EXT FALSE 74
# EXT FALSE 75
# EXT FALSE 76
# EXT FALSE 77
# EXT FALSE 78
# EXT TRUE 79
# EXT FALSE 80
# EXT FALSE 81
# EXT FALSE 82
# EXT FALSE 83
# EXT FALSE 84
# EXT FALSE 85
# MP336 - UNATTENDED VEHICLE EXCLUSION.pdf
# COUNT 170
# 1
# MP331 - RESTRICTED THEFT.pdf
# COUNT 171
# 1
# MP134 - FAILURE TO SUPPLY - PL.pdf
# COUNT 172
# 1
# MP128a - EMF (ELECTRO MAGNETIC FIELDS) EXCLUSION - PL.pdf
# COUNT 173
# 1
# MP303 - CONTENTS EXCLUSION.pdf
# COUNT 174
# 1
# MP309 - ROYALTIES.pdf
# COUNT 175
# 1
# MasterPackage policy wording 01_09_2017 (no end date available).pdf
# COUNT 176
# 83
# EXT FALSE 1
# PASS
#   Page    Contents  Introduction  General Insuring Agreement  Definitions  General Provisions Applicable to All Sections of the Policy  Section 1. Property Damage  A. Costs, fees and expenses  B. Extensions  Chubbflex  Special Conditions - Valuation  Section 2. Business Interruption  Basis of Settlement  Extensions  Conditions applicable to sections 1 and 2  Section 3. Terrorism  A. Pool Re  B. Specified territory – Non-Pool Re (Wrap)  C. Outside specified territory – Non-Pool  Exclusions applicable to Section 1,2 and 3  Conditions applicable to Sections 1,2 and 3  Section 4.  Employers’ Liability  Section 5.  Public and Products Liability  Limits of Liability  Extensions  Exclusions  Special Conditions  Limits of Liability  Extensions  Exclusions  Special Conditions  Special Extension – Environmental liability  Extensions Applicable to sections 4 and 5  Claims Conditions applicable to Sections 4 and 5  Section 6 – Chubb Basket  Section 6A – Employee Fidelity  Section 6B – Cancellation of Event  Section 6C – Marine Cargo  Section 6D – Abduction And Extortion  Section - 6E Impairment of Computer Services  Definitions applicable to all Sections of this Policy  2  2  2  3  8  8  10  17  19  22  22  24  28  30  30  31  31  33  37  41  41  41  41  42  43  43  43  46  49  50  55  57  58  58  60  61  62  63  66  MasterPacka ge 01/09/2017
# EXT TRUE 3
# EXT FALSE 4
# EXT FALSE 5
# EXT FALSE 6
# EXT FALSE 7
# EXT FALSE 8
# EXT TRUE 9
# EXT TRUE 10
# EXT TRUE 11
# EXT TRUE 12
# EXT TRUE 13
# EXT TRUE 14
# EXT TRUE 15
# EXT TRUE 16
# EXT TRUE 17
# EXT TRUE 18
# EXT TRUE 19
# EXT TRUE 20
# EXT FALSE 21
# EXT FALSE 22
# EXT FALSE 23
# EXT FALSE 24
# EXT TRUE 25
# EXT TRUE 26
# EXT TRUE 27
# EXT TRUE 28
# EXT TRUE 29
# EXT FALSE 30
# EXT FALSE 31
# EXT TRUE 32
# EXT FALSE 33
# EXT TRUE 34
# EXT FALSE 35
# EXT TRUE 36
# EXT TRUE 37
# EXT FALSE 38
# EXT FALSE 39
# EXT FALSE 40
# EXT FALSE 41
# EXT TRUE 42
# EXT FALSE 43
# EXT TRUE 44
# EXT TRUE 45
# EXT TRUE 46
# EXT TRUE 47
# EXT FALSE 48
# EXT FALSE 49
# EXT TRUE 50
# EXT TRUE 51
# EXT TRUE 52
# EXT TRUE 53
# EXT TRUE 54
# EXT TRUE 55
# EXT TRUE 56
# EXT TRUE 57
# EXT TRUE 58
# EXT FALSE 59
# EXT FALSE 60
# EXT FALSE 61
# EXT FALSE 62
# EXT FALSE 63
# EXT FALSE 64
# EXT FALSE 65
# EXT FALSE 66
# EXT TRUE 67
# EXT FALSE 68
# EXT TRUE 69
# EXT FALSE 70
# EXT FALSE 71
# EXT FALSE 72
# EXT FALSE 73
# EXT FALSE 74
# EXT FALSE 75
# EXT FALSE 76
# EXT FALSE 77
# EXT FALSE 78
# EXT FALSE 79
# EXT FALSE 80
# EXT FALSE 81
# EXT FALSE 82
# MP120 - CONSTRUCTION - CIVIL ENGINEERING - EXCLUDED WORK CLAUSE - EL PL.pdf
# COUNT 177
# 1
# MP157 - MENTAL INJURY ANGUISH AND SHOCK - USA CANADA - PL.pdf
# COUNT 178
# 1
# MP333 - STOCK DECLARATION ADJUSTMENT.pdf
# COUNT 179
# 1
# MP109a - BONA FIDE SUBCONTRACTORS (EQUIVALENT COVER) - PL.pdf
# COUNT 180
# 1
# MP158 - MOBILE PHONE EXCLUSION - PL.pdf
# COUNT 181
# 1
# MP170 - POLLUTION AND CONTAMINATION CLEAN UP.pdf
# COUNT 182
# 2
# EXT TRUE 1
# MP110 - BONA FIDE SUBCONTRACTORS (LIMIT STATED) - PL.pdf
# COUNT 183
# 1
# MP185 - TERRORISM INCLUSION - EL.pdf
# COUNT 184
# 1
# MP114 - CHILDCARE BODILY INJURY EXCLUSION - PL.pdf
# COUNT 185
# 1
# MP135 - FINANCIAL LOSS EXTENSION (CLAIMS MADE BASIS) - PL.pdf
# COUNT 186
# 3
# EXT TRUE 1
# EXT TRUE 2
# MP327 - HIRED IN PLANT AND CONTINUING HIRE CHARGES.pdf
# COUNT 187
# 1
# MP221 - UNMANNED AERIAL VEHICLE PRODUCTS EXTENSION - PL.pdf
# COUNT 188
# 1
# MP182 - SILICA DUST AND PARTICULATE MATTER EXCLUSION.pdf
# COUNT 189
# 1
# MP216 - MANUAL WORK AWAY FROM THE PREMISES EXCLUSION - PL.pdf
# COUNT 190
# 1
# MP114a - CHILDCARE BODILY INJURY EXCLUSION - PL.pdf
# COUNT 191
# 1
# MP330 - RESTRICTED THEFT - SPECIFIC LOCATION.pdf
# COUNT 192
# 1
# MP199 - USE OF HEAT AWAY FROM THE PREMISES - PL.pdf
# COUNT 193
# 1
# MP190 - TOUR OPERATORS LIABILITY EXCLUSION - FULL - PL.pdf
# COUNT 194
# 1
# MP126 - DISPENSING OF DRUGS - PL.pdf
# COUNT 195
# 1
# MP347 - LOSS OF LICENSE.pdf
# COUNT 196
# 2
# EXT FALSE 1
# MP151 - LOSS OF UNDERGROUND RESOURCES EXCLUSION - PL.pdf
# COUNT 197
# 1
# MP227 - DIACETYL - PL.pdf
# COUNT 198
# 1
# MP222 - PREMIUM ADJUSTMENT - EL PL.pdf
# COUNT 199
# 1
# MP102 - AERIAL ERECTION EXCLUSION - EL PL.pdf
# COUNT 231
# 2
# EXT FALSE 1
# CD1a - Communicable Disease Endt, Restrictions on Use of Premises option (from 010720).pdf
# COUNT 232
# 2
# EXT TRUE 1
# PDBI21-CUSTOMERS AND SUPPLIERS-UNSPECIFIED-ALL RISKS.pdf
# COUNT 233
# 1
# MPDBINAR-COINSURERS SCHEDULE OF INSURERS (Other Insurers_Lloyds).pdf
# COUNT 234
# 1
# Chubb Multinational PDBI - UK - (from 01-04-2018 to 31-12-18) - SPECIMEN.pdf
# COUNT 235
# /opt/app/RB/.local/lib/python3.6/site-packages/pdfminer/pdfpage.py:140: PDFTextExtractionNotAllowedWarning: The PDF <_io.BufferedReader name='/opt/app/RB/policy_search_APIs/tt_preprocessing/UK-Fire/Industry Standard Wording/Chubb Multinational PDBI - UK - (from 01-04-2018 to 31-12-18) - SPECIMEN.pdf'> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding.
#   warnings.warn(warning_msg, PDFTextExtractionNotAllowedWarning)
# 78
# EXT FALSE 1
# EXT TRUE 2
# EXT TRUE 3
# EXT TRUE 4
# EXT TRUE 5
# EXT FALSE 6
# EXT FALSE 7
# EXT FALSE 8
# EXT TRUE 9
# EXT TRUE 10
# EXT TRUE 11
# EXT TRUE 12
# EXT TRUE 13
# EXT FALSE 14
# EXT FALSE 15
# EXT FALSE 16
# EXT FALSE 17
# EXT FALSE 18
# EXT TRUE 19
# EXT TRUE 20
# EXT TRUE 21
# EXT TRUE 22
# EXT TRUE 23
# EXT TRUE 24
# EXT TRUE 25
# EXT TRUE 26
# EXT TRUE 27
# EXT TRUE 28
# EXT TRUE 29
# EXT TRUE 30
# EXT TRUE 31
# EXT TRUE 32
# EXT TRUE 33
# EXT FALSE 34
# EXT FALSE 35
# EXT FALSE 36
# EXT TRUE 37
# EXT TRUE 38
# EXT TRUE 39
# EXT TRUE 40
# EXT TRUE 41
# EXT TRUE 42
# EXT TRUE 43
# EXT FALSE 44
# EXT TRUE 45
# EXT FALSE 46
# EXT FALSE 47
# EXT FALSE 48
# EXT FALSE 49
# EXT TRUE 50
# EXT TRUE 51
# EXT FALSE 52
# EXT FALSE 53
# EXT TRUE 54
# EXT FALSE 55
# EXT FALSE 56
# EXT FALSE 57
# EXT FALSE 58
# EXT FALSE 59
# EXT FALSE 60
# EXT FALSE 61
# EXT FALSE 62
# EXT TRUE 63
# EXT FALSE 64
# EXT FALSE 65
# EXT FALSE 66
# EXT FALSE 67
# EXT FALSE 68
# EXT FALSE 69
# EXT FALSE 70
# EXT FALSE 71
# EXT FALSE 72
# EXT FALSE 73
# EXT FALSE 74
# EXT FALSE 75
# EXT FALSE 76
# EXT FALSE 77
# 78 True !!!
# True EXCL
# Chubb PDBI - UK - (from 01-05-2017 until 31-03-2018) - Specimen.pdf
# COUNT 236
# /opt/app/RB/.local/lib/python3.6/site-packages/pdfminer/pdfpage.py:140: PDFTextExtractionNotAllowedWarning: The PDF <_io.BufferedReader name='/opt/app/RB/policy_search_APIs/tt_preprocessing/UK-Fire/Industry Standard Wording/Chubb PDBI - UK - (from 01-05-2017 until 31-03-2018) - Specimen.pdf'> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding.
#   warnings.warn(warning_msg, PDFTextExtractionNotAllowedWarning)
# 61
# EXT FALSE 1
# EXT TRUE 2
# EXT TRUE 3
# EXT TRUE 4
# EXT TRUE 5
# EXT TRUE 6
# EXT TRUE 7
# EXT TRUE 8
# EXT TRUE 9
# EXT TRUE 10
# EXT FALSE 11
# EXT FALSE 12
# EXT FALSE 13
# EXT FALSE 14
# EXT FALSE 15
# EXT TRUE 16
# EXT TRUE 17
# EXT TRUE 18
# EXT TRUE 19
# EXT TRUE 20
# EXT TRUE 21
# EXT TRUE 22
# EXT TRUE 23
# EXT TRUE 24
# EXT TRUE 25
# EXT TRUE 26
# EXT TRUE 27
# EXT TRUE 28
# EXT TRUE 29
# EXT FALSE 30
# EXT FALSE 31
# EXT FALSE 32
# EXT TRUE 33
# EXT TRUE 34
# EXT TRUE 35
# EXT TRUE 36
# EXT TRUE 37
# EXT TRUE 38
# EXT FALSE 39
# EXT TRUE 40
# EXT FALSE 41
# EXT FALSE 42
# EXT FALSE 43
# EXT FALSE 44
# EXT TRUE 45
# EXT TRUE 46
# EXT FALSE 47
# EXT FALSE 48
# EXT TRUE 49
# EXT FALSE 50
# EXT FALSE 51
# EXT FALSE 52
# EXT FALSE 53
# EXT FALSE 54
# EXT FALSE 55
# EXT FALSE 56
# EXT FALSE 57
# EXT FALSE 58
# EXT FALSE 59
# EXT FALSE 60
# 61 True !!!
# True EXCL
# PDBIPDN-COMBUSTIBLE MATERIALS CONDITION.pdf
# COUNT 237
# 1
# MPDBINDV-LONG TERM AGREEMENT-SECTIONAL CLAUSE-DISCOUNT-SPECIFIC PERCENTAGE.pdf
# COUNT 238
# 1
# Chubb Multinational PDBI - UK - 04-2018 (SE - from 01-01-2019) - SPECIMEN.pdf
# COUNT 239
# /opt/app/RB/.local/lib/python3.6/site-packages/pdfminer/pdfpage.py:140: PDFTextExtractionNotAllowedWarning: The PDF <_io.BufferedReader name='/opt/app/RB/policy_search_APIs/tt_preprocessing/UK-Fire/Industry Standard Wording/Chubb Multinational PDBI - UK - 04-2018 (SE - from 01-01-2019) - SPECIMEN.pdf'> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding.
#   warnings.warn(warning_msg, PDFTextExtractionNotAllowedWarning)
# 78
# EXT FALSE 1
# EXT TRUE 2
# EXT TRUE 3
# EXT TRUE 4
# EXT TRUE 5
# EXT FALSE 6
# EXT FALSE 7
# EXT FALSE 8
# EXT TRUE 9
# EXT TRUE 10
# EXT TRUE 11
# EXT TRUE 12
# EXT TRUE 13
# EXT FALSE 14
# EXT FALSE 15
# EXT FALSE 16
# EXT FALSE 17
# EXT FALSE 18
# EXT TRUE 19
# EXT TRUE 20
# EXT TRUE 21
# EXT TRUE 22
# EXT TRUE 23
# EXT TRUE 24
# EXT TRUE 25
# EXT TRUE 26
# EXT TRUE 27
# EXT TRUE 28
# EXT TRUE 29
# EXT TRUE 30
# EXT TRUE 31
# EXT TRUE 32
# EXT TRUE 33
# EXT FALSE 34
# EXT FALSE 35
# EXT FALSE 36
# EXT TRUE 37
# EXT TRUE 38
# EXT TRUE 39
# EXT TRUE 40
# EXT TRUE 41
# EXT TRUE 42
# EXT TRUE 43
# EXT FALSE 44
# EXT TRUE 45
# EXT FALSE 46
# EXT FALSE 47
# EXT FALSE 48
# EXT FALSE 49
# EXT TRUE 50
# EXT TRUE 51
# EXT FALSE 52
# EXT FALSE 53
# EXT TRUE 54
# EXT FALSE 55
# EXT FALSE 56
# EXT FALSE 57
# EXT FALSE 58
# EXT FALSE 59
# EXT FALSE 60
# EXT FALSE 61
# EXT FALSE 62
# EXT TRUE 63
# EXT FALSE 64
# EXT FALSE 65
# EXT FALSE 66
# EXT FALSE 67
# EXT FALSE 68
# EXT FALSE 69
# EXT FALSE 70
# EXT FALSE 71
# EXT FALSE 72
# EXT FALSE 73
# EXT FALSE 74
# EXT FALSE 75
# EXT FALSE 76
# EXT FALSE 77
# 78 True !!!
# True EXCL
# MPDBI - Marsh PEMA Endorsement (from 08-04-2020).pdf
# COUNT 240
# 8
# EXT TRUE 1
# EXT TRUE 2
# EXT TRUE 3
# EXT TRUE 4
# EXT TRUE 5
# EXT TRUE 6
# EXT TRUE 7
# MPDBI36-SECURITY CANCELLATION.pdf
# COUNT 241
# 1
# PDBI08-NOTIFIABLE DISEASE+DECONT EXCLUDING LEGIONNAIRES.pdf
# COUNT 242
# 2
# EXT TRUE 1
# PDBI26-FULL THEFT.pdf
# COUNT 243
# 1
# PDBI27-GLASS.pdf
# COUNT 244
# 1
# PDBI41- LOSS PAYEE.pdf
# COUNT 245
# 1
# MPDBIIIA-INTERESTS INSURED AMENDED.pdf
# COUNT 246
# 1
# PDBI36-SECURITY CANCELLATION.pdf
# COUNT 247
# 1
# MPDBI - Marsh PEMA Endorsement (to 12-02-2020).pdf
# COUNT 248
# 8
# EXT TRUE 1
# EXT TRUE 2
# EXT TRUE 3
# EXT TRUE 4
# EXT TRUE 5
# EXT TRUE 6
# EXT TRUE 7
# MPDBI13-CATASTROPHES NATURELLES.pdf
# COUNT 249
# 1
# MPDBIEPA-EXTENDED PERIOD AGREEMENT.pdf
# COUNT 250
# 1
# Chubb PDBI - UK - (from 01-04-18 to 31-12-18) - SPECIMEN.pdf
# COUNT 251
# /opt/app/RB/.local/lib/python3.6/site-packages/pdfminer/pdfpage.py:140: PDFTextExtractionNotAllowedWarning: The PDF <_io.BufferedReader name='/opt/app/RB/policy_search_APIs/tt_preprocessing/UK-Fire/Industry Standard Wording/Chubb PDBI - UK - (from 01-04-18 to 31-12-18) - SPECIMEN.pdf'> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding.
#   warnings.warn(warning_msg, PDFTextExtractionNotAllowedWarning)
# 62
# EXT FALSE 1
# EXT TRUE 2
# EXT TRUE 3
# EXT TRUE 4
# EXT TRUE 5
# EXT TRUE 6
# EXT TRUE 7
# EXT TRUE 8
# EXT TRUE 9
# EXT TRUE 10
# EXT FALSE 11
# EXT FALSE 12
# EXT FALSE 13
# EXT FALSE 14
# EXT FALSE 15
# EXT TRUE 16
# EXT TRUE 17
# EXT TRUE 18
# EXT TRUE 19
# EXT TRUE 20
# EXT TRUE 21
# EXT TRUE 22
# EXT TRUE 23
# EXT TRUE 24
# EXT TRUE 25
# EXT TRUE 26
# EXT TRUE 27
# EXT TRUE 28
# EXT TRUE 29
# EXT FALSE 30
# EXT FALSE 31
# EXT FALSE 32
# EXT TRUE 33
# EXT TRUE 34
# EXT TRUE 35
# EXT TRUE 36
# EXT TRUE 37
# EXT TRUE 38
# EXT FALSE 39
# EXT TRUE 40
# EXT FALSE 41
# EXT FALSE 42
# EXT FALSE 43
# EXT FALSE 44
# EXT TRUE 45
# EXT TRUE 46
# EXT FALSE 47
# EXT FALSE 48
# EXT TRUE 49
# EXT FALSE 50
# EXT FALSE 51
# EXT FALSE 52
# EXT FALSE 53
# EXT FALSE 54
# EXT FALSE 55
# EXT FALSE 56
# EXT FALSE 57
# EXT FALSE 58
# EXT FALSE 59
# EXT FALSE 60
# EXT FALSE 61
# 62 True !!!
# True EXCL
# MPDBI_WRP_2 - Willis Risk Protect - Extensions to Section 2.pdf
# COUNT 252
# 1
# MPDBI20-CUSTOMERS AND SUPPLIERS-SPECIFIED-ALL RISKS.pdf
# COUNT 253
# 1
# PDBINDW-LONG TERM AGREEMENT-POLICY CLAUSE-NO DISCOUNT.pdf
# COUNT 254
# 1
# MPDBIRAN-RANKING OF COVERS (SECTION 4 vs SECTIONS 1 AND 2) until 31-03-2018.pdf
# COUNT 255
# 1
# Chubb PDBI - UK - 04-2018 (SE - from 01-01-2019 to 31-12-20) - SPECIMEN.pdf
# COUNT 256
# /opt/app/RB/.local/lib/python3.6/site-packages/pdfminer/pdfpage.py:140: PDFTextExtractionNotAllowedWarning: The PDF <_io.BufferedReader name='/opt/app/RB/policy_search_APIs/tt_preprocessing/UK-Fire/Industry Standard Wording/Chubb PDBI - UK - 04-2018 (SE - from 01-01-2019 to 31-12-20) - SPECIMEN.pdf'> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding.
#   warnings.warn(warning_msg, PDFTextExtractionNotAllowedWarning)
# 62
# EXT FALSE 1
# EXT TRUE 2
# EXT TRUE 3
# EXT TRUE 4
# EXT TRUE 5
# EXT TRUE 6
# EXT TRUE 7
# EXT TRUE 8
# EXT TRUE 9
# EXT TRUE 10
# EXT FALSE 11
# EXT FALSE 12
# EXT FALSE 13
# EXT FALSE 14
# EXT FALSE 15
# EXT TRUE 16
# EXT TRUE 17
# EXT TRUE 18
# EXT TRUE 19
# EXT TRUE 20
# EXT TRUE 21
# EXT TRUE 22
# EXT TRUE 23
# EXT TRUE 24
# EXT TRUE 25
# EXT TRUE 26
# EXT TRUE 27
# EXT TRUE 28
# EXT TRUE 29
# EXT FALSE 30
# EXT FALSE 31
# EXT FALSE 32
# EXT TRUE 33
# EXT TRUE 34
# EXT TRUE 35
# EXT TRUE 36
# EXT TRUE 37
# EXT TRUE 38
# EXT FALSE 39
# EXT TRUE 40
# EXT FALSE 41
# EXT FALSE 42
# EXT FALSE 43
# EXT FALSE 44
# EXT TRUE 45
# EXT TRUE 46
# EXT FALSE 47
# EXT FALSE 48
# EXT TRUE 49
# EXT FALSE 50
# EXT FALSE 51
# EXT FALSE 52
# EXT FALSE 53
# EXT FALSE 54
# EXT FALSE 55
# EXT FALSE 56
# EXT FALSE 57
# EXT FALSE 58
# EXT FALSE 59
# EXT FALSE 60
# EXT FALSE 61
# 62 True !!!
# True EXCL
# MPDBINDX-LONG TERM AGREEMENT-POLICY CLAUSE-DISCOUNT.pdf
# COUNT 257
# 1
# MPDBI40-SPECIFIED ITEMS-ALL RISKS COVER-AMENDED TERRITORIAL LIMITS.pdf
# COUNT 258
# 1
# MPDBI14-TERRORISM IN FRANCE.pdf
# COUNT 259
# 1
# PDBI20-CUSTOMERS AND SUPPLIERS-SPECIFIED-ALL RISKS.pdf
# COUNT 260
# 1
# MPDBI31-OVERSEAS LOCATIONS EXTENSION (extended Drafting Instructions).pdf
# COUNT 261
# 1
# MPDBI_WRP_GC - Willis Risk Protect - General Conditions Endorsement.pdf
# COUNT 262
# 1
# PDBI38-THEFT (RESTRICTED COVER).pdf
# COUNT 263
# 1
# PDBI03-CONTENTS EXCLUSION.pdf
# COUNT 264
# 1
# MPDBI38-THEFT (RESTRICTED COVER).pdf
# COUNT 265
# 1
# MPDBI21-CUSTOMERS AND SUPPLIERS-UNSPECIFIED-ALL RISKS.pdf
# COUNT 266
# 1
# PDBI40-SPECIFIED ITEMS-ALL RISKS-AMENDED TERRITORIAL LIMITS.pdf
# COUNT 267
# 1
# PDBIEPA-EXTENDED PERIOD AGREEMENT.pdf
# COUNT 268
# 1
# PDBINDX-LONG TERM AGREEMENT-POLICY CLAUSE-DISCOUNT.pdf
# COUNT 269
# 1
# PDBI02-BUILDINGS EXCLUSION.pdf
# COUNT 270
# 1
# PDBINBD-ELECTRICAL EQUIPMENT CONDITION.pdf
# COUNT 271
# 1
# MPDBI01-STOCK EXCLUSION.pdf
# COUNT 272
# 1
# MPDBI17-AVERAGE and PRE ADJ INC LIMIT.pdf
# COUNT 273
# 1
# Chubb Multinational PDBI - UK - (from 01-05-2017 until 31-03-2018) - Specimen.pdf
# COUNT 274
# /opt/app/RB/.local/lib/python3.6/site-packages/pdfminer/pdfpage.py:140: PDFTextExtractionNotAllowedWarning: The PDF <_io.BufferedReader name='/opt/app/RB/policy_search_APIs/tt_preprocessing/UK-Fire/Industry Standard Wording/Chubb Multinational PDBI - UK - (from 01-05-2017 until 31-03-2018) - Specimen.pdf'> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding.
#   warnings.warn(warning_msg, PDFTextExtractionNotAllowedWarning)
# 77
# EXT FALSE 1
# EXT TRUE 2
# EXT TRUE 3
# EXT TRUE 4
# EXT TRUE 5
# EXT FALSE 6
# EXT FALSE 7
# EXT FALSE 8
# EXT TRUE 9
# EXT TRUE 10
# EXT TRUE 11
# EXT TRUE 12
# EXT TRUE 13
# EXT FALSE 14
# EXT FALSE 15
# EXT FALSE 16
# EXT FALSE 17
# EXT FALSE 18
# EXT TRUE 19
# EXT TRUE 20
# EXT TRUE 21
# EXT TRUE 22
# EXT TRUE 23
# EXT TRUE 24
# EXT TRUE 25
# EXT TRUE 26
# EXT TRUE 27
# EXT TRUE 28
# EXT TRUE 29
# EXT TRUE 30
# EXT TRUE 31
# EXT TRUE 32
# EXT TRUE 33
# EXT FALSE 34
# EXT FALSE 35
# EXT FALSE 36
# EXT TRUE 37
# EXT TRUE 38
# EXT TRUE 39
# EXT TRUE 40
# EXT TRUE 41
# EXT TRUE 42
# EXT TRUE 43
# EXT FALSE 44
# EXT TRUE 45
# EXT FALSE 46
# EXT FALSE 47
# EXT FALSE 48
# EXT FALSE 49
# EXT TRUE 50
# EXT TRUE 51
# EXT FALSE 52
# EXT FALSE 53
# EXT TRUE 54
# EXT FALSE 55
# EXT FALSE 56
# EXT FALSE 57
# EXT FALSE 58
# EXT FALSE 59
# EXT FALSE 60
# EXT FALSE 61
# EXT TRUE 62
# EXT FALSE 63
# EXT FALSE 64
# EXT FALSE 65
# EXT FALSE 66
# EXT FALSE 67
# EXT FALSE 68
# EXT FALSE 69
# EXT FALSE 70
# EXT FALSE 71
# EXT FALSE 72
# EXT FALSE 73
# EXT FALSE 74
# EXT FALSE 75
# EXT FALSE 76
# 77 True !!!
# True EXCL
# MPDBI02-BUILDINGS EXCLUSION.pdf
# COUNT 275
# 1
# MPDBI03-CONTENTS EXCLUSION.pdf
# COUNT 276
# 1
# MPDBI - Marsh PEMA Endorsement (to 07-04-2020).pdf
# COUNT 277
# 8
# EXT TRUE 1
# EXT TRUE 2
# EXT TRUE 3
# EXT TRUE 4
# EXT TRUE 5
# EXT TRUE 6
# EXT TRUE 7
# MPDBI_WRP_1 - Willis Risk Protect - Extension to Section 1.pdf
# COUNT 278
# 1
# PDBINAR-COINSURERS SCHEDULE OF INSURERS (Other Insurers_Lloyds).pdf
# COUNT 279
# 1
# PDBINAX-PORTABLE HEATING CONDITION.pdf
# COUNT 280
# 1
# PDBI05-NOTIFIABLE DISEASE+DECONT INCLUDING LEGIONNAIRES.pdf
# COUNT 281
# 2
# EXT TRUE 1
# MPDBICAN-CANCELLATION RESTATED (MICRO-ENTERPRISES ONLY).pdf
# COUNT 282
# 2
# EXT FALSE 1
# MPDBI41- LOSS PAYEE.pdf
# COUNT 283
# 1
# PDBINDV-LONG TERM AGREEMENT-SECTIONAL CLAUSE-DISCOUNT-SPECIFIC PERCENTAGE.pdf
# COUNT 284
# 1
# CD1 - Communicable Disease Endt, Restrictions on Use of Premises option (to 30-06-20).pdf
# COUNT 285
# 2
# EXT TRUE 1
# PDBI01-STOCK EXCLUSION.pdf
# COUNT 286
# 1
# MPDBI42 - RIOTS, STRIKES, CIVIL COMMOTION, MALICIOUS DAMAGE EXCLUSION (Sections 1 and 2).pdf
# COUNT 287
# 1
# MPDBI05-NOTIFIABLE DISEASE+DECONT INCLUDING LEGIONNAIRES.pdf
# COUNT 288
# 2
# EXT TRUE 1
# PDBINCE-FAT FRYING CONDITION.pdf
# COUNT 289
# 1
# MPDBI27-GLASS.pdf
# COUNT 290
# 1

# %%
len(local_indexed)
# Out:
# 1139

# %%
from azure.cosmos import exceptions, CosmosClient, PartitionKey

cosmo_endpoint="https://nf-poc-cdb-sql.documents.azure.com"
cosmo_key="iEcEfrxYe0Fm9QtoxDrOpLvGsfzjowwybULlWT9Uz4XxV4RmOIAnRuLdgRFUu1LPU5Vwk3UGivRrPrxnk7083w=="
client = CosmosClient(cosmo_endpoint, cosmo_key)
database=client.get_database_client('policy-analysis')
container=database.get_container_client('fire-wordings')

# %%
for key,value in local_indexed.items():
    doc={}
    doc['text']=key
    doc['page']=int(value[1])
    if value[4]==True or value[0].find('Exclusion')!=-1:
        doc['IsExclusion']=True
    else:
        doc['IsExclusion']=False
    doc['doc_name']=value[0].replace('.pdf','')
    doc['id']=doc['doc_name']+' '+str(doc['page'])
    doc['bold_phrases']=value[2]
    doc['plain_text']=value[3]
    doc['excl_count']=value[5]
    doc['excl_pos']=value[6]
    doc['folder']=value[7]
    doc['definitions']=[{'name':key,'text':value} for key,value in re.findall('###(.*?)@@(.*?)%%%',doc['text'])]
    doc['country']=value[9]
    doc['language']=value[10]
    doc['definition_text']=value[11]
#     print(doc['definition_text'],'\n\n')
    if doc['definition_text']:
        doc['definition_flag']=True
    else:
        doc['definition_flag']=False
    if value[14]==True or 'endorsement' in value[0].lower(): 
        doc['endorsements']=True
    else:
        doc['endorsements']=value[13]
    doc['excl_text']=value[14]
    doc['cond_text']=value[15]
    doc['cond_flag']=value[16]
    doc['cond_count']=value[17]
    doc['cond_pos']=value[18]
    doc['definitions_in_page']=value[19]
    doc['ext_text']=value[20]
    doc['ext_flag']=value[21]
    doc['ext_count']=value[22]
    doc['ext_pos']=value[23]
    
    try:       
        container.create_item(body=doc)
    except Exception as err:
        print(err)
        pass

# %%
print('added to cosmos')
# Out:
# added to cosmos
